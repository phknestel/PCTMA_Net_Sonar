# %%
import os
os.environ["KMP_DUPLICATE_LIB_OK"]="TRUE"

# %%
# set GPU number
os.environ["CUDA_VISIBLE_DEVICES"] = "0"

# %% [markdown]
# # UNet

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F

# define the module of UNet
class DoubleConv(nn.Module):
    """(convolution => [BN] => ReLU) * 2"""

    def __init__(self, in_channels, out_channels, mid_channels=None):
        super().__init__()
        if not mid_channels:
            mid_channels = out_channels
        self.double_conv = nn.Sequential(
            nn.Conv2d(in_channels, mid_channels, kernel_size=3, padding=1),
            nn.BatchNorm2d(mid_channels),
            nn.ReLU(inplace=True),
            nn.Conv2d(mid_channels, out_channels, kernel_size=3, padding=1),
            nn.BatchNorm2d(out_channels),
            nn.ReLU(inplace=True)
        )

    def forward(self, x):
        return self.double_conv(x)


class Down(nn.Module):
    """Downscaling with maxpool then double conv"""

    def __init__(self, in_channels, out_channels):
        super().__init__()
        self.maxpool_conv = nn.Sequential(
            nn.MaxPool2d(2),
            DoubleConv(in_channels, out_channels)
        )

    def forward(self, x):
        return self.maxpool_conv(x)


class Up(nn.Module):
    """Upscaling then double conv"""

    def __init__(self, in_channels, out_channels, bilinear=True):
        super().__init__()

        # if bilinear, use the normal convolutions to reduce the number of channels
        if bilinear:
            self.up = nn.Upsample(scale_factor=2, mode='bilinear', align_corners=True)
            self.conv = DoubleConv(in_channels, out_channels, in_channels // 2)
        else:
            self.up = nn.ConvTranspose2d(in_channels , in_channels // 2, kernel_size=2, stride=2)
            self.conv = DoubleConv(in_channels, out_channels)


    def forward(self, x1, x2):
        x1 = self.up(x1)
        # input is CHW
        diffY = x2.size()[2] - x1.size()[2]
        diffX = x2.size()[3] - x1.size()[3]

        x1 = F.pad(x1, [diffX // 2, diffX - diffX // 2,
                        diffY // 2, diffY - diffY // 2])
        # if you have padding issues, see
        # https://github.com/HaiyongJiang/U-Net-Pytorch-Unstructured-Buggy/commit/0e854509c2cea854e247a9c615f175f76fbb2e3a
        # https://github.com/xiaopeng-liao/Pytorch-UNet/commit/8ebac70e633bac59fc22bb5195e513d5832fb3bd
        x = torch.cat([x2, x1], dim=1)
        return self.conv(x)


class OutConv(nn.Module):
    def __init__(self, in_channels, out_channels):
        super(OutConv, self).__init__()
        self.conv = nn.Conv2d(in_channels, out_channels, kernel_size=1)

    def forward(self, x):
        return self.conv(x)

# %%
# define UNet

class UNet(nn.Module):
    def __init__(self, n_channels=1, n_classes=1, bilinear=True):
        super(UNet, self).__init__()
        self.n_channels = n_channels
        self.n_classes = n_classes
        self.bilinear = bilinear

        self.inc = DoubleConv(n_channels, 64)
        self.down1 = Down(64, 128)
        self.down2 = Down(128, 256)
        self.down3 = Down(256, 512)
        factor = 2 if bilinear else 1
        self.down4 = Down(512, 1024 // factor)
        self.up1 = Up(1024, 512 // factor, bilinear)
        self.up2 = Up(512, 256 // factor, bilinear)
        self.up3 = Up(256, 128 // factor, bilinear)
        self.up4 = Up(128, 64, bilinear)
        self.outc = OutConv(64, n_classes)

    def forward(self, x):
        x1 = self.inc(x)
        x2 = self.down1(x1)
        x3 = self.down2(x2)
        x4 = self.down3(x3)
        x5 = self.down4(x4)
        x = self.up1(x5, x4)
        x = self.up2(x, x3)
        x = self.up3(x, x2)
        x = self.up4(x, x1)
        x = self.outc(x)
        x = F.sigmoid(x)
        #x,pr = self.depth_layer(x)
        #return x,pr
        return x

# %% [markdown]
# ## Train dataset

# %%
from PIL import Image, ImageOps
import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.utils.data import Dataset
import torchvision.transforms as transforms
import os
import numpy as np
import matplotlib.pyplot as plt
from torchvision.transforms.functional import to_pil_image
from PIL import Image, ImageOps
#from skimage import filters
from PIL import ImageFilter
import glob


torch.manual_seed(3)

class AcousticDataset(Dataset):
    def __init__(self,root='./BlenderFiles/dataset_four_obj/',transform=None, train=True): #trans_trim
        self.transform = transform
        self.train = train
        self.root = root
        
        
        self.length=self.generate_files()
    def generate_files(self,interv=3):
        self.path2acfiles = []
        self.path2elefiles = []
        self.path2fakefiles = []
        self.path2frontfiles = []
        self.motion = []
        count =+ 0
        for i in range(3): #it was 1
            i=i*80
            for j in range(17):  #change the scope of i and j to determine how many images are used for training. It was 5
                if (j==2 and i==0) or j==7:
                    continue
                j=j*10
                path2pose = self.root+str(i).rjust(3,'0')+'_'+str(j).rjust(3,'0')+'/record.txt'
                path=self.root+str(i).rjust(3,'0')+'_'+str(j).rjust(3,'0')+'/real_*.png'
                path2ele=self.root+str(i).rjust(3,'0')+'_'+str(j).rjust(3,'0')+'/ele_*.png'
                path2fake=self.root+str(i).rjust(3,'0')+'_'+str(j).rjust(3,'0')+'/sim_*.png'
                path2front=self.root+str(i).rjust(3,'0')+'_'+str(j).rjust(3,'0')+'/front_*.npy'
                
                #print(path)
                #path2mask=self.root+str(i).rjust(2,'0')+'/mask*.jpg'
            
                with open(path2pose) as f:
                    poselist = f.readlines()
                pathlist = glob.glob(path)
                pathlistele = glob.glob(path2ele)
                pathlistfake = glob.glob(path2fake)
                pathlistfront = glob.glob(path2front)
                pathlist.sort()
                pathlistele.sort()
                pathlistfake.sort()
                pathlistfront.sort()
                count = count + 1
                #print(f"Length of {count} pathlist: {len(pathlist)}")
                #print(f"Length of {count} poselist: {len(poselist)}")
                for k in range(interv,len(pathlist)-interv):
                    sublist = []
                    sublist.append(pathlist[k-interv])
                    sublist.append(pathlist[k])
                    sublist.append(pathlist[k+interv])

                    self.path2acfiles.append(sublist)
                
                    sublistele = []
                    sublistele.append(pathlistele[k-interv])
                    sublistele.append(pathlistele[k])
                    sublistele.append(pathlistele[k+interv])
                    self.path2elefiles.append(sublistele)
                    
                    sublistfake = []
                    sublistfake.append(pathlistfake[k-interv])
                    sublistfake.append(pathlistfake[k])
                    sublistfake.append(pathlistfake[k+interv])

                    self.path2fakefiles.append(sublistfake)
                    
                    self.path2frontfiles.append(pathlistfront[k])
                    
                    #idx_pre, p_previous = poselist[k-interv].split(' ')
                    #idx_cr, p_cr = poselist[k].split(' ')
                    #idx_next, p_next = poselist[k+interv].split(' ')
                    
                    p_previous = poselist[k-interv]
                    p_cr = poselist[k]
                    p_next = poselist[k+interv]
                
                    pose_previous = float(p_previous)
                    pose = float(p_cr)
                    pose_next = float(p_next)
                
                    motion1 = pose_previous-pose
                    motion2 = pose_next-pose
                
                    submotion=[]
                    submotion.append(motion1)
                    submotion.append(motion2)
                
                    self.motion.append(submotion)
                
                
                
        self.length=len(self.path2acfiles)
        return (self.length)

              

    
    def get_index(self):
        #idx = np.random.randint(self.length)
        idx = np.random.randint(1,22)
        return idx
    def __getitem__(self,idx):
        
        #idx = self.get_index()
        #print(idx)
        #path2image, path2label = self.lines[idx].split(' ')
        
        aclist=[]
        elelist=[]
        sublist = self.path2acfiles[idx]
        sublistele = self.path2elefiles[idx]
        sublistfake = self.path2fakefiles[idx]
        #sublistmask = self.path2maskfiles[idx]
        submotion = self.motion[idx]
        
        ac_previous=Image.open(sublist[0]).convert('L')
        ac=Image.open(sublist[1]).convert('L')
        ac_next=Image.open(sublist[2]).convert('L')
        
        ele_previous=Image.open(sublistele[0]).convert('L')
        ele=Image.open(sublistele[1]).convert('L')
        ele_next=Image.open(sublistele[2]).convert('L')
        
        fake_previous=Image.open(sublistfake[0]).convert('L')
        fake=Image.open(sublistfake[1]).convert('L')
        fake_next=Image.open(sublistfake[2]).convert('L')
        #mask_previous=Image.open(sublistmask[0]).convert('1')
        #mask=Image.open(sublistmask[1]).convert('1')
        #mask_next=Image.open(sublistmask[2]).convert('1')
        front_path = self.path2frontfiles[idx]
        front = np.load(front_path)
        
        front_resize = torch.tensor(front,dtype=torch.float32).unsqueeze(0).unsqueeze(0)
        #resize
        
      
        front_resize = F.interpolate(front_resize,(64,128), mode='bicubic')
        
        #front_resize = front_resize*6-1.5
        front_resize = 1/front_resize
        
        
        minimum_depth = 0.971+0.00299*400
        maximum_depth = 0.971+0.00299*1100
        front_resize[front_resize>maximum_depth] =maximum_depth
        front_resize[front_resize<minimum_depth] = minimum_depth
        
        front_resize = front_resize.squeeze()
        
        motion1 = submotion[0]/180.0*3.1415926
        motion2 = submotion[1]/180.0*3.1415926
        
        #ac = ac.resize((128,256))
        #ac_next = ac_next.resize((128,256))
        #ac_previous = ac_previous.resize((128,256))
        ac = ac.crop((0,400,128,1100))
        ele = ele.crop((0,400,128,1100))
        ac_next = ac_next.crop((0,400,128,1100))
        ac_previous = ac_previous.crop((0,400,128,1100))
        ele_next = ele_next.crop((0,400,128,1100))
        ele_previous = ele_previous.crop((0,400,128,1100))
        fake = fake.crop((0,400,128,1100))
        fake_next = fake_next.crop((0,400,128,1100))
        fake_previous = fake_previous.crop((0,400,128,1100))
        
        ac = ac.resize((128,512))
        ac_next = ac_next.resize((128,512))
        ac_previous = ac_previous.resize((128,512))
        
        ele = ele.resize((128,512))
        ele_next = ele_next.resize((128,512))
        ele_previous = ele_previous.resize((128,512))
        
        fake = fake.resize((128,512))
        fake_next = fake_next.resize((128,512))
        fake_previous = fake_previous.resize((128,512))
        
        ac_blur=ac.filter(ImageFilter.MedianFilter(7))
        ac_next_blur=ac_next.filter(ImageFilter.MedianFilter(7))
        ac_previous_blur=ac_previous.filter(ImageFilter.MedianFilter(7))
        
        ac=ac.filter(ImageFilter.MedianFilter(3))
        ac_next=ac_next.filter(ImageFilter.MedianFilter(3))
        ac_previous=ac_previous.filter(ImageFilter.MedianFilter(3))  
        
        #mask = ac_blur.point(lambda p: p > 30 and 255)
        #mask_previous = ac_previous_blur.point(lambda p: p > 30 and 255)  #27
        #mask_next = ac_next_blur.point(lambda p: p > 30 and 255)
        
        mask = ele.point(lambda p: p > 3 and 255)
        mask_previous = ele_previous.point(lambda p: p > 3 and 255)  #27
        mask_next = ele_next.point(lambda p: p > 3 and 255)

        #hflip = np.random.random() < 0.5
        hflip=False
        if hflip and self.train:
            ac=ImageOps.mirror(ac)
        
            ac_previous=ImageOps.mirror(ac_previous)
            
            ac_next=ImageOps.mirror(ac_next)
            
            fake=ImageOps.mirror(fake)
        
            fake_previous=ImageOps.mirror(fake_previous)
            
            fake_next=ImageOps.mirror(fake_next)
            
            
            
            ele=ImageOps.mirror(ele)
        
            ele_previous=ImageOps.mirror(ele_previous)
            
            ele_next=ImageOps.mirror(ele_next)
            
            mask=ImageOps.mirror(mask)
        
            mask_previous=ImageOps.mirror(mask_previous)
            
            mask_next=ImageOps.mirror(mask_next)
        
      
        
        if self.transform is not None:
            
            ac = self.transform(ac)
            ac_previous = self.transform(ac_previous)
            ac_next = self.transform(ac_next)
            
            fake = self.transform(fake)
            fake_previous = self.transform(fake_previous)
            fake_next = self.transform(fake_next)
            
            ele = self.transform(ele)
            ele_previous = self.transform(ele_previous)
            ele_next = self.transform(ele_next)
          
            mask = self.transform(mask)
            mask_previous = self.transform(mask_previous)
            mask_next = self.transform(mask_next)
            
            #masker = self.transform(masker)
            motiona = torch.zeros(6)
            motionb = torch.zeros(6)
            
            motion1 = torch.tensor(motion1)
            motion2 = torch.tensor(motion2)
            
            motiona[3] = -motion1
            motionb[3] = -motion2
            
           
            #ac = fake
            #ac_next = fake_next
            #ac_previous = fake_previous
            
        return ac, ele, mask, ac_previous, ele_previous, mask_previous, ac_next, ele_next, mask_next, motiona, motionb, front_resize
    def __len__(self):
        return self.length

# %% [markdown]
# ## Train dataset trial

# %%
transformations = transforms.Compose([transforms.ToTensor()])
acoustic_dataset = AcousticDataset(transform=transformations,train=True)
print(len(acoustic_dataset))
ac, ele, mask, ac_previous, ele_previous, mask_previous, ac_next, ele_next, mask_next, motion1, motion2, front_resize= acoustic_dataset[15]

print(motion1)
print(motion2)

print(ac.shape)
plt.rcParams['image.cmap'] = 'gray'
plt.figure(figsize=(8,8))
plt.subplot(1,3,1)
plt.imshow(ac_previous.squeeze())
plt.subplot(1,3,2)
plt.imshow(ac.squeeze())
plt.subplot(1,3,3)
plt.imshow(ac_next.squeeze())
plt.rcParams['image.cmap'] = 'viridis'
plt.figure(figsize=(8,8))
plt.subplot(1,3,1)
plt.imshow(mask_previous.squeeze())
plt.subplot(1,3,2)
plt.imshow(mask.squeeze())
plt.subplot(1,3,3)
plt.imshow(mask_next.squeeze())
plt.figure(figsize=(8,8))
plt.subplot(1,3,1)
plt.imshow(mask_previous.squeeze()*ac_previous.squeeze())
plt.subplot(1,3,2)
plt.imshow(mask.squeeze()*ac.squeeze())
plt.subplot(1,3,3)
plt.imshow(mask_next.squeeze()*ac_next.squeeze())
# Out:
# 1234
# tensor([0.0000, 0.0000, 0.0000, 0.1099, 0.0000, 0.0000])
# tensor([ 0.0000,  0.0000,  0.0000, -0.1099,  0.0000,  0.0000])
# torch.Size([1, 512, 128])

# %%
from torch.utils.data import DataLoader
train_dl = DataLoader(acoustic_dataset,batch_size=4,shuffle=True)

# %% [markdown]
# # Test

# %%
class TestDataset(Dataset):
    def __init__(self,root='./BlenderFiles/dataset_four_obj/',transform=None, train=False): #trans_trim
        self.transform = transform
        self.train = train
        self.root = root
        
        
        self.length=self.generate_files()
    def generate_files(self,interv=0):
        self.path2acfiles = []
        self.path2elefiles = []
        self.path2fakefiles = []
        self.path2frontfiles = []
        self.motion = []
        for i in range(3):
            i=i*80
            for j in range(17): # change here to determine test set
                if j==2 and i==0: # change here to determine test set
                    continue
                #if  j==7:
                #if j>-1:
                
                if  j==7:
                    j=j*10
                    path2pose = self.root+str(i).rjust(3,'0')+'_'+str(j).rjust(3,'0')+'/record.txt'
                    path=self.root+str(i).rjust(3,'0')+'_'+str(j).rjust(3,'0')+'/real_*.png'
                    path2ele=self.root+str(i).rjust(3,'0')+'_'+str(j).rjust(3,'0')+'/ele_*.png'
                    path2fake=self.root+str(i).rjust(3,'0')+'_'+str(j).rjust(3,'0')+'/sim_*.png'
                    path2front=self.root+str(i).rjust(3,'0')+'_'+str(j).rjust(3,'0')+'/front_*.npy'
                
                
            
                    with open(path2pose) as f:
                        poselist = f.readlines()
                    pathlist = glob.glob(path)
                    pathlistele = glob.glob(path2ele)
                    pathlistfake = glob.glob(path2fake)
                    pathlistfront = glob.glob(path2front)
                    pathlist.sort()
                    pathlistele.sort()
                    pathlistfake.sort()
                    pathlistfront.sort()
                    for k in range(interv,len(pathlist)-interv):
                        sublist = []
                        sublist.append(pathlist[k-interv])
                        sublist.append(pathlist[k])
                        sublist.append(pathlist[k+interv])

                        self.path2acfiles.append(sublist)
                
                        sublistele = []
                        sublistele.append(pathlistele[k-interv])
                        sublistele.append(pathlistele[k])
                        sublistele.append(pathlistele[k+interv])
                        self.path2elefiles.append(sublistele)
                    
                        sublistfake = []
                        sublistfake.append(pathlistfake[k-interv])
                        sublistfake.append(pathlistfake[k])
                        sublistfake.append(pathlistfake[k+interv])

                        self.path2fakefiles.append(sublistfake)
                    
                        self.path2frontfiles.append(pathlistfront[k])
                    
                        #idx_pre, p_previous = poselist[k-interv].split(' ')
                        #idx_cr, p_cr = poselist[k].split(' ')
                        #idx_next, p_next = poselist[k+interv].split(' ')
                    
                        p_previous = poselist[k-interv]
                        p_cr = poselist[k]
                        p_next = poselist[k+interv]
                
                        pose_previous = float(p_previous)
                        pose = float(p_cr)
                        pose_next = float(p_next)
                
                        motion1 = pose_previous-pose
                        motion2 = pose_next-pose
                
                        submotion=[]
                        submotion.append(motion1)
                        submotion.append(motion2)
                
                        self.motion.append(submotion)
                
                
                
        self.length=len(self.path2acfiles)
        return (self.length)

              

    
    def get_index(self):
        #idx = np.random.randint(self.length)
        idx = np.random.randint(1,22)
        return idx
    def __getitem__(self,idx):
        
        #idx = self.get_index()
        #print(idx)
        #path2image, path2label = self.lines[idx].split(' ')
        
        aclist=[]
        elelist=[]
        sublist = self.path2acfiles[idx]
        sublistele = self.path2elefiles[idx]
        sublistfake = self.path2fakefiles[idx]
        #sublistmask = self.path2maskfiles[idx]
        submotion = self.motion[idx]
        
        ac_previous=Image.open(sublist[0]).convert('L')
        ac=Image.open(sublist[1]).convert('L')
        ac_next=Image.open(sublist[2]).convert('L')
        
        ele_previous=Image.open(sublistele[0]).convert('L')
        ele=Image.open(sublistele[1]).convert('L')
        ele_next=Image.open(sublistele[2]).convert('L')
        
        fake_previous=Image.open(sublistfake[0]).convert('L')
        fake=Image.open(sublistfake[1]).convert('L')
        fake_next=Image.open(sublistfake[2]).convert('L')
        #mask_previous=Image.open(sublistmask[0]).convert('1')
        #mask=Image.open(sublistmask[1]).convert('1')
        #mask_next=Image.open(sublistmask[2]).convert('1')
        
        front_path = self.path2frontfiles[idx]
        front = np.load(front_path)
        
        front_resize = torch.tensor(front,dtype=torch.float32).unsqueeze(0).unsqueeze(0)
        #resize
        
      
        front_resize = F.interpolate(front_resize,(64,128), mode='bicubic')
        
        #front_resize = front_resize*6-1.5
        front_resize = 1/front_resize
        
        
        minimum_depth = 0.971+0.00299*400
        maximum_depth = 0.971+0.00299*1100
        front_resize[front_resize>maximum_depth] =maximum_depth
        front_resize[front_resize<minimum_depth] = minimum_depth
        
        front_resize = front_resize.squeeze()
        
        
        motion1 = submotion[0]/180.0*3.1415926
        motion2 = submotion[1]/180.0*3.1415926
        
        #ac = ac.resize((128,256))
        #ac_next = ac_next.resize((128,256))
        #ac_previous = ac_previous.resize((128,256))
        ac = ac.crop((0,400,128,1100))
        ele = ele.crop((0,400,128,1100))
        ac_next = ac_next.crop((0,400,128,1100))
        ac_previous = ac_previous.crop((0,400,128,1100))
        ele_next = ele_next.crop((0,400,128,1100))
        ele_previous = ele_previous.crop((0,400,128,1100))
        fake = fake.crop((0,400,128,1100))
        fake_next = fake_next.crop((0,400,128,1100))
        fake_previous = fake_previous.crop((0,400,128,1100))
        
        ac = ac.resize((128,512))
        ac_next = ac_next.resize((128,512))
        ac_previous = ac_previous.resize((128,512))
        
        ele = ele.resize((128,512))
        ele_next = ele_next.resize((128,512))
        ele_previous = ele_previous.resize((128,512))
        
        fake = fake.resize((128,512))
        fake_next = fake_next.resize((128,512))
        fake_previous = fake_previous.resize((128,512))
        
        ac_blur=ac.filter(ImageFilter.MedianFilter(7))
        ac_next_blur=ac_next.filter(ImageFilter.MedianFilter(7))
        ac_previous_blur=ac_previous.filter(ImageFilter.MedianFilter(7))
        
        ac=ac.filter(ImageFilter.MedianFilter(3))
        ac_next=ac_next.filter(ImageFilter.MedianFilter(3))
        ac_previous=ac_previous.filter(ImageFilter.MedianFilter(3))  
        
        #mask = ac_blur.point(lambda p: p > 30 and 255)
        #mask_previous = ac_previous_blur.point(lambda p: p > 30 and 255)  #27
        #mask_next = ac_next_blur.point(lambda p: p > 30 and 255)
        
        mask = ele.point(lambda p: p > 3 and 255) #22
        mask_previous = ele_previous.point(lambda p: p > 3 and 255)  #27
        mask_next = ele_next.point(lambda p: p > 3 and 255)

        #hflip = np.random.random() < 0.5
        hflip=False
        if hflip:
            ac=ImageOps.mirror(ac)
        
            ac_previous=ImageOps.mirror(ac_previous)
            
            ac_next=ImageOps.mirror(ac_next)
            
            fake=ImageOps.mirror(fake)
        
            fake_previous=ImageOps.mirror(fake_previous)
            
            fake_next=ImageOps.mirror(fake_next)
            
            
            
            ele=ImageOps.mirror(ele)
        
            ele_previous=ImageOps.mirror(ele_previous)
            
            ele_next=ImageOps.mirror(ele_next)
            
            mask=ImageOps.mirror(mask)
        
            mask_previous=ImageOps.mirror(mask_previous)
            
            mask_next=ImageOps.mirror(mask_next)
        
      
        
        if self.transform is not None:
            
            ac = self.transform(ac)
            ac_previous = self.transform(ac_previous)
            ac_next = self.transform(ac_next)
            
            fake = self.transform(fake)
            fake_previous = self.transform(fake_previous)
            fake_next = self.transform(fake_next)
            
            ele = self.transform(ele)
            ele_previous = self.transform(ele_previous)
            ele_next = self.transform(ele_next)
          
            mask = self.transform(mask)
            mask_previous = self.transform(mask_previous)
            mask_next = self.transform(mask_next)
            
            #masker = self.transform(masker)
            motiona = torch.zeros(6)
            motionb = torch.zeros(6)
            
            motion1 = torch.tensor(motion1)
            motion2 = torch.tensor(motion2)
            
            motiona[3] = motion1
            motionb[3] = motion2
            
           
            #ac = fake
            #ac_next = fake_next
            #ac_previous = fake_previous
            
        return ac, ele, mask, ac_previous, ele_previous, mask_previous, ac_next, ele_next, mask_next, motiona, motionb, front_resize
    def __len__(self):
        return self.length

# %%
transformations = transforms.Compose([transforms.ToTensor()])
test_dataset = TestDataset(transform=transformations,train=False)
print(len(test_dataset))
ac, ele, mask, ac_previous, ele_previous, mask_previous, ac_next, ele_next, mask_next, motion1, motion2, front_resize= test_dataset[15]

print(motion1)
print(motion2)

print(ac.shape)
plt.rcParams['image.cmap'] = 'gray'
plt.figure(figsize=(8,8))
plt.subplot(1,3,1)
plt.imshow(ac_previous.squeeze())
plt.subplot(1,3,2)
plt.imshow(ac.squeeze())
plt.subplot(1,3,3)
plt.imshow(ac_next.squeeze())
plt.rcParams['image.cmap'] = 'viridis'
plt.figure(figsize=(8,8))
plt.subplot(1,3,1)
plt.imshow(mask_previous.squeeze())
plt.subplot(1,3,2)
plt.imshow(mask.squeeze())
plt.subplot(1,3,3)
plt.imshow(mask_next.squeeze())
plt.figure(figsize=(8,8))
plt.subplot(1,3,1)
plt.imshow(mask_previous.squeeze()*ac_previous.squeeze())
plt.subplot(1,3,2)
plt.imshow(mask.squeeze()*ac.squeeze())
plt.subplot(1,3,3)
plt.imshow(mask_next.squeeze()*ac_next.squeeze())

plt.figure(figsize=(8,8))
plt.imshow(front_resize.squeeze())
# Out:
# 100
# tensor([0., 0., 0., 0., 0., 0.])
# tensor([0., 0., 0., 0., 0., 0.])
# torch.Size([1, 512, 128])

# %%
from torch.utils.data import DataLoader
test_dl = DataLoader(test_dataset,batch_size=1,shuffle=False)

# %% [markdown]
# ### AllData

# %%
class AllDataDataset(Dataset):
    def __init__(self,root='./BlenderFiles/dataset_four_obj/',transform=None, train=False):
        self.transform = transform
        self.train = train
        self.root = root
        
        
        self.length=self.generate_files()
    def generate_files(self,interv=0):
        self.path2acfiles = []
        self.path2elefiles = []
        self.path2fakefiles = []
        self.path2frontfiles = []
        self.motion = []
        for i in range(3):
            i=i*80
            for j in range(17): # change here to determine test set
                if j==2 and i==0: # change here to determine test set
                    continue
                #if  j==7:
                if j>-1:
                    j=j*10
                    path2pose = self.root+str(i).rjust(3,'0')+'_'+str(j).rjust(3,'0')+'/record.txt'
                    path=self.root+str(i).rjust(3,'0')+'_'+str(j).rjust(3,'0')+'/real_*.png'
                    path2ele=self.root+str(i).rjust(3,'0')+'_'+str(j).rjust(3,'0')+'/ele_*.png'
                    path2fake=self.root+str(i).rjust(3,'0')+'_'+str(j).rjust(3,'0')+'/sim_*.png'
                    path2front=self.root+str(i).rjust(3,'0')+'_'+str(j).rjust(3,'0')+'/front_*.npy'
                
                
            
                    with open(path2pose) as f:
                        poselist = f.readlines()
                    pathlist = glob.glob(path)
                    pathlistele = glob.glob(path2ele)
                    pathlistfake = glob.glob(path2fake)
                    pathlistfront = glob.glob(path2front)
                    pathlist.sort()
                    pathlistele.sort()
                    pathlistfake.sort()
                    pathlistfront.sort()
                    for k in range(interv,len(pathlist)-interv):
                        sublist = []
                        sublist.append(pathlist[k-interv])
                        sublist.append(pathlist[k])
                        sublist.append(pathlist[k+interv])

                        self.path2acfiles.append(sublist)
                
                        sublistele = []
                        sublistele.append(pathlistele[k-interv])
                        sublistele.append(pathlistele[k])
                        sublistele.append(pathlistele[k+interv])
                        self.path2elefiles.append(sublistele)
                    
                        sublistfake = []
                        sublistfake.append(pathlistfake[k-interv])
                        sublistfake.append(pathlistfake[k])
                        sublistfake.append(pathlistfake[k+interv])

                        self.path2fakefiles.append(sublistfake)
                    
                        self.path2frontfiles.append(pathlistfront[k])
                    
                        #idx_pre, p_previous = poselist[k-interv].split(' ')
                        #idx_cr, p_cr = poselist[k].split(' ')
                        #idx_next, p_next = poselist[k+interv].split(' ')
                    
                        p_previous = poselist[k-interv]
                        p_cr = poselist[k]
                        p_next = poselist[k+interv]
                
                        pose_previous = float(p_previous)
                        pose = float(p_cr)
                        pose_next = float(p_next)
                
                        motion1 = pose_previous-pose
                        motion2 = pose_next-pose
                
                        submotion=[]
                        submotion.append(motion1)
                        submotion.append(motion2)
                
                        self.motion.append(submotion)
                
                
                
        self.length=len(self.path2acfiles)
        return (self.length)

              

    
    def get_index(self):
        #idx = np.random.randint(self.length)
        idx = np.random.randint(1,22)
        return idx
    def __getitem__(self,idx):
        
        #idx = self.get_index()
        #print(idx)
        #path2image, path2label = self.lines[idx].split(' ')
        
        aclist=[]
        elelist=[]
        sublist = self.path2acfiles[idx]
        sublistele = self.path2elefiles[idx]
        sublistfake = self.path2fakefiles[idx]
        #sublistmask = self.path2maskfiles[idx]
        submotion = self.motion[idx]
        
        ac_previous=Image.open(sublist[0]).convert('L')
        ac=Image.open(sublist[1]).convert('L')
        ac_next=Image.open(sublist[2]).convert('L')
        
        ele_previous=Image.open(sublistele[0]).convert('L')
        ele=Image.open(sublistele[1]).convert('L')
        ele_next=Image.open(sublistele[2]).convert('L')
        
        fake_previous=Image.open(sublistfake[0]).convert('L')
        fake=Image.open(sublistfake[1]).convert('L')
        fake_next=Image.open(sublistfake[2]).convert('L')
        #mask_previous=Image.open(sublistmask[0]).convert('1')
        #mask=Image.open(sublistmask[1]).convert('1')
        #mask_next=Image.open(sublistmask[2]).convert('1')
        
        front_path = self.path2frontfiles[idx]
        front = np.load(front_path)
        
        front_resize = torch.tensor(front,dtype=torch.float32).unsqueeze(0).unsqueeze(0)
        #resize
        
      
        front_resize = F.interpolate(front_resize,(64,128), mode='bicubic')
        
        #front_resize = front_resize*6-1.5
        front_resize = 1/front_resize
        
        
        minimum_depth = 0.971+0.00299*400
        maximum_depth = 0.971+0.00299*1100
        front_resize[front_resize>maximum_depth] =maximum_depth
        front_resize[front_resize<minimum_depth] = minimum_depth
        
        front_resize = front_resize.squeeze()
        
        
        motion1 = submotion[0]/180.0*3.1415926
        motion2 = submotion[1]/180.0*3.1415926
        
        #ac = ac.resize((128,256))
        #ac_next = ac_next.resize((128,256))
        #ac_previous = ac_previous.resize((128,256))
        ac = ac.crop((0,400,128,1100))
        ele = ele.crop((0,400,128,1100))
        ac_next = ac_next.crop((0,400,128,1100))
        ac_previous = ac_previous.crop((0,400,128,1100))
        ele_next = ele_next.crop((0,400,128,1100))
        ele_previous = ele_previous.crop((0,400,128,1100))
        fake = fake.crop((0,400,128,1100))
        fake_next = fake_next.crop((0,400,128,1100))
        fake_previous = fake_previous.crop((0,400,128,1100))
        
        ac = ac.resize((128,512))
        ac_next = ac_next.resize((128,512))
        ac_previous = ac_previous.resize((128,512))
        
        ele = ele.resize((128,512))
        ele_next = ele_next.resize((128,512))
        ele_previous = ele_previous.resize((128,512))
        
        fake = fake.resize((128,512))
        fake_next = fake_next.resize((128,512))
        fake_previous = fake_previous.resize((128,512))
        
        ac_blur=ac.filter(ImageFilter.MedianFilter(7))
        ac_next_blur=ac_next.filter(ImageFilter.MedianFilter(7))
        ac_previous_blur=ac_previous.filter(ImageFilter.MedianFilter(7))
        
        ac=ac.filter(ImageFilter.MedianFilter(3))
        ac_next=ac_next.filter(ImageFilter.MedianFilter(3))
        ac_previous=ac_previous.filter(ImageFilter.MedianFilter(3))  
        
        #mask = ac_blur.point(lambda p: p > 30 and 255)
        #mask_previous = ac_previous_blur.point(lambda p: p > 30 and 255)  #27
        #mask_next = ac_next_blur.point(lambda p: p > 30 and 255)
        
        mask = ele.point(lambda p: p > 3 and 255) #22
        mask_previous = ele_previous.point(lambda p: p > 3 and 255)  #27
        mask_next = ele_next.point(lambda p: p > 3 and 255)

        #hflip = np.random.random() < 0.5
        hflip=False
        if hflip:
            ac=ImageOps.mirror(ac)
        
            ac_previous=ImageOps.mirror(ac_previous)
            
            ac_next=ImageOps.mirror(ac_next)
            
            fake=ImageOps.mirror(fake)
        
            fake_previous=ImageOps.mirror(fake_previous)
            
            fake_next=ImageOps.mirror(fake_next)
            
            
            
            ele=ImageOps.mirror(ele)
        
            ele_previous=ImageOps.mirror(ele_previous)
            
            ele_next=ImageOps.mirror(ele_next)
            
            mask=ImageOps.mirror(mask)
        
            mask_previous=ImageOps.mirror(mask_previous)
            
            mask_next=ImageOps.mirror(mask_next)
        
      
        
        if self.transform is not None:
            
            ac = self.transform(ac)
            ac_previous = self.transform(ac_previous)
            ac_next = self.transform(ac_next)
            
            fake = self.transform(fake)
            fake_previous = self.transform(fake_previous)
            fake_next = self.transform(fake_next)
            
            ele = self.transform(ele)
            ele_previous = self.transform(ele_previous)
            ele_next = self.transform(ele_next)
          
            mask = self.transform(mask)
            mask_previous = self.transform(mask_previous)
            mask_next = self.transform(mask_next)
            
            #masker = self.transform(masker)
            motiona = torch.zeros(6)
            motionb = torch.zeros(6)
            
            motion1 = torch.tensor(motion1)
            motion2 = torch.tensor(motion2)
            
            motiona[3] = motion1
            motionb[3] = motion2
            
           
            #ac = fake
            #ac_next = fake_next
            #ac_previous = fake_previous
            
        return ac, ele, mask, ac_previous, ele_previous, mask_previous, ac_next, ele_next, mask_next, motiona, motionb, front_resize
    def __len__(self):
        return self.length

# %%
transformations = transforms.Compose([transforms.ToTensor()])
alldata_dataset = AllDataDataset(transform=transformations,train=False)
print(len(alldata_dataset))
ac, ele, mask, ac_previous, ele_previous, mask_previous, ac_next, ele_next, mask_next, motion1, motion2, front_resize= test_dataset[15]

print(motion1)
print(motion2)

print(ac.shape)
plt.rcParams['image.cmap'] = 'gray'
plt.figure(figsize=(8,8))
plt.subplot(1,3,1)
plt.imshow(ac_previous.squeeze())
plt.subplot(1,3,2)
plt.imshow(ac.squeeze())
plt.subplot(1,3,3)
plt.imshow(ac_next.squeeze())
plt.rcParams['image.cmap'] = 'viridis'
plt.figure(figsize=(8,8))
plt.subplot(1,3,1)
plt.imshow(mask_previous.squeeze())
plt.subplot(1,3,2)
plt.imshow(mask.squeeze())
plt.subplot(1,3,3)
plt.imshow(mask_next.squeeze())
plt.figure(figsize=(8,8))
plt.subplot(1,3,1)
plt.imshow(mask_previous.squeeze()*ac_previous.squeeze())
plt.subplot(1,3,2)
plt.imshow(mask.squeeze()*ac.squeeze())
plt.subplot(1,3,3)
plt.imshow(mask_next.squeeze()*ac_next.squeeze())

plt.figure(figsize=(8,8))
plt.imshow(front_resize.squeeze())
# Out:
# 1616
# tensor([0., 0., 0., 0., 0., 0.])
# tensor([0., 0., 0., 0., 0., 0.])
# torch.Size([1, 512, 128])

# %%
from torch.utils.data import DataLoader
all_dl = DataLoader(alldata_dataset,batch_size=1,shuffle=True)

# %% [markdown]
# ## warp

# %%
PI = torch.acos(torch.zeros(1)).item() * 2

def ele2pc(ele,mask): #depth: batch, channel, elevation, azimuth [b,c,e,a]  [1,1,32,128]
    
    scale=700/512
    angle=18.0
    
    ele = ele*mask
    ele = ele*angle-angle/2
        
    
    #print(ele.shape)
    aa = (ele<9)
    bb = (ele>-9)
    valid = (aa&bb)
  
    
    ele=ele/180.0*PI
    #global pixel_coords
    b,c,e,a = ele.size()
    valid = valid.reshape(b,-1)
    
    
    i_range = torch.arange(0, e).view(1, e, 1).expand(1,e,a).type_as(ele)*(scale*0.00299)+0.971+400*(0.00299)  # 48.55 optical camera aperture
    i_range = i_range
    j_range = torch.arange(0, a).view(1, 1, a).expand(1,e,a).type_as(ele)/128*(30.0)-(30.0/2)  #-32
    j_range = j_range/180.0*PI
    ones = torch.ones(1,e,a).type_as(ele)
    
    #print(i_range.shape)
    

    
    pixel_coords = torch.stack((j_range, i_range, ones), dim=1)
    
    
    current_pixel_coords = pixel_coords[:,:,:e,:a].expand(b,3,e,a)
    
    ones_exp = torch.ones(b,e,a).type_as(ele)

    ele_exp = torch.stack((ones_exp, ones_exp, ele.squeeze(1)), dim=1)
    
    current_pixel_coords= ele_exp*current_pixel_coords
    
    #print(current_pixel_coords.shape)
   
    #print(current_pixel_coords[:,2,:,:]/PI*180)
    
    x = current_pixel_coords[:,1,:,:]*torch.cos(current_pixel_coords[:,0,:,:])*torch.cos(current_pixel_coords[:,2,:,:])
    y = current_pixel_coords[:,1,:,:]*torch.sin(current_pixel_coords[:,0,:,:])*torch.cos(current_pixel_coords[:,2,:,:])
    z = current_pixel_coords[:,1,:,:]*torch.sin(current_pixel_coords[:,2,:,:])
    
   
    pc = torch.stack((x, y, z), dim=1)
    #pc = pc*mask
    #print(pc.shape)
    
    pc = pc.view(b,3,-1)
    #pc = pc.transpose(1,2)
    
    #valid =valid.unsqueeze(2)
    
    #print(pc.shape)
    
    return pc,valid

# %%
def pc2pixel(pc, proj_c2p_rot, proj_c2p_tr,valid=None):
    """Transform coordinates in the camera frame to the pixel frame.
    Args:
        pc: point cloud in the first camera coordinates system -- [B, 3, N]
        proj_c2p_rot: rotation matrix of cameras -- [B, 3, 4]
        proj_c2p_tr: translation vectors of cameras -- [B, 3, 1]
    Returns:
        array of [-1,1] coordinates -- [B, 2, H, W]
    """
    scale=700/512
    
    
    w = 128
    h = 512
    b, n, _ = pc.size()
   
    if proj_c2p_rot is not None:
        pcoords = proj_c2p_rot @ pc
    else:
        pcoords = pc

    if proj_c2p_tr is not None:
        pcoords = pcoords + proj_c2p_tr  # [B, 3, H*W]
    X = pcoords[:, 0]
    Y = pcoords[:, 1]
    Z = pcoords[:, 2] #.clamp(min=1e-3)
    
    
    r = torch.sign(X)*torch.sqrt(X**2+Y**2+Z**2)
    theta = torch.atan(Y/X)
    phi = torch.atan(Z/torch.sqrt(X**2+Y**2))

    
    x_norm = (theta/3.1415926*180.0+15.0)/(30.0/128.0)
    y_norm = (r-0.971-400*0.00299)/(scale*0.00299)
   
    
    

    x_norm = 2*x_norm/(w-1) - 1  # Normalized, -1 if on extreme left, 1 if on extreme right (x = w-1) [B, H*W]
    y_norm = 2*y_norm/(h-1) - 1  # Idem [B, H*W]

    pixel_coords = torch.stack([x_norm, y_norm], dim=2)  # [B, H*W, 2]
    return pixel_coords.reshape(b,h,w,2)


def euler2mat(angle):
    """Convert euler angles to rotation matrix.
     Reference: https://github.com/pulkitag/pycaffe-utils/blob/master/rot_utils.py#L174
    Args:
        angle: rotation angle along 3 axis (in radians) -- size = [B, 3]
    Returns:
        Rotation matrix corresponding to the euler angles -- size = [B, 3, 3]
    """
    B = angle.size(0)
    x, y, z = angle[:,0], angle[:,1], angle[:,2]

    cosz = torch.cos(z)
    sinz = torch.sin(z)

    zeros = z.detach()*0
    ones = zeros.detach()+1
    zmat = torch.stack([cosz, -sinz, zeros,
                        sinz,  cosz, zeros,
                        zeros, zeros,  ones], dim=1).reshape(B, 3, 3)

    cosy = torch.cos(y)
    siny = torch.sin(y)

    ymat = torch.stack([cosy, zeros,  siny,
                        zeros,  ones, zeros,
                        -siny, zeros,  cosy], dim=1).reshape(B, 3, 3)

    cosx = torch.cos(x)
    sinx = torch.sin(x)

    xmat = torch.stack([ones, zeros, zeros,
                        zeros,  cosx, -sinx,
                        zeros,  sinx,  cosx], dim=1).reshape(B, 3, 3)

    rotMat = xmat @ ymat @ zmat
    return rotMat


def quat2mat(quat):
    """Convert quaternion coefficients to rotation matrix.
    Args:
        quat: first three coeff of quaternion of rotation. fourht is then computed to have a norm of 1 -- size = [B, 3]
    Returns:
        Rotation matrix corresponding to the quaternion -- size = [B, 3, 3]
    """
    norm_quat = torch.cat([quat[:,:1].detach()*0 + 1, quat], dim=1)
    norm_quat = norm_quat/norm_quat.norm(p=2, dim=1, keepdim=True)
    w, x, y, z = norm_quat[:,0], norm_quat[:,1], norm_quat[:,2], norm_quat[:,3]

    B = quat.size(0)

    w2, x2, y2, z2 = w.pow(2), x.pow(2), y.pow(2), z.pow(2)
    wx, wy, wz = w*x, w*y, w*z
    xy, xz, yz = x*y, x*z, y*z

    rotMat = torch.stack([w2 + x2 - y2 - z2, 2*xy - 2*wz, 2*wy + 2*xz,
                          2*wz + 2*xy, w2 - x2 + y2 - z2, 2*yz - 2*wx,
                          2*xz - 2*wy, 2*wx + 2*yz, w2 - x2 - y2 + z2], dim=1).reshape(B, 3, 3)
    return rotMat


def pose_vec2mat(vec, rotation_mode='euler'):
    """
    Convert 6DoF parameters to transformation matrix.
    Args:s
        vec: 6DoF parameters in the order of tx, ty, tz, rx, ry, rz -- [B, 6]
    Returns:
        A transformation matrix -- [B, 3, 4]
    """
    translation = vec[:, :3].unsqueeze(-1)  # [B, 3, 1]


    B,_,_=translation.shape
    rot = vec[:,3:]
    if rotation_mode == 'euler':
        rot_mat = euler2mat(rot)  # [B, 3, 3]
    elif rotation_mode == 'quat':
        rot_mat = quat2mat(rot)  # [B, 3, 3]
    one_vector = torch.tensor([0.0,0.0,0.0,1.0]).repeat(B,1).unsqueeze(1).cuda()
    #print(one_vector.shape)
    transform_mat = torch.cat([rot_mat, translation], dim=2)  # [B, 3, 4]
    #print(transform_mat.shape)
    transform_mat = torch.cat([transform_mat, one_vector], dim=1)
    return transform_mat

def inverse_warp(ac_next, ele,mask, pose, rotation_mode='euler', padding_mode='zeros'):
    """
    Inverse warp a source image to the target image plane.
    Args:
        img: the source image (where to sample pixels) -- [B, 3, H, W]
        depth: depth map of the target image -- [B, H, W]
        pose: 6DoF pose parameters from target to source -- [B, 6]
        intrinsics: camera intrinsic matrix -- [B, 3, 3]
    Returns:
        projected_img: Source image warped to the target image plane
        valid_points: Boolean array indicating point validity
    """


    batch_size, _, img_height, img_width = ac_next.size()

    cam_coords,valid = ele2pc(ele,mask)  # [B,3,H,W]

    
    pose_mat = pose_vec2mat(pose, rotation_mode)  # [B,3,4]
    pose_mater = pose_mat#pose_mat[:,0:3,:]
   
    # Get projection matrix for tgt camera frame to source pixel frame
    proj_cam_to_src_pixel =  pose_mater  # [B, 3, 4]

    rot, tr = proj_cam_to_src_pixel[:,:,:3], proj_cam_to_src_pixel[:,:,-1:]
    #print(tr)
    src_pixel_coords = pc2pixel(cam_coords, rot, tr)  # [B,H,W,2]
    projected_img = F.grid_sample(ac_next, src_pixel_coords, padding_mode=padding_mode)#, align_corners=True

    valid_points = src_pixel_coords.abs().max(dim=-1)[0] <= 1

    return projected_img, valid_points

# %% [markdown]
# ## Normal

# %%
import numpy as np
import time
import torch.nn.functional as F

# we also estimate normal map here. Not written in the paper. Smoothness loss on normal map can improve the performance

def compute_3dpts(ele,mask):
    scale=624/256
    angle=18.0

    ele = ele*mask
    ele = ele*angle-angle/2
        
    
    #print(ele.shape)
    aa = (ele<9)
    bb = (ele>-9)
    valid = (aa&bb)
  
    
    ele=ele/180.0*PI
    #global pixel_coords
    c,e,a = ele.size()
    #valid = valid.reshape(b,-1)
    
    
    i_range = torch.arange(0, e).view(1, e, 1).expand(1,e,a).type_as(ele)*(0.00299*scale)+0.971+400*(0.00299)  # 48.55 optical camera aperture
    i_range = i_range
    j_range = torch.arange(0, a).view(1, 1, a).expand(1,e,a).type_as(ele)/128*(30.0)-(30.0/2)  #-32
    j_range = j_range/180.0*PI
    ones = torch.ones(e,a).type_as(ele)
    
    #print(i_range.shape)
    

    
    pixel_coords = torch.stack((j_range, i_range, ones), dim=0)
    
    
    current_pixel_coords = pixel_coords[:,:e,:a].expand(3,e,a)
    
    ones_exp = torch.ones(e,a).type_as(ele)

    ele_exp = torch.stack((ones_exp, ones_exp, ele.squeeze()), dim=0)
    
    current_pixel_coords= ele_exp*current_pixel_coords
    
    #print(current_pixel_coords.shape)
   
    #print(current_pixel_coords[:,2,:,:]/PI*180)
    
    x = current_pixel_coords[1,:,:]*torch.cos(current_pixel_coords[0,:,:])*torch.cos(current_pixel_coords[2,:,:])
    y = current_pixel_coords[1,:,:]*torch.sin(current_pixel_coords[0,:,:])*torch.cos(current_pixel_coords[2,:,:])
    z = current_pixel_coords[1,:,:]*torch.sin(current_pixel_coords[2,:,:])
    
   
    pc = torch.stack((x, y, z), dim=0)
    
    pc = pc.permute(1,2,0)
    
    return pc,valid

def compute_3dpts_batch(ele,mask):
    
    ## pts is the depth map of rank3 [batch, h, w], intrinsics is in [batch, 4]
    scale=624/256
    angle=18.0

    ele = ele*mask
    ele = ele*angle-angle/2
        
    
    #print(ele.shape)
    aa = (ele<7)
    bb = (ele>-7)
    valid = (aa&bb)
  
    
    ele=ele/180.0*PI
    #global pixel_coords
    b,c,e,a = ele.size()
    valid = valid.reshape(b,-1)
    
    
    i_range = torch.arange(0, e).view(1, e, 1).expand(1,e,a).type_as(ele)*(scale*0.00299)+400*(0.00299)+0.971  # 48.55 optical camera aperture
    i_range = i_range
    j_range = torch.arange(0, a).view(1, 1, a).expand(1,e,a).type_as(ele)/128*(30.0)-(30.0/2)  #-32
    j_range = j_range/180.0*PI
    ones = torch.ones(1,e,a).type_as(ele)
    
    #print(i_range.shape)
    

    
    pixel_coords = torch.stack((j_range, i_range, ones), dim=1)
    
    
    current_pixel_coords = pixel_coords[:,:,:e,:a].expand(b,3,e,a)
    
    ones_exp = torch.ones(b,e,a).type_as(ele)

    ele_exp = torch.stack((ones_exp, ones_exp, ele.squeeze(1)), dim=1)
    
    current_pixel_coords= ele_exp*current_pixel_coords
    
    #print(current_pixel_coords.shape)
   
    #print(current_pixel_coords[:,2,:,:]/PI*180)
    
    x = current_pixel_coords[:,1,:,:]*torch.cos(current_pixel_coords[:,0,:,:])*torch.cos(current_pixel_coords[:,2,:,:])
    y = current_pixel_coords[:,1,:,:]*torch.sin(current_pixel_coords[:,0,:,:])*torch.cos(current_pixel_coords[:,2,:,:])
    z = current_pixel_coords[:,1,:,:]*torch.sin(current_pixel_coords[:,2,:,:])
    
   
    pc = torch.stack((x, y, z), dim=1)
    
    pc = pc.permute(0,2,3,1)
    
    return pc,valid

def normalize_l2(vector):
    return F.normalize(vector, dim=1, p=2)

def incidence_angle_batch(pc,normal):
    b,h,w,c = normal.size()
    l = pc[:,:,:,0]*normal[:,:,:,0]+pc[:,:,:,1]*normal[:,:,:,1]+pc[:,:,:,2]*normal[:,:,:,2]
    #l_a = torch.sqrt(pc[:,:,:,0]*pc[:,:,:,0]+pc[:,:,:,1]*pc[:,:,:,1]+pc[:,:,:,2]*pc[:,:,:,2])+1e-6
    #l_b = torch.sqrt(normal[:,:,:,0]*normal[:,:,:,0]+normal[:,:,:,1]*normal[:,:,:,1]+normal[:,:,:,2]*normal[:,:,:,2])+1e-6
    
    cosine_incidence = l
    return cosine_incidence

def depth2normal_layer(ele, mask):

    ## mask is used to filter the background with infinite depth
   
    ele_shape = ele.size()
    pts_3d_map,valid = compute_3dpts(ele, mask)
    print ("shape of pts_3d_map:")
    print (pts_3d_map.size())
    
    nei = 3

    ## shift the 3d pts map by nei along 8 directions
    pts_3d_map_ctr = pts_3d_map[nei:-nei, nei:-nei, :]
    pts_3d_map_x0 = pts_3d_map[nei:-nei, 0:-(2*nei), :]
    pts_3d_map_y0 = pts_3d_map[0:-(2*nei), nei:-nei, :]
    pts_3d_map_x1 = pts_3d_map[nei:-nei, 2*nei:, :]
    pts_3d_map_y1 = pts_3d_map[2*nei:, nei:-nei, :]
    pts_3d_map_x0y0 = pts_3d_map[0:-(2*nei), 0:-(2*nei), :]
    pts_3d_map_x0y1 = pts_3d_map[2*nei:, 0:-(2*nei), :]
    pts_3d_map_x1y0 = pts_3d_map[0:-(2*nei), 2*nei:, :]
    pts_3d_map_x1y1 = pts_3d_map[2*nei:, 2*nei:, :]

    ## generate difference between the central pixel and one of 8 neighboring pixels
    diff_x0 = pts_3d_map_ctr - pts_3d_map_x0
    diff_x1 = pts_3d_map_ctr - pts_3d_map_x1
    diff_y0 = pts_3d_map_y0 - pts_3d_map_ctr
    diff_y1 = pts_3d_map_y1 - pts_3d_map_ctr
    diff_x0y0 = pts_3d_map_x0y0 - pts_3d_map_ctr
    diff_x0y1 = pts_3d_map_ctr - pts_3d_map_x0y1
    diff_x1y0 = pts_3d_map_x1y0 - pts_3d_map_ctr
    diff_x1y1 = pts_3d_map_ctr - pts_3d_map_x1y1

    ## flatten the diff to a #pixle by 3 matrix
    pix_num = (ele_shape[1]-2*nei) * (ele_shape[2]-2*nei)
    diff_x0 = diff_x0.view(pix_num, 3)
    diff_y0 = diff_y0.view(pix_num, 3)
    diff_x1 = diff_x1.view(pix_num, 3)
    diff_y1 = diff_y1.view(pix_num, 3)
    diff_x0y0 = diff_x0y0.view(pix_num, 3)
    diff_x0y1 = diff_x0y1.view(pix_num, 3)
    diff_x1y0 = diff_x1y0.view(pix_num, 3)
    diff_x1y1 = diff_x1y1.view(pix_num, 3)

    ## calculate normal by cross product of two vectors
    normals0 = normalize_l2(torch.cross(diff_x1, diff_y1))
    normals1 = normalize_l2(torch.cross(diff_x0, diff_y0))
    normals2 = normalize_l2(torch.cross(diff_x0y1, diff_x0y0))
    normals3 = normalize_l2(torch.cross(diff_x1y0, diff_x1y1))
    normals = torch.stack([normals0, normals1, normals2, normals3], 0)
    
    print(normals.size())
    
    normal_vector = torch.sum(normals,dim=0)
                              
    print(normal_vector.size())                          
                              
    normal_vector = normalize_l2(normal_vector)
    normal_map = normal_vector.view(ele_shape[1]-2*nei,ele_shape[2]-2*nei,3)
    print (normal_map.size())
    mask=mask.squeeze()
    normal_map *= mask[nei:-nei, nei:-nei].squeeze(0).unsqueeze(2).repeat(1,1,3)
    print(normal_map.size())
    #normal_map = normal_map.unsqueeze(0)
    pad = (0,0,nei, nei, nei, nei)
    normal_map = F.pad(normal_map, pad ,"constant")
    print(normal_map.shape)

    return normal_map

def depth2normal_layer_batch(ele, mask, nei=5):

    ## depth_map is in rank 3 [batch, h, w], intrinsics are in rank 2 [batch,4]
    ## mask is used to filter the background with infinite depth
    #print(ele.size)

    ele_shape = ele.shape
    pts_3d_map,valid = compute_3dpts_batch(ele, mask)
    #print ("shape of pts_3d_map:")
    #print (pts_3d_map.size())
    

    ## shift the 3d pts map by nei along 8 directions
    pts_3d_map_ctr = pts_3d_map[:,nei:-nei, nei:-nei, :]
    pts_3d_map_x0 = pts_3d_map[:,nei:-nei, 0:-(2*nei), :]
    pts_3d_map_y0 = pts_3d_map[:,0:-(2*nei), nei:-nei, :]
    pts_3d_map_x1 = pts_3d_map[:,nei:-nei, 2*nei:, :]
    pts_3d_map_y1 = pts_3d_map[:,2*nei:, nei:-nei, :]
    pts_3d_map_x0y0 = pts_3d_map[:,0:-(2*nei), 0:-(2*nei), :]
    pts_3d_map_x0y1 = pts_3d_map[:,2*nei:, 0:-(2*nei), :]
    pts_3d_map_x1y0 = pts_3d_map[:,0:-(2*nei), 2*nei:, :]
    pts_3d_map_x1y1 = pts_3d_map[:,2*nei:, 2*nei:, :]

    ## generate difference between the central pixel and one of 8 neighboring pixels
    diff_x0 = pts_3d_map_ctr - pts_3d_map_x0
    diff_x1 = pts_3d_map_ctr - pts_3d_map_x1
    diff_y0 = pts_3d_map_y0 - pts_3d_map_ctr
    diff_y1 = pts_3d_map_y1 - pts_3d_map_ctr
    diff_x0y0 = pts_3d_map_x0y0 - pts_3d_map_ctr
    diff_x0y1 = pts_3d_map_ctr - pts_3d_map_x0y1
    diff_x1y0 = pts_3d_map_x1y0 - pts_3d_map_ctr
    diff_x1y1 = pts_3d_map_ctr - pts_3d_map_x1y1

    ## flatten the diff to a #pixle by 3 matrix
    pix_num = ele_shape[0]*(ele_shape[2]-2*nei) * (ele_shape[3]-2*nei)
    diff_x0 = diff_x0.reshape(pix_num, 3)
    diff_y0 = diff_y0.reshape(pix_num, 3)
    diff_x1 = diff_x1.reshape(pix_num, 3)
    diff_y1 = diff_y1.reshape(pix_num, 3)
    diff_x0y0 = diff_x0y0.reshape(pix_num, 3)
    diff_x0y1 = diff_x0y1.reshape(pix_num, 3)
    diff_x1y0 = diff_x1y0.reshape(pix_num, 3)
    diff_x1y1 = diff_x1y1.reshape(pix_num, 3)

    ## calculate normal by cross product of two vectors
    normals0 = normalize_l2(torch.cross(diff_x1, diff_y1))
    normals1 = normalize_l2(torch.cross(diff_x0, diff_y0))
    normals2 = normalize_l2(torch.cross(diff_x0y1, diff_x0y0))
    normals3 = normalize_l2(torch.cross(diff_x1y0, diff_x1y1))
    normals = torch.stack([normals0, normals1, normals2, normals3], 0)
    
    normal_vector = torch.sum(normals,dim=0)
    normal_vector = normalize_l2(normals0)
    normal_map = normal_vector.reshape(ele_shape[0],ele_shape[2]-2*nei,ele_shape[3]-2*nei,3)
    
    normal_map *= mask[:,:,nei:-nei, nei:-nei].squeeze().unsqueeze(3).repeat(1,1,1,3)
    pad = (0,0,nei, nei, nei, nei,0,0)
    normal_map = F.pad(normal_map, pad ,"constant")

    return normal_map

# %% [markdown]
# ## smooth

# %%
L1_loss = nn.L1Loss()

# %%
def smooth_loss(pred_map):
    def gradient(pred):
        D_dy = pred[:, :, 1:] - pred[:, :, :-1]
        D_dx = pred[:, :, :, 1:] - pred[:, :, :, :-1]
        return D_dx, D_dy

    loss = 0
    weight = 1.

    dx, dy = gradient(pred_map)
    dx2, dxdy = gradient(dx)
    dydx, dy2 = gradient(dy)
    loss += (dx2.abs().mean() + dxdy.abs().mean() + dydx.abs().mean() + dy2.abs().mean())
       
    return loss

# %%
def get_smooth_loss(disp, img):
    """Computes the smoothness loss for a disparity image
    The color image is used for edge-aware smoothness
    """
    grad_disp_x = torch.abs(disp[:, :, :, :-1] - disp[:, :, :, 1:])
    grad_disp_y = torch.abs(disp[:, :, :-1, :] - disp[:, :, 1:, :])

    grad_img_x = torch.mean(torch.abs(img[:, :, :, :-1] - img[:, :, :, 1:]), 1, keepdim=True)
    grad_img_y = torch.mean(torch.abs(img[:, :, :-1, :] - img[:, :, 1:, :]), 1, keepdim=True)

    grad_disp_x *= torch.exp(-grad_img_x)
    grad_disp_y *= torch.exp(-grad_img_y)

    return grad_disp_x.mean() + grad_disp_y.mean()

# %%
def monotonic_decrease_loss(disp,img):
    grad_disp_y = -disp[:, :, :-1, :] + disp[:, :, 1:, :] 
    grad_img_y = torch.mean(torch.abs(img[:, :, :-1, :] - img[:, :, 1:, :]), 1, keepdim=True)
    grad_disp_y *= torch.exp(-grad_img_y)

    return torch.relu(grad_disp_y).abs().mean()

# %%
def ia_decrease_loss(disp,img):
    grad_disp_y = -disp[:, :, 100:200, :] + disp[:, :, 300:400, :] 
    

    return torch.relu(grad_disp_y).mean()

# %%
class SSIM(nn.Module):
    """Layer to compute the SSIM loss between a pair of images
    """
    def __init__(self):
        super(SSIM, self).__init__()
        self.mu_x_pool   = nn.AvgPool2d(3, 1)
        self.mu_y_pool   = nn.AvgPool2d(3, 1)
        self.sig_x_pool  = nn.AvgPool2d(3, 1)
        self.sig_y_pool  = nn.AvgPool2d(3, 1)
        self.sig_xy_pool = nn.AvgPool2d(3, 1)

        self.refl = nn.ReflectionPad2d(1)

        self.C1 = 0.01 ** 2
        self.C2 = 0.03 ** 2

    def forward(self, x, y):
        x = self.refl(x)
        y = self.refl(y)

        mu_x = self.mu_x_pool(x)
        mu_y = self.mu_y_pool(y)

        sigma_x  = self.sig_x_pool(x ** 2) - mu_x ** 2
        sigma_y  = self.sig_y_pool(y ** 2) - mu_y ** 2
        sigma_xy = self.sig_xy_pool(x * y) - mu_x * mu_y

        SSIM_n = (2 * mu_x * mu_y + self.C1) * (2 * sigma_xy + self.C2)
        SSIM_d = (mu_x ** 2 + mu_y ** 2 + self.C1) * (sigma_x + sigma_y + self.C2)

        return torch.clamp((1 - SSIM_n / SSIM_d) / 2, 0, 1)

# %% [markdown]
# ## model

# %%
model = UNet()
model = model.cuda()

# %%
from torch import optim
from torch.optim import lr_scheduler
opt = optim.Adam(model.parameters(),lr=3e-4) #5e-4
#scheduler = lr_scheduler.StepLR(opt,step_size=50,gamma=0.5)
scheduler = lr_scheduler.CosineAnnealingLR(opt,T_max=12,eta_min=1e-5)  #max was 100

# %%
import random
import numpy as np
import torch

# %%
seed=47
random.seed(seed)
# Numpy
np.random.seed(seed)
# Pytorch
torch.manual_seed(seed)
torch.cuda.manual_seed(seed)

# %% [markdown]
# # Train

# %%
import os

best_score=1e5
for epoch in range(30):
    running_loss = 0.
    count =0
    test_loss =0.
    model.train()
    for i, data in enumerate(train_dl):
        
        ac, ele_gt, mask, ac_previous, ele_previous_gt, mask_previous, ac_next, ele_next_gt, mask_next, motion1, motion2, front  = data
        ac, ele_gt, mask, ac_previous, ele_previous_gt, mask_previous, ac_next, ele_next_gt, mask_next, motion1, motion2 = ac.cuda(), ele_gt.cuda(), mask.cuda(), ac_previous.cuda(), ele_previous_gt.cuda(), mask_previous.cuda(), ac_next.cuda(), ele_next_gt.cuda(), mask_next.cuda(), motion1.cuda(), motion2.cuda()
        opt.zero_grad()
        ac = ac*mask
        ele = model(ac)
        norm=depth2normal_layer_batch(ele,mask)
        #norm=torch.sqrt(norm[:,:,:,0]*norm[:,:,:,0]+norm[:,:,:,1]*norm[:,:,:,1]+norm[:,:,:,2]*norm[:,:,:,2])
        norm1=norm[:,:,:,2]
        norm1=norm1.unsqueeze(1)
        norm1=norm1*mask
        
        norm2=norm[:,:,:,0]
        norm2=norm2.unsqueeze(1)
        norm2=norm2*mask
        
        batch_size,c,h,w = ac.size()
        #print(motion2.shape)
        ac_next = ac_next*mask_next
        ac_previous = ac_previous*mask_previous
        #cosine_incidence_current = incidence_angle_batch(pc,norm)
        #cosine_incidence_current = cosine_incidence_current.unsqueeze(1)
        #cosine_incidence_current = F.relu(-cosine_incidence_current)
        
        #ci_loss = torch.mean(cosine_incidence_current)
        
        warp1,valid1 = inverse_warp(ac_next,ele,mask,motion2)
        warp_mask1,valid_mask1 = inverse_warp(mask_next,ele,mask,motion2)
        warp2,valid2 = inverse_warp(ac_previous,ele,mask,motion1)
        warp_mask2,valid_mask2 = inverse_warp(mask_previous,ele,mask,motion1)
       
        diff1 = (warp1 -ac) * valid1.unsqueeze(1).float()*mask#*warp_mask1
        diff2 = (warp2 -ac) * valid2.unsqueeze(1).float()*mask#*warp_mask2
        ssim = SSIM()
        img1 = warp1 * valid1.unsqueeze(1).float()*mask#*warp_mask1
        img2 = ac * valid1.unsqueeze(1).float()*mask#*warp_mask2
        
        img3 = warp2 * valid2.unsqueeze(1).float()*mask#*warp_mask1
        img4 = ac * valid2.unsqueeze(1).float()*mask#*warp_mask2
        
        loss_ssim = ssim(img1,img2).mean()+ssim(img3,img4).mean()
        
        loss_rec = diff1.abs().mean()+diff2.abs().mean()
        loss_smooth =  get_smooth_loss(ele*mask, ac*mask)
        
        loss_smooth2 =  get_smooth_loss(norm1[:,:,5:-5,5:-5], ac[:,:,5:-5,5:-5])
        loss_smooth3 =  get_smooth_loss(norm2[:,:,5:-5,5:-5], ac[:,:,5:-5,5:-5])
        #loss_ia = ia_decrease_loss(ele,ac)
        
        loss = 2*loss_rec*0.3+2*loss_ssim*0.7+0.1*loss_smooth+0.1*loss_smooth2+0.1*loss_smooth3#0.1*loss_smooth2+0.1*loss_smooth3+0.1*ci_loss   #+loss_mask loss_smooth*0.1+  loss_ia #+0.1*loss_smooth
        #loss = loss_rec+0.2*loss_smooth
        
        loss.backward()
        
        
        diff_metric = (ele-ele_gt) * mask
        metric = diff_metric.abs().mean()
        test_loss = metric.item()+ test_loss
        running_loss = loss.item()+running_loss
        count = count + 1
        opt.step()
        if i%4==0:
            print('Training: [%d, %5d] loss: %.4f loss smooth: %.4f' %(epoch + 1, (i+1)*batch_size, loss.item(),loss_smooth.item()))
            print('Metric: %.4f ' %(metric.item()))
    if (epoch)%1 ==0:
        model_dir = './sim_4obj_ele_data/checkpoints/sim_2023_11_14/'
    
        # Create the directory if it does not exist
        os.makedirs(model_dir, exist_ok=True)

        model_path = './sim_4obj_ele_data/checkpoints/sim_2023_11_14/'+str(epoch)+'.pth'
        torch.save(model.state_dict(), model_path)
    print('Epoch: %d Average Train loss: %.4f' %(epoch + 1,running_loss/count))
    print('Epoch: %d Average Train metrics: %.4f' %(epoch + 1,test_loss/count))
    print('=======================================')
    print('=======================================')  
    with torch.no_grad():
        model.eval()
        test_loss = 0
        counts=0
        for i,data in enumerate(test_dl):
            ac, ele_gt, mask, ac_previous, ele_previous_gt, mask_previous, ac_next, ele_next_gt, mask_next, motion1, motion2, front = data
            ac, ele_gt, mask, ac_previous, ele_previous_gt, mask_previous, ac_next, ele_next_gt, mask_next, motion1, motion2 = ac.cuda(), ele_gt.cuda(), mask.cuda(), ac_previous.cuda(), ele_previous_gt.cuda(), mask_previous.cuda(), ac_next.cuda(), ele_next_gt.cuda(), mask_next.cuda(), motion1.cuda(), motion2.cuda()
            ac = ac*mask
            ele = model(ac)
            ele = ele*mask
            diff_metric = ele-ele_gt*mask
            
            metric = diff_metric.abs().mean()
            test_loss = test_loss + metric.item()
            counts = counts+1
        print('Epoch: %d Average Test loss: %.4f' %(epoch + 1,test_loss/counts))
        if best_score>(test_loss/counts):
            best_score=test_loss/counts
        print('Best score: %.4f' %(best_score))
# Out:
# /home/philipp/.local/lib/python3.10/site-packages/torch/nn/functional.py:4296: UserWarning: Default grid_sample and affine_grid behavior has changed to align_corners=False since 1.3.0. Please specify align_corners=True if the old behavior is desired. See the documentation of grid_sample for details.
#   warnings.warn(
# Training: [1,     4] loss: 0.1522 loss smooth: 0.0344
# Metric: 0.1114
# Training: [1,    20] loss: 0.1200 loss smooth: 0.0187
# Metric: 0.0850
# Training: [1,    36] loss: 0.1016 loss smooth: 0.0154
# Metric: 0.0741
# Training: [1,    52] loss: 0.1033 loss smooth: 0.0128
# Metric: 0.0808
# Training: [1,    68] loss: 0.0872 loss smooth: 0.0104
# Metric: 0.0774
# Training: [1,    84] loss: 0.0790 loss smooth: 0.0112
# Metric: 0.0703
# Training: [1,   100] loss: 0.0721 loss smooth: 0.0113
# Metric: 0.0803
# Training: [1,   116] loss: 0.0946 loss smooth: 0.0144
# Metric: 0.0689
# Training: [1,   132] loss: 0.0950 loss smooth: 0.0159
# Metric: 0.0651
# Training: [1,   148] loss: 0.0806 loss smooth: 0.0110
# Metric: 0.0723
# Training: [1,   164] loss: 0.0995 loss smooth: 0.0118
# Metric: 0.0742
# Training: [1,   180] loss: 0.0931 loss smooth: 0.0115
# Metric: 0.0591
# Training: [1,   196] loss: 0.0890 loss smooth: 0.0122
# Metric: 0.0668
# Training: [1,   212] loss: 0.0862 loss smooth: 0.0108
# Metric: 0.0644
# Training: [1,   228] loss: 0.0897 loss smooth: 0.0123
# Metric: 0.0539
# Training: [1,   244] loss: 0.0845 loss smooth: 0.0119
# Metric: 0.0599
# Training: [1,   260] loss: 0.0957 loss smooth: 0.0120
# Metric: 0.0885
# Training: [1,   276] loss: 0.0862 loss smooth: 0.0112
# Metric: 0.0781
# Training: [1,   292] loss: 0.0782 loss smooth: 0.0118
# Metric: 0.0532
# Training: [1,   308] loss: 0.0777 loss smooth: 0.0109
# Metric: 0.0520
# Training: [1,   324] loss: 0.0757 loss smooth: 0.0116
# Metric: 0.0574
# Training: [1,   340] loss: 0.0880 loss smooth: 0.0124
# Metric: 0.0601
# Training: [1,   356] loss: 0.0892 loss smooth: 0.0121
# Metric: 0.0585
# Training: [1,   372] loss: 0.0846 loss smooth: 0.0103
# Metric: 0.0578
# Training: [1,   388] loss: 0.0755 loss smooth: 0.0102
# Metric: 0.0560
# Training: [1,   404] loss: 0.0798 loss smooth: 0.0118
# Metric: 0.0529
# Training: [1,   420] loss: 0.0736 loss smooth: 0.0122
# Metric: 0.0546
# Training: [1,   436] loss: 0.0850 loss smooth: 0.0131
# Metric: 0.0520
# Training: [1,   452] loss: 0.0945 loss smooth: 0.0124
# Metric: 0.0606
# Training: [1,   468] loss: 0.0767 loss smooth: 0.0133
# Metric: 0.0502
# Training: [1,   484] loss: 0.0997 loss smooth: 0.0146
# Metric: 0.0671
# Training: [1,   500] loss: 0.0737 loss smooth: 0.0122
# Metric: 0.0503
# Training: [1,   516] loss: 0.0834 loss smooth: 0.0130
# Metric: 0.0574
# Training: [1,   532] loss: 0.0795 loss smooth: 0.0100
# Metric: 0.0606
# Training: [1,   548] loss: 0.0823 loss smooth: 0.0115
# Metric: 0.0508
# Training: [1,   564] loss: 0.0912 loss smooth: 0.0131
# Metric: 0.0473
# Training: [1,   580] loss: 0.1096 loss smooth: 0.0158
# Metric: 0.0738
# Training: [1,   596] loss: 0.0845 loss smooth: 0.0136
# Metric: 0.0500
# Training: [1,   612] loss: 0.0850 loss smooth: 0.0142
# Metric: 0.0508
# Training: [1,   628] loss: 0.0788 loss smooth: 0.0139
# Metric: 0.0582
# Training: [1,   644] loss: 0.0657 loss smooth: 0.0141
# Metric: 0.0413
# Training: [1,   660] loss: 0.0845 loss smooth: 0.0135
# Metric: 0.0511
# Training: [1,   676] loss: 0.0747 loss smooth: 0.0123
# Metric: 0.0545
# Training: [1,   692] loss: 0.0824 loss smooth: 0.0115
# Metric: 0.0576
# Training: [1,   708] loss: 0.0796 loss smooth: 0.0144
# Metric: 0.0546
# Training: [1,   724] loss: 0.0804 loss smooth: 0.0122
# Metric: 0.0561
# Training: [1,   740] loss: 0.0863 loss smooth: 0.0125
# Metric: 0.0589
# Training: [1,   756] loss: 0.0799 loss smooth: 0.0143
# Metric: 0.0491
# Training: [1,   772] loss: 0.1032 loss smooth: 0.0150
# Metric: 0.0472
# Training: [1,   788] loss: 0.0815 loss smooth: 0.0110
# Metric: 0.0479
# Training: [1,   804] loss: 0.0801 loss smooth: 0.0136
# Metric: 0.0558
# Training: [1,   820] loss: 0.0651 loss smooth: 0.0132
# Metric: 0.0501
# Training: [1,   836] loss: 0.0686 loss smooth: 0.0121
# Metric: 0.0552
# Training: [1,   852] loss: 0.0886 loss smooth: 0.0114
# Metric: 0.0513
# Training: [1,   868] loss: 0.0685 loss smooth: 0.0129
# Metric: 0.0406
# Training: [1,   884] loss: 0.0760 loss smooth: 0.0124
# Metric: 0.0501
# Training: [1,   900] loss: 0.0717 loss smooth: 0.0133
# Metric: 0.0485
# Training: [1,   916] loss: 0.0755 loss smooth: 0.0127
# Metric: 0.0580
# Training: [1,   932] loss: 0.0733 loss smooth: 0.0133
# Metric: 0.0470
# Training: [1,   948] loss: 0.0866 loss smooth: 0.0122
# Metric: 0.0412
# Training: [1,   964] loss: 0.1035 loss smooth: 0.0165
# Metric: 0.0480
# Training: [1,   980] loss: 0.0825 loss smooth: 0.0143
# Metric: 0.0430
# Training: [1,   996] loss: 0.0780 loss smooth: 0.0121
# Metric: 0.0511
# Training: [1,  1012] loss: 0.0669 loss smooth: 0.0125
# Metric: 0.0508
# Training: [1,  1028] loss: 0.0633 loss smooth: 0.0116
# Metric: 0.0461
# Training: [1,  1044] loss: 0.0919 loss smooth: 0.0163
# Metric: 0.0432
# Training: [1,  1060] loss: 0.0775 loss smooth: 0.0150
# Metric: 0.0472
# Training: [1,  1076] loss: 0.0827 loss smooth: 0.0131
# Metric: 0.0411
# Training: [1,  1092] loss: 0.0812 loss smooth: 0.0138
# Metric: 0.0421
# Training: [1,  1108] loss: 0.0824 loss smooth: 0.0135
# Metric: 0.0488
# Training: [1,  1124] loss: 0.0737 loss smooth: 0.0142
# Metric: 0.0506
# Training: [1,  1140] loss: 0.0741 loss smooth: 0.0132
# Metric: 0.0476
# Training: [1,  1156] loss: 0.0782 loss smooth: 0.0148
# Metric: 0.0431
# Training: [1,  1172] loss: 0.0736 loss smooth: 0.0134
# Metric: 0.0464
# Training: [1,  1188] loss: 0.0732 loss smooth: 0.0127
# Metric: 0.0497
# Training: [1,  1204] loss: 0.0811 loss smooth: 0.0142
# Metric: 0.0494
# Training: [1,  1220] loss: 0.0733 loss smooth: 0.0144
# Metric: 0.0479
# Training: [1,   618] loss: 0.0843 loss smooth: 0.0120
# Metric: 0.0499
# Epoch: 1 Average Train loss: 0.0843
# Epoch: 1 Average Train metrics: 0.0573
# =======================================
# =======================================
# Epoch: 1 Average Test loss: 0.0514
# Best score: 0.0514
# Training: [2,     4] loss: 0.0781 loss smooth: 0.0132
# Metric: 0.0466
# Training: [2,    20] loss: 0.0902 loss smooth: 0.0127
# Metric: 0.0447
# Training: [2,    36] loss: 0.0752 loss smooth: 0.0115
# Metric: 0.0447
# Training: [2,    52] loss: 0.0703 loss smooth: 0.0137
# Metric: 0.0508
# Training: [2,    68] loss: 0.0814 loss smooth: 0.0141
# Metric: 0.0449
# Training: [2,    84] loss: 0.0798 loss smooth: 0.0118
# Metric: 0.0555
# Training: [2,   100] loss: 0.0656 loss smooth: 0.0135
# Metric: 0.0561
# Training: [2,   116] loss: 0.0772 loss smooth: 0.0109
# Metric: 0.0481
# Training: [2,   132] loss: 0.0827 loss smooth: 0.0143
# Metric: 0.0537
# Training: [2,   148] loss: 0.0785 loss smooth: 0.0121
# Metric: 0.0625
# Training: [2,   164] loss: 0.0735 loss smooth: 0.0148
# Metric: 0.0470
# Training: [2,   180] loss: 0.0985 loss smooth: 0.0149
# Metric: 0.0563
# Training: [2,   196] loss: 0.0673 loss smooth: 0.0134
# Metric: 0.0432
# Training: [2,   212] loss: 0.0751 loss smooth: 0.0132
# Metric: 0.0547
# Training: [2,   228] loss: 0.0744 loss smooth: 0.0122
# Metric: 0.0544
# Training: [2,   244] loss: 0.0666 loss smooth: 0.0123
# Metric: 0.0543
# Training: [2,   260] loss: 0.0761 loss smooth: 0.0144
# Metric: 0.0482
# Training: [2,   276] loss: 0.0773 loss smooth: 0.0120
# Metric: 0.0531
# Training: [2,   292] loss: 0.0647 loss smooth: 0.0134
# Metric: 0.0480
# Training: [2,   308] loss: 0.0714 loss smooth: 0.0114
# Metric: 0.0555
# Training: [2,   324] loss: 0.0726 loss smooth: 0.0125
# Metric: 0.0519
# Training: [2,   340] loss: 0.0792 loss smooth: 0.0120
# Metric: 0.0554
# Training: [2,   356] loss: 0.0815 loss smooth: 0.0122
# Metric: 0.0588
# Training: [2,   372] loss: 0.0715 loss smooth: 0.0135
# Metric: 0.0476
# Training: [2,   388] loss: 0.0815 loss smooth: 0.0149
# Metric: 0.0511
# Training: [2,   404] loss: 0.0759 loss smooth: 0.0138
# Metric: 0.0473
# Training: [2,   420] loss: 0.0676 loss smooth: 0.0119
# Metric: 0.0444
# Training: [2,   436] loss: 0.0726 loss smooth: 0.0114
# Metric: 0.0540
# Training: [2,   452] loss: 0.0841 loss smooth: 0.0140
# Metric: 0.0390
# Training: [2,   468] loss: 0.0846 loss smooth: 0.0131
# Metric: 0.0475
# Training: [2,   484] loss: 0.0780 loss smooth: 0.0123
# Metric: 0.0496
# Training: [2,   500] loss: 0.0669 loss smooth: 0.0116
# Metric: 0.0414
# Training: [2,   516] loss: 0.0739 loss smooth: 0.0132
# Metric: 0.0490
# Training: [2,   532] loss: 0.0746 loss smooth: 0.0132
# Metric: 0.0489
# Training: [2,   548] loss: 0.0630 loss smooth: 0.0129
# Metric: 0.0438
# Training: [2,   564] loss: 0.0766 loss smooth: 0.0139
# Metric: 0.0525
# Training: [2,   580] loss: 0.0803 loss smooth: 0.0127
# Metric: 0.0461
# Training: [2,   596] loss: 0.0785 loss smooth: 0.0114
# Metric: 0.0478
# Training: [2,   612] loss: 0.0865 loss smooth: 0.0138
# Metric: 0.0593
# Training: [2,   628] loss: 0.0775 loss smooth: 0.0141
# Metric: 0.0499
# Training: [2,   644] loss: 0.0626 loss smooth: 0.0121
# Metric: 0.0514
# Training: [2,   660] loss: 0.0628 loss smooth: 0.0136
# Metric: 0.0502
# Training: [2,   676] loss: 0.0901 loss smooth: 0.0160
# Metric: 0.0528
# Training: [2,   692] loss: 0.0717 loss smooth: 0.0138
# Metric: 0.0411
# Training: [2,   708] loss: 0.0768 loss smooth: 0.0128
# Metric: 0.0554
# Training: [2,   724] loss: 0.0722 loss smooth: 0.0143
# Metric: 0.0496
# Training: [2,   740] loss: 0.0773 loss smooth: 0.0115
# Metric: 0.0538
# Training: [2,   756] loss: 0.0651 loss smooth: 0.0111
# Metric: 0.0477
# Training: [2,   772] loss: 0.0759 loss smooth: 0.0136
# Metric: 0.0458
# Training: [2,   788] loss: 0.0832 loss smooth: 0.0141
# Metric: 0.0530
# Training: [2,   804] loss: 0.0826 loss smooth: 0.0137
# Metric: 0.0509
# Training: [2,   820] loss: 0.0722 loss smooth: 0.0130
# Metric: 0.0504
# Training: [2,   836] loss: 0.0755 loss smooth: 0.0137
# Metric: 0.0521
# Training: [2,   852] loss: 0.0826 loss smooth: 0.0127
# Metric: 0.0562
# Training: [2,   868] loss: 0.0652 loss smooth: 0.0127
# Metric: 0.0474
# Training: [2,   884] loss: 0.0664 loss smooth: 0.0123
# Metric: 0.0509
# Training: [2,   900] loss: 0.0702 loss smooth: 0.0147
# Metric: 0.0551
# Training: [2,   916] loss: 0.0805 loss smooth: 0.0125
# Metric: 0.0490
# Training: [2,   932] loss: 0.0762 loss smooth: 0.0114
# Metric: 0.0504
# Training: [2,   948] loss: 0.0672 loss smooth: 0.0146
# Metric: 0.0454
# Training: [2,   964] loss: 0.0743 loss smooth: 0.0139
# Metric: 0.0474
# Training: [2,   980] loss: 0.0772 loss smooth: 0.0134
# Metric: 0.0520
# Training: [2,   996] loss: 0.0871 loss smooth: 0.0141
# Metric: 0.0528
# Training: [2,  1012] loss: 0.0759 loss smooth: 0.0115
# Metric: 0.0479
# Training: [2,  1028] loss: 0.0733 loss smooth: 0.0120
# Metric: 0.0482
# Training: [2,  1044] loss: 0.0792 loss smooth: 0.0109
# Metric: 0.0432
# Training: [2,  1060] loss: 0.0677 loss smooth: 0.0135
# Metric: 0.0452
# Training: [2,  1076] loss: 0.0781 loss smooth: 0.0137
# Metric: 0.0472
# Training: [2,  1092] loss: 0.0763 loss smooth: 0.0119
# Metric: 0.0544
# Training: [2,  1108] loss: 0.0633 loss smooth: 0.0104
# Metric: 0.0497
# Training: [2,  1124] loss: 0.0900 loss smooth: 0.0133
# Metric: 0.0541
# Training: [2,  1140] loss: 0.0783 loss smooth: 0.0129
# Metric: 0.0476
# Training: [2,  1156] loss: 0.0707 loss smooth: 0.0118
# Metric: 0.0550
# Training: [2,  1172] loss: 0.0626 loss smooth: 0.0118
# Metric: 0.0534
# Training: [2,  1188] loss: 0.0924 loss smooth: 0.0164
# Metric: 0.0445
# Training: [2,  1204] loss: 0.0654 loss smooth: 0.0131
# Metric: 0.0507
# Training: [2,  1220] loss: 0.0874 loss smooth: 0.0156
# Metric: 0.0508
# Training: [2,   618] loss: 0.0835 loss smooth: 0.0137
# Metric: 0.0569
# Epoch: 2 Average Train loss: 0.0764
# Epoch: 2 Average Train metrics: 0.0500
# =======================================
# =======================================
# Epoch: 2 Average Test loss: 0.0543
# Best score: 0.0514
# Training: [3,     4] loss: 0.0655 loss smooth: 0.0126
# Metric: 0.0525
# Training: [3,    20] loss: 0.0800 loss smooth: 0.0112
# Metric: 0.0487
# Training: [3,    36] loss: 0.0847 loss smooth: 0.0140
# Metric: 0.0467
# Training: [3,    52] loss: 0.0813 loss smooth: 0.0133
# Metric: 0.0495
# Training: [3,    68] loss: 0.0786 loss smooth: 0.0116
# Metric: 0.0507
# Training: [3,    84] loss: 0.0817 loss smooth: 0.0114
# Metric: 0.0527
# Training: [3,   100] loss: 0.0777 loss smooth: 0.0141
# Metric: 0.0459
# Training: [3,   116] loss: 0.0763 loss smooth: 0.0118
# Metric: 0.0492
# Training: [3,   132] loss: 0.0786 loss smooth: 0.0120
# Metric: 0.0492
# Training: [3,   148] loss: 0.0806 loss smooth: 0.0134
# Metric: 0.0538
# Training: [3,   164] loss: 0.0758 loss smooth: 0.0130
# Metric: 0.0538
# Training: [3,   180] loss: 0.0609 loss smooth: 0.0111
# Metric: 0.0634
# Training: [3,   196] loss: 0.0694 loss smooth: 0.0120
# Metric: 0.0572
# Training: [3,   212] loss: 0.0665 loss smooth: 0.0109
# Metric: 0.0541
# Training: [3,   228] loss: 0.0837 loss smooth: 0.0151
# Metric: 0.0511
# Training: [3,   244] loss: 0.0699 loss smooth: 0.0126
# Metric: 0.0517
# Training: [3,   260] loss: 0.0723 loss smooth: 0.0113
# Metric: 0.0597
# Training: [3,   276] loss: 0.0659 loss smooth: 0.0120
# Metric: 0.0532
# Training: [3,   292] loss: 0.0990 loss smooth: 0.0129
# Metric: 0.0541
# Training: [3,   308] loss: 0.0667 loss smooth: 0.0130
# Metric: 0.0468
# Training: [3,   324] loss: 0.0705 loss smooth: 0.0135
# Metric: 0.0491
# Training: [3,   340] loss: 0.0741 loss smooth: 0.0111
# Metric: 0.0542
# Training: [3,   356] loss: 0.0651 loss smooth: 0.0128
# Metric: 0.0450
# Training: [3,   372] loss: 0.0790 loss smooth: 0.0134
# Metric: 0.0516
# Training: [3,   388] loss: 0.0916 loss smooth: 0.0122
# Metric: 0.0493
# Training: [3,   404] loss: 0.0717 loss smooth: 0.0108
# Metric: 0.0423
# Training: [3,   420] loss: 0.0871 loss smooth: 0.0137
# Metric: 0.0539
# Training: [3,   436] loss: 0.0677 loss smooth: 0.0139
# Metric: 0.0555
# Training: [3,   452] loss: 0.0534 loss smooth: 0.0113
# Metric: 0.0495
# Training: [3,   468] loss: 0.0883 loss smooth: 0.0160
# Metric: 0.0514
# Training: [3,   484] loss: 0.0763 loss smooth: 0.0115
# Metric: 0.0486
# Training: [3,   500] loss: 0.0764 loss smooth: 0.0139
# Metric: 0.0538
# Training: [3,   516] loss: 0.0671 loss smooth: 0.0114
# Metric: 0.0487
# Training: [3,   532] loss: 0.0741 loss smooth: 0.0114
# Metric: 0.0532
# Training: [3,   548] loss: 0.0768 loss smooth: 0.0144
# Metric: 0.0502
# Training: [3,   564] loss: 0.0681 loss smooth: 0.0112
# Metric: 0.0538
# Training: [3,   580] loss: 0.0863 loss smooth: 0.0135
# Metric: 0.0504
# Training: [3,   596] loss: 0.0774 loss smooth: 0.0138
# Metric: 0.0413
# Training: [3,   612] loss: 0.0745 loss smooth: 0.0131
# Metric: 0.0476
# Training: [3,   628] loss: 0.0818 loss smooth: 0.0145
# Metric: 0.0512
# Training: [3,   644] loss: 0.0699 loss smooth: 0.0117
# Metric: 0.0499
# Training: [3,   660] loss: 0.0676 loss smooth: 0.0140
# Metric: 0.0566
# Training: [3,   676] loss: 0.0691 loss smooth: 0.0111
# Metric: 0.0531
# Training: [3,   692] loss: 0.0741 loss smooth: 0.0133
# Metric: 0.0468
# Training: [3,   708] loss: 0.0728 loss smooth: 0.0128
# Metric: 0.0495
# Training: [3,   724] loss: 0.0611 loss smooth: 0.0118
# Metric: 0.0443
# Training: [3,   740] loss: 0.0829 loss smooth: 0.0124
# Metric: 0.0478
# Training: [3,   756] loss: 0.0733 loss smooth: 0.0134
# Metric: 0.0467
# Training: [3,   772] loss: 0.0907 loss smooth: 0.0166
# Metric: 0.0512
# Training: [3,   788] loss: 0.0699 loss smooth: 0.0108
# Metric: 0.0512
# Training: [3,   804] loss: 0.0720 loss smooth: 0.0112
# Metric: 0.0496
# Training: [3,   820] loss: 0.0775 loss smooth: 0.0113
# Metric: 0.0505
# Training: [3,   836] loss: 0.0829 loss smooth: 0.0144
# Metric: 0.0547
# Training: [3,   852] loss: 0.0730 loss smooth: 0.0151
# Metric: 0.0452
# Training: [3,   868] loss: 0.0809 loss smooth: 0.0128
# Metric: 0.0527
# Training: [3,   884] loss: 0.0721 loss smooth: 0.0117
# Metric: 0.0507
# Training: [3,   900] loss: 0.0740 loss smooth: 0.0143
# Metric: 0.0503
# Training: [3,   916] loss: 0.0825 loss smooth: 0.0139
# Metric: 0.0509
# Training: [3,   932] loss: 0.0793 loss smooth: 0.0124
# Metric: 0.0529
# Training: [3,   948] loss: 0.0847 loss smooth: 0.0118
# Metric: 0.0510
# Training: [3,   964] loss: 0.0753 loss smooth: 0.0132
# Metric: 0.0535
# Training: [3,   980] loss: 0.0743 loss smooth: 0.0116
# Metric: 0.0540
# Training: [3,   996] loss: 0.0706 loss smooth: 0.0111
# Metric: 0.0540
# Training: [3,  1012] loss: 0.0717 loss smooth: 0.0130
# Metric: 0.0529
# Training: [3,  1028] loss: 0.0810 loss smooth: 0.0145
# Metric: 0.0530
# Training: [3,  1044] loss: 0.0894 loss smooth: 0.0141
# Metric: 0.0531
# Training: [3,  1060] loss: 0.0672 loss smooth: 0.0129
# Metric: 0.0458
# Training: [3,  1076] loss: 0.0798 loss smooth: 0.0122
# Metric: 0.0477
# Training: [3,  1092] loss: 0.0658 loss smooth: 0.0143
# Metric: 0.0491
# Training: [3,  1108] loss: 0.0768 loss smooth: 0.0145
# Metric: 0.0482
# Training: [3,  1124] loss: 0.0724 loss smooth: 0.0147
# Metric: 0.0503
# Training: [3,  1140] loss: 0.0804 loss smooth: 0.0122
# Metric: 0.0499
# Training: [3,  1156] loss: 0.0792 loss smooth: 0.0113
# Metric: 0.0483
# Training: [3,  1172] loss: 0.0658 loss smooth: 0.0117
# Metric: 0.0510
# Training: [3,  1188] loss: 0.0849 loss smooth: 0.0133
# Metric: 0.0510
# Training: [3,  1204] loss: 0.0747 loss smooth: 0.0137
# Metric: 0.0545
# Training: [3,  1220] loss: 0.0765 loss smooth: 0.0160
# Metric: 0.0463
# Training: [3,   618] loss: 0.0714 loss smooth: 0.0155
# Metric: 0.0497
# Epoch: 3 Average Train loss: 0.0740
# Epoch: 3 Average Train metrics: 0.0503
# =======================================
# =======================================
# Epoch: 3 Average Test loss: 0.0486
# Best score: 0.0486
# Training: [4,     4] loss: 0.0760 loss smooth: 0.0135
# Metric: 0.0499
# Training: [4,    20] loss: 0.0754 loss smooth: 0.0123
# Metric: 0.0511
# Training: [4,    36] loss: 0.0776 loss smooth: 0.0131
# Metric: 0.0506
# Training: [4,    52] loss: 0.0748 loss smooth: 0.0131
# Metric: 0.0554
# Training: [4,    68] loss: 0.0683 loss smooth: 0.0124
# Metric: 0.0524
# Training: [4,    84] loss: 0.0772 loss smooth: 0.0155
# Metric: 0.0504
# Training: [4,   100] loss: 0.0703 loss smooth: 0.0137
# Metric: 0.0428
# Training: [4,   116] loss: 0.0660 loss smooth: 0.0134
# Metric: 0.0455
# Training: [4,   132] loss: 0.0908 loss smooth: 0.0144
# Metric: 0.0519
# Training: [4,   148] loss: 0.0557 loss smooth: 0.0119
# Metric: 0.0541
# Training: [4,   164] loss: 0.0814 loss smooth: 0.0132
# Metric: 0.0531
# Training: [4,   180] loss: 0.0835 loss smooth: 0.0133
# Metric: 0.0510
# Training: [4,   196] loss: 0.0760 loss smooth: 0.0129
# Metric: 0.0581
# Training: [4,   212] loss: 0.0726 loss smooth: 0.0121
# Metric: 0.0502
# Training: [4,   228] loss: 0.0793 loss smooth: 0.0140
# Metric: 0.0574
# Training: [4,   244] loss: 0.0825 loss smooth: 0.0120
# Metric: 0.0420
# Training: [4,   260] loss: 0.0589 loss smooth: 0.0118
# Metric: 0.0438
# Training: [4,   276] loss: 0.0902 loss smooth: 0.0110
# Metric: 0.0504
# Training: [4,   292] loss: 0.0737 loss smooth: 0.0140
# Metric: 0.0497
# Training: [4,   308] loss: 0.0752 loss smooth: 0.0131
# Metric: 0.0546
# Training: [4,   324] loss: 0.0777 loss smooth: 0.0129
# Metric: 0.0491
# Training: [4,   340] loss: 0.0743 loss smooth: 0.0116
# Metric: 0.0556
# Training: [4,   356] loss: 0.0586 loss smooth: 0.0109
# Metric: 0.0563
# Training: [4,   372] loss: 0.0725 loss smooth: 0.0116
# Metric: 0.0506
# Training: [4,   388] loss: 0.0655 loss smooth: 0.0122
# Metric: 0.0521
# Training: [4,   404] loss: 0.0694 loss smooth: 0.0120
# Metric: 0.0504
# Training: [4,   420] loss: 0.0814 loss smooth: 0.0130
# Metric: 0.0466
# Training: [4,   436] loss: 0.0627 loss smooth: 0.0115
# Metric: 0.0467
# Training: [4,   452] loss: 0.0726 loss smooth: 0.0139
# Metric: 0.0506
# Training: [4,   468] loss: 0.0654 loss smooth: 0.0123
# Metric: 0.0537
# Training: [4,   484] loss: 0.0601 loss smooth: 0.0127
# Metric: 0.0579
# Training: [4,   500] loss: 0.0805 loss smooth: 0.0141
# Metric: 0.0543
# Training: [4,   516] loss: 0.0661 loss smooth: 0.0138
# Metric: 0.0526
# Training: [4,   532] loss: 0.0780 loss smooth: 0.0153
# Metric: 0.0434
# Training: [4,   548] loss: 0.0728 loss smooth: 0.0147
# Metric: 0.0462
# Training: [4,   564] loss: 0.0768 loss smooth: 0.0130
# Metric: 0.0580
# Training: [4,   580] loss: 0.0898 loss smooth: 0.0132
# Metric: 0.0460
# Training: [4,   596] loss: 0.0779 loss smooth: 0.0137
# Metric: 0.0432
# Training: [4,   612] loss: 0.0574 loss smooth: 0.0136
# Metric: 0.0489
# Training: [4,   628] loss: 0.0905 loss smooth: 0.0133
# Metric: 0.0491
# Training: [4,   644] loss: 0.0729 loss smooth: 0.0147
# Metric: 0.0506
# Training: [4,   660] loss: 0.0664 loss smooth: 0.0114
# Metric: 0.0524
# Training: [4,   676] loss: 0.0685 loss smooth: 0.0143
# Metric: 0.0482
# Training: [4,   692] loss: 0.0781 loss smooth: 0.0137
# Metric: 0.0496
# Training: [4,   708] loss: 0.0855 loss smooth: 0.0143
# Metric: 0.0482
# Training: [4,   724] loss: 0.0732 loss smooth: 0.0137
# Metric: 0.0546
# Training: [4,   740] loss: 0.0703 loss smooth: 0.0145
# Metric: 0.0465
# Training: [4,   756] loss: 0.0567 loss smooth: 0.0127
# Metric: 0.0441
# Training: [4,   772] loss: 0.0883 loss smooth: 0.0119
# Metric: 0.0493
# Training: [4,   788] loss: 0.0750 loss smooth: 0.0124
# Metric: 0.0468
# Training: [4,   804] loss: 0.0744 loss smooth: 0.0121
# Metric: 0.0465
# Training: [4,   820] loss: 0.0694 loss smooth: 0.0129
# Metric: 0.0522
# Training: [4,   836] loss: 0.0670 loss smooth: 0.0129
# Metric: 0.0548
# Training: [4,   852] loss: 0.0748 loss smooth: 0.0120
# Metric: 0.0510
# Training: [4,   868] loss: 0.0729 loss smooth: 0.0137
# Metric: 0.0504
# Training: [4,   884] loss: 0.0665 loss smooth: 0.0121
# Metric: 0.0491
# Training: [4,   900] loss: 0.0722 loss smooth: 0.0148
# Metric: 0.0489
# Training: [4,   916] loss: 0.0716 loss smooth: 0.0129
# Metric: 0.0564
# Training: [4,   932] loss: 0.0686 loss smooth: 0.0134
# Metric: 0.0495
# Training: [4,   948] loss: 0.0618 loss smooth: 0.0137
# Metric: 0.0553
# Training: [4,   964] loss: 0.0541 loss smooth: 0.0130
# Metric: 0.0471
# Training: [4,   980] loss: 0.0536 loss smooth: 0.0113
# Metric: 0.0492
# Training: [4,   996] loss: 0.0751 loss smooth: 0.0143
# Metric: 0.0497
# Training: [4,  1012] loss: 0.0707 loss smooth: 0.0113
# Metric: 0.0558
# Training: [4,  1028] loss: 0.0646 loss smooth: 0.0118
# Metric: 0.0497
# Training: [4,  1044] loss: 0.0804 loss smooth: 0.0136
# Metric: 0.0473
# Training: [4,  1060] loss: 0.0770 loss smooth: 0.0123
# Metric: 0.0517
# Training: [4,  1076] loss: 0.0751 loss smooth: 0.0115
# Metric: 0.0483
# Training: [4,  1092] loss: 0.0716 loss smooth: 0.0129
# Metric: 0.0530
# Training: [4,  1108] loss: 0.0640 loss smooth: 0.0106
# Metric: 0.0543
# Training: [4,  1124] loss: 0.0688 loss smooth: 0.0136
# Metric: 0.0516
# Training: [4,  1140] loss: 0.0710 loss smooth: 0.0151
# Metric: 0.0547
# Training: [4,  1156] loss: 0.0701 loss smooth: 0.0124
# Metric: 0.0472
# Training: [4,  1172] loss: 0.0754 loss smooth: 0.0130
# Metric: 0.0566
# Training: [4,  1188] loss: 0.0661 loss smooth: 0.0121
# Metric: 0.0567
# Training: [4,  1204] loss: 0.0702 loss smooth: 0.0129
# Metric: 0.0492
# Training: [4,  1220] loss: 0.0731 loss smooth: 0.0139
# Metric: 0.0511
# Training: [4,   618] loss: 0.0645 loss smooth: 0.0142
# Metric: 0.0479
# Epoch: 4 Average Train loss: 0.0726
# Epoch: 4 Average Train metrics: 0.0505
# =======================================
# =======================================
# Epoch: 4 Average Test loss: 0.0492
# Best score: 0.0486
# Training: [5,     4] loss: 0.0801 loss smooth: 0.0123
# Metric: 0.0485
# Training: [5,    20] loss: 0.0703 loss smooth: 0.0138
# Metric: 0.0539
# Training: [5,    36] loss: 0.0859 loss smooth: 0.0156
# Metric: 0.0511
# Training: [5,    52] loss: 0.0792 loss smooth: 0.0127
# Metric: 0.0508
# Training: [5,    68] loss: 0.0671 loss smooth: 0.0129
# Metric: 0.0561
# Training: [5,    84] loss: 0.0589 loss smooth: 0.0127
# Metric: 0.0516
# Training: [5,   100] loss: 0.0794 loss smooth: 0.0144
# Metric: 0.0486
# Training: [5,   116] loss: 0.0773 loss smooth: 0.0121
# Metric: 0.0419
# Training: [5,   132] loss: 0.0674 loss smooth: 0.0121
# Metric: 0.0523
# Training: [5,   148] loss: 0.0717 loss smooth: 0.0135
# Metric: 0.0512
# Training: [5,   164] loss: 0.0723 loss smooth: 0.0138
# Metric: 0.0551
# Training: [5,   180] loss: 0.0704 loss smooth: 0.0115
# Metric: 0.0446
# Training: [5,   196] loss: 0.0888 loss smooth: 0.0150
# Metric: 0.0461
# Training: [5,   212] loss: 0.0652 loss smooth: 0.0131
# Metric: 0.0573
# Training: [5,   228] loss: 0.0890 loss smooth: 0.0168
# Metric: 0.0528
# Training: [5,   244] loss: 0.0789 loss smooth: 0.0137
# Metric: 0.0471
# Training: [5,   260] loss: 0.0759 loss smooth: 0.0128
# Metric: 0.0493
# Training: [5,   276] loss: 0.0763 loss smooth: 0.0151
# Metric: 0.0487
# Training: [5,   292] loss: 0.0704 loss smooth: 0.0152
# Metric: 0.0486
# Training: [5,   308] loss: 0.0778 loss smooth: 0.0126
# Metric: 0.0485
# Training: [5,   324] loss: 0.0635 loss smooth: 0.0127
# Metric: 0.0536
# Training: [5,   340] loss: 0.0645 loss smooth: 0.0142
# Metric: 0.0505
# Training: [5,   356] loss: 0.0685 loss smooth: 0.0145
# Metric: 0.0532
# Training: [5,   372] loss: 0.0772 loss smooth: 0.0134
# Metric: 0.0514
# Training: [5,   388] loss: 0.0711 loss smooth: 0.0122
# Metric: 0.0546
# Training: [5,   404] loss: 0.0758 loss smooth: 0.0143
# Metric: 0.0494
# Training: [5,   420] loss: 0.0733 loss smooth: 0.0148
# Metric: 0.0466
# Training: [5,   436] loss: 0.0704 loss smooth: 0.0121
# Metric: 0.0546
# Training: [5,   452] loss: 0.0687 loss smooth: 0.0134
# Metric: 0.0550
# Training: [5,   468] loss: 0.0584 loss smooth: 0.0117
# Metric: 0.0511
# Training: [5,   484] loss: 0.0865 loss smooth: 0.0132
# Metric: 0.0583
# Training: [5,   500] loss: 0.0672 loss smooth: 0.0117
# Metric: 0.0504
# Training: [5,   516] loss: 0.0729 loss smooth: 0.0118
# Metric: 0.0464
# Training: [5,   532] loss: 0.0698 loss smooth: 0.0126
# Metric: 0.0575
# Training: [5,   548] loss: 0.0820 loss smooth: 0.0154
# Metric: 0.0518
# Training: [5,   564] loss: 0.0529 loss smooth: 0.0121
# Metric: 0.0503
# Training: [5,   580] loss: 0.0593 loss smooth: 0.0117
# Metric: 0.0569
# Training: [5,   596] loss: 0.0815 loss smooth: 0.0139
# Metric: 0.0569
# Training: [5,   612] loss: 0.0669 loss smooth: 0.0144
# Metric: 0.0521
# Training: [5,   628] loss: 0.0589 loss smooth: 0.0108
# Metric: 0.0472
# Training: [5,   644] loss: 0.0777 loss smooth: 0.0117
# Metric: 0.0489
# Training: [5,   660] loss: 0.0594 loss smooth: 0.0147
# Metric: 0.0467
# Training: [5,   676] loss: 0.0892 loss smooth: 0.0149
# Metric: 0.0570
# Training: [5,   692] loss: 0.0682 loss smooth: 0.0127
# Metric: 0.0547
# Training: [5,   708] loss: 0.0667 loss smooth: 0.0125
# Metric: 0.0478
# Training: [5,   724] loss: 0.0718 loss smooth: 0.0117
# Metric: 0.0480
# Training: [5,   740] loss: 0.0758 loss smooth: 0.0109
# Metric: 0.0427
# Training: [5,   756] loss: 0.0767 loss smooth: 0.0127
# Metric: 0.0514
# Training: [5,   772] loss: 0.0614 loss smooth: 0.0109
# Metric: 0.0498
# Training: [5,   788] loss: 0.0677 loss smooth: 0.0128
# Metric: 0.0471
# Training: [5,   804] loss: 0.0866 loss smooth: 0.0134
# Metric: 0.0481
# Training: [5,   820] loss: 0.0624 loss smooth: 0.0132
# Metric: 0.0538
# Training: [5,   836] loss: 0.0748 loss smooth: 0.0131
# Metric: 0.0488
# Training: [5,   852] loss: 0.0568 loss smooth: 0.0106
# Metric: 0.0563
# Training: [5,   868] loss: 0.0827 loss smooth: 0.0151
# Metric: 0.0503
# Training: [5,   884] loss: 0.0552 loss smooth: 0.0113
# Metric: 0.0532
# Training: [5,   900] loss: 0.0805 loss smooth: 0.0148
# Metric: 0.0518
# Training: [5,   916] loss: 0.0595 loss smooth: 0.0135
# Metric: 0.0526
# Training: [5,   932] loss: 0.0832 loss smooth: 0.0148
# Metric: 0.0480
# Training: [5,   948] loss: 0.0608 loss smooth: 0.0134
# Metric: 0.0483
# Training: [5,   964] loss: 0.0893 loss smooth: 0.0126
# Metric: 0.0461
# Training: [5,   980] loss: 0.0757 loss smooth: 0.0136
# Metric: 0.0510
# Training: [5,   996] loss: 0.0730 loss smooth: 0.0139
# Metric: 0.0544
# Training: [5,  1012] loss: 0.0792 loss smooth: 0.0126
# Metric: 0.0546
# Training: [5,  1028] loss: 0.0903 loss smooth: 0.0133
# Metric: 0.0538
# Training: [5,  1044] loss: 0.0723 loss smooth: 0.0124
# Metric: 0.0499
# Training: [5,  1060] loss: 0.0942 loss smooth: 0.0132
# Metric: 0.0493
# Training: [5,  1076] loss: 0.0686 loss smooth: 0.0112
# Metric: 0.0482
# Training: [5,  1092] loss: 0.0790 loss smooth: 0.0154
# Metric: 0.0502
# Training: [5,  1108] loss: 0.0752 loss smooth: 0.0138
# Metric: 0.0564
# Training: [5,  1124] loss: 0.0704 loss smooth: 0.0138
# Metric: 0.0563
# Training: [5,  1140] loss: 0.0701 loss smooth: 0.0147
# Metric: 0.0512
# Training: [5,  1156] loss: 0.0808 loss smooth: 0.0159
# Metric: 0.0529
# Training: [5,  1172] loss: 0.0764 loss smooth: 0.0127
# Metric: 0.0479
# Training: [5,  1188] loss: 0.0879 loss smooth: 0.0136
# Metric: 0.0567
# Training: [5,  1204] loss: 0.0797 loss smooth: 0.0146
# Metric: 0.0478
# Training: [5,  1220] loss: 0.0676 loss smooth: 0.0136
# Metric: 0.0589
# Training: [5,   618] loss: 0.0582 loss smooth: 0.0104
# Metric: 0.0560
# Epoch: 5 Average Train loss: 0.0717
# Epoch: 5 Average Train metrics: 0.0508
# =======================================
# =======================================
# Epoch: 5 Average Test loss: 0.0510
# Best score: 0.0486
# Training: [6,     4] loss: 0.0550 loss smooth: 0.0137
# Metric: 0.0501
# Training: [6,    20] loss: 0.0629 loss smooth: 0.0123
# Metric: 0.0552
# Training: [6,    36] loss: 0.0660 loss smooth: 0.0128
# Metric: 0.0557
# Training: [6,    52] loss: 0.0822 loss smooth: 0.0116
# Metric: 0.0529
# Training: [6,    68] loss: 0.0659 loss smooth: 0.0147
# Metric: 0.0489
# Training: [6,    84] loss: 0.0834 loss smooth: 0.0116
# Metric: 0.0555
# Training: [6,   100] loss: 0.0585 loss smooth: 0.0126
# Metric: 0.0548
# Training: [6,   116] loss: 0.0789 loss smooth: 0.0135
# Metric: 0.0528
# Training: [6,   132] loss: 0.0693 loss smooth: 0.0102
# Metric: 0.0527
# Training: [6,   148] loss: 0.0637 loss smooth: 0.0125
# Metric: 0.0441
# Training: [6,   164] loss: 0.0642 loss smooth: 0.0123
# Metric: 0.0450
# Training: [6,   180] loss: 0.0638 loss smooth: 0.0137
# Metric: 0.0498
# Training: [6,   196] loss: 0.0708 loss smooth: 0.0148
# Metric: 0.0539
# Training: [6,   212] loss: 0.0627 loss smooth: 0.0134
# Metric: 0.0508
# Training: [6,   228] loss: 0.0809 loss smooth: 0.0110
# Metric: 0.0550
# Training: [6,   244] loss: 0.0597 loss smooth: 0.0141
# Metric: 0.0453
# Training: [6,   260] loss: 0.0693 loss smooth: 0.0129
# Metric: 0.0469
# Training: [6,   276] loss: 0.0718 loss smooth: 0.0120
# Metric: 0.0498
# Training: [6,   292] loss: 0.0767 loss smooth: 0.0129
# Metric: 0.0494
# Training: [6,   308] loss: 0.0614 loss smooth: 0.0118
# Metric: 0.0546
# Training: [6,   324] loss: 0.0668 loss smooth: 0.0139
# Metric: 0.0503
# Training: [6,   340] loss: 0.0681 loss smooth: 0.0130
# Metric: 0.0475
# Training: [6,   356] loss: 0.0633 loss smooth: 0.0146
# Metric: 0.0415
# Training: [6,   372] loss: 0.0723 loss smooth: 0.0137
# Metric: 0.0466
# Training: [6,   388] loss: 0.0731 loss smooth: 0.0125
# Metric: 0.0467
# Training: [6,   404] loss: 0.0779 loss smooth: 0.0112
# Metric: 0.0560
# Training: [6,   420] loss: 0.0693 loss smooth: 0.0161
# Metric: 0.0535
# Training: [6,   436] loss: 0.0539 loss smooth: 0.0106
# Metric: 0.0580
# Training: [6,   452] loss: 0.0874 loss smooth: 0.0117
# Metric: 0.0560
# Training: [6,   468] loss: 0.0536 loss smooth: 0.0115
# Metric: 0.0528
# Training: [6,   484] loss: 0.0817 loss smooth: 0.0145
# Metric: 0.0470
# Training: [6,   500] loss: 0.0671 loss smooth: 0.0145
# Metric: 0.0477
# Training: [6,   516] loss: 0.0601 loss smooth: 0.0123
# Metric: 0.0470
# Training: [6,   532] loss: 0.0660 loss smooth: 0.0136
# Metric: 0.0513
# Training: [6,   548] loss: 0.0670 loss smooth: 0.0123
# Metric: 0.0504
# Training: [6,   564] loss: 0.0790 loss smooth: 0.0154
# Metric: 0.0436
# Training: [6,   580] loss: 0.0646 loss smooth: 0.0133
# Metric: 0.0516
# Training: [6,   596] loss: 0.0607 loss smooth: 0.0121
# Metric: 0.0475
# Training: [6,   612] loss: 0.0787 loss smooth: 0.0136
# Metric: 0.0464
# Training: [6,   628] loss: 0.0686 loss smooth: 0.0122
# Metric: 0.0541
# Training: [6,   644] loss: 0.0777 loss smooth: 0.0116
# Metric: 0.0489
# Training: [6,   660] loss: 0.0853 loss smooth: 0.0153
# Metric: 0.0489
# Training: [6,   676] loss: 0.0728 loss smooth: 0.0116
# Metric: 0.0549
# Training: [6,   692] loss: 0.0696 loss smooth: 0.0141
# Metric: 0.0530
# Training: [6,   708] loss: 0.0582 loss smooth: 0.0127
# Metric: 0.0467
# Training: [6,   724] loss: 0.0772 loss smooth: 0.0133
# Metric: 0.0486
# Training: [6,   740] loss: 0.0801 loss smooth: 0.0121
# Metric: 0.0501
# Training: [6,   756] loss: 0.0791 loss smooth: 0.0112
# Metric: 0.0505
# Training: [6,   772] loss: 0.0629 loss smooth: 0.0135
# Metric: 0.0508
# Training: [6,   788] loss: 0.0654 loss smooth: 0.0137
# Metric: 0.0462
# Training: [6,   804] loss: 0.0777 loss smooth: 0.0133
# Metric: 0.0546
# Training: [6,   820] loss: 0.0631 loss smooth: 0.0132
# Metric: 0.0500
# Training: [6,   836] loss: 0.0744 loss smooth: 0.0134
# Metric: 0.0479
# Training: [6,   852] loss: 0.0619 loss smooth: 0.0129
# Metric: 0.0572
# Training: [6,   868] loss: 0.0708 loss smooth: 0.0124
# Metric: 0.0489
# Training: [6,   884] loss: 0.0710 loss smooth: 0.0117
# Metric: 0.0490
# Training: [6,   900] loss: 0.0778 loss smooth: 0.0123
# Metric: 0.0581
# Training: [6,   916] loss: 0.0791 loss smooth: 0.0130
# Metric: 0.0499
# Training: [6,   932] loss: 0.0856 loss smooth: 0.0136
# Metric: 0.0488
# Training: [6,   948] loss: 0.0649 loss smooth: 0.0137
# Metric: 0.0521
# Training: [6,   964] loss: 0.0682 loss smooth: 0.0128
# Metric: 0.0523
# Training: [6,   980] loss: 0.0844 loss smooth: 0.0130
# Metric: 0.0534
# Training: [6,   996] loss: 0.0562 loss smooth: 0.0121
# Metric: 0.0519
# Training: [6,  1012] loss: 0.0682 loss smooth: 0.0117
# Metric: 0.0606
# Training: [6,  1028] loss: 0.0710 loss smooth: 0.0129
# Metric: 0.0541
# Training: [6,  1044] loss: 0.0902 loss smooth: 0.0133
# Metric: 0.0546
# Training: [6,  1060] loss: 0.0750 loss smooth: 0.0125
# Metric: 0.0554
# Training: [6,  1076] loss: 0.0689 loss smooth: 0.0142
# Metric: 0.0519
# Training: [6,  1092] loss: 0.0861 loss smooth: 0.0155
# Metric: 0.0478
# Training: [6,  1108] loss: 0.0743 loss smooth: 0.0143
# Metric: 0.0476
# Training: [6,  1124] loss: 0.0599 loss smooth: 0.0122
# Metric: 0.0479
# Training: [6,  1140] loss: 0.0656 loss smooth: 0.0121
# Metric: 0.0525
# Training: [6,  1156] loss: 0.0708 loss smooth: 0.0135
# Metric: 0.0575
# Training: [6,  1172] loss: 0.0750 loss smooth: 0.0161
# Metric: 0.0507
# Training: [6,  1188] loss: 0.0683 loss smooth: 0.0131
# Metric: 0.0496
# Training: [6,  1204] loss: 0.0780 loss smooth: 0.0141
# Metric: 0.0532
# Training: [6,  1220] loss: 0.0734 loss smooth: 0.0121
# Metric: 0.0525
# Training: [6,   618] loss: 0.0759 loss smooth: 0.0114
# Metric: 0.0467
# Epoch: 6 Average Train loss: 0.0711
# Epoch: 6 Average Train metrics: 0.0508
# =======================================
# =======================================
# Epoch: 6 Average Test loss: 0.0475
# Best score: 0.0475
# Training: [7,     4] loss: 0.0624 loss smooth: 0.0123
# Metric: 0.0528
# Training: [7,    20] loss: 0.0688 loss smooth: 0.0123
# Metric: 0.0557
# Training: [7,    36] loss: 0.0765 loss smooth: 0.0131
# Metric: 0.0529
# Training: [7,    52] loss: 0.0700 loss smooth: 0.0137
# Metric: 0.0486
# Training: [7,    68] loss: 0.0622 loss smooth: 0.0117
# Metric: 0.0549
# Training: [7,    84] loss: 0.0614 loss smooth: 0.0125
# Metric: 0.0522
# Training: [7,   100] loss: 0.0742 loss smooth: 0.0129
# Metric: 0.0589
# Training: [7,   116] loss: 0.0682 loss smooth: 0.0141
# Metric: 0.0509
# Training: [7,   132] loss: 0.0595 loss smooth: 0.0108
# Metric: 0.0570
# Training: [7,   148] loss: 0.0710 loss smooth: 0.0134
# Metric: 0.0556
# Training: [7,   164] loss: 0.0687 loss smooth: 0.0143
# Metric: 0.0521
# Training: [7,   180] loss: 0.0712 loss smooth: 0.0131
# Metric: 0.0548
# Training: [7,   196] loss: 0.0680 loss smooth: 0.0130
# Metric: 0.0508
# Training: [7,   212] loss: 0.0825 loss smooth: 0.0130
# Metric: 0.0505
# Training: [7,   228] loss: 0.0759 loss smooth: 0.0165
# Metric: 0.0455
# Training: [7,   244] loss: 0.0731 loss smooth: 0.0127
# Metric: 0.0592
# Training: [7,   260] loss: 0.0699 loss smooth: 0.0140
# Metric: 0.0535
# Training: [7,   276] loss: 0.0691 loss smooth: 0.0137
# Metric: 0.0521
# Training: [7,   292] loss: 0.0783 loss smooth: 0.0127
# Metric: 0.0529
# Training: [7,   308] loss: 0.0576 loss smooth: 0.0120
# Metric: 0.0459
# Training: [7,   324] loss: 0.0710 loss smooth: 0.0130
# Metric: 0.0419
# Training: [7,   340] loss: 0.0663 loss smooth: 0.0122
# Metric: 0.0461
# Training: [7,   356] loss: 0.0687 loss smooth: 0.0117
# Metric: 0.0507
# Training: [7,   372] loss: 0.0787 loss smooth: 0.0122
# Metric: 0.0510
# Training: [7,   388] loss: 0.0764 loss smooth: 0.0117
# Metric: 0.0538
# Training: [7,   404] loss: 0.0658 loss smooth: 0.0134
# Metric: 0.0466
# Training: [7,   420] loss: 0.0710 loss smooth: 0.0108
# Metric: 0.0552
# Training: [7,   436] loss: 0.0667 loss smooth: 0.0134
# Metric: 0.0585
# Training: [7,   452] loss: 0.0637 loss smooth: 0.0127
# Metric: 0.0480
# Training: [7,   468] loss: 0.0666 loss smooth: 0.0135
# Metric: 0.0501
# Training: [7,   484] loss: 0.0633 loss smooth: 0.0112
# Metric: 0.0575
# Training: [7,   500] loss: 0.0691 loss smooth: 0.0143
# Metric: 0.0461
# Training: [7,   516] loss: 0.0694 loss smooth: 0.0136
# Metric: 0.0546
# Training: [7,   532] loss: 0.0701 loss smooth: 0.0133
# Metric: 0.0513
# Training: [7,   548] loss: 0.0711 loss smooth: 0.0118
# Metric: 0.0615
# Training: [7,   564] loss: 0.0854 loss smooth: 0.0133
# Metric: 0.0470
# Training: [7,   580] loss: 0.0834 loss smooth: 0.0123
# Metric: 0.0467
# Training: [7,   596] loss: 0.0670 loss smooth: 0.0131
# Metric: 0.0476
# Training: [7,   612] loss: 0.0660 loss smooth: 0.0136
# Metric: 0.0515
# Training: [7,   628] loss: 0.0714 loss smooth: 0.0110
# Metric: 0.0568
# Training: [7,   644] loss: 0.0672 loss smooth: 0.0111
# Metric: 0.0467
# Training: [7,   660] loss: 0.0604 loss smooth: 0.0128
# Metric: 0.0528
# Training: [7,   676] loss: 0.0688 loss smooth: 0.0123
# Metric: 0.0515
# Training: [7,   692] loss: 0.0618 loss smooth: 0.0152
# Metric: 0.0478
# Training: [7,   708] loss: 0.0596 loss smooth: 0.0129
# Metric: 0.0463
# Training: [7,   724] loss: 0.0751 loss smooth: 0.0125
# Metric: 0.0463
# Training: [7,   740] loss: 0.0574 loss smooth: 0.0136
# Metric: 0.0480
# Training: [7,   756] loss: 0.0654 loss smooth: 0.0131
# Metric: 0.0510
# Training: [7,   772] loss: 0.0786 loss smooth: 0.0148
# Metric: 0.0437
# Training: [7,   788] loss: 0.0772 loss smooth: 0.0134
# Metric: 0.0489
# Training: [7,   804] loss: 0.0596 loss smooth: 0.0108
# Metric: 0.0563
# Training: [7,   820] loss: 0.0607 loss smooth: 0.0125
# Metric: 0.0494
# Training: [7,   836] loss: 0.0704 loss smooth: 0.0120
# Metric: 0.0511
# Training: [7,   852] loss: 0.0779 loss smooth: 0.0135
# Metric: 0.0516
# Training: [7,   868] loss: 0.0882 loss smooth: 0.0155
# Metric: 0.0509
# Training: [7,   884] loss: 0.0705 loss smooth: 0.0156
# Metric: 0.0466
# Training: [7,   900] loss: 0.0649 loss smooth: 0.0105
# Metric: 0.0446
# Training: [7,   916] loss: 0.0708 loss smooth: 0.0149
# Metric: 0.0510
# Training: [7,   932] loss: 0.0544 loss smooth: 0.0131
# Metric: 0.0538
# Training: [7,   948] loss: 0.0743 loss smooth: 0.0117
# Metric: 0.0495
# Training: [7,   964] loss: 0.0749 loss smooth: 0.0120
# Metric: 0.0485
# Training: [7,   980] loss: 0.0788 loss smooth: 0.0137
# Metric: 0.0497
# Training: [7,   996] loss: 0.0801 loss smooth: 0.0143
# Metric: 0.0483
# Training: [7,  1012] loss: 0.0730 loss smooth: 0.0109
# Metric: 0.0556
# Training: [7,  1028] loss: 0.0753 loss smooth: 0.0160
# Metric: 0.0521
# Training: [7,  1044] loss: 0.0563 loss smooth: 0.0136
# Metric: 0.0537
# Training: [7,  1060] loss: 0.0783 loss smooth: 0.0120
# Metric: 0.0465
# Training: [7,  1076] loss: 0.0735 loss smooth: 0.0140
# Metric: 0.0508
# Training: [7,  1092] loss: 0.0763 loss smooth: 0.0109
# Metric: 0.0395
# Training: [7,  1108] loss: 0.0719 loss smooth: 0.0127
# Metric: 0.0456
# Training: [7,  1124] loss: 0.0542 loss smooth: 0.0130
# Metric: 0.0457
# Training: [7,  1140] loss: 0.0827 loss smooth: 0.0125
# Metric: 0.0560
# Training: [7,  1156] loss: 0.0569 loss smooth: 0.0114
# Metric: 0.0572
# Training: [7,  1172] loss: 0.0737 loss smooth: 0.0143
# Metric: 0.0530
# Training: [7,  1188] loss: 0.0658 loss smooth: 0.0132
# Metric: 0.0549
# Training: [7,  1204] loss: 0.0686 loss smooth: 0.0135
# Metric: 0.0457
# Training: [7,  1220] loss: 0.0741 loss smooth: 0.0138
# Metric: 0.0488
# Training: [7,   618] loss: 0.0659 loss smooth: 0.0105
# Metric: 0.0524
# Epoch: 7 Average Train loss: 0.0708
# Epoch: 7 Average Train metrics: 0.0506
# =======================================
# =======================================
# Epoch: 7 Average Test loss: 0.0480
# Best score: 0.0475
# Training: [8,     4] loss: 0.0638 loss smooth: 0.0128
# Metric: 0.0494
# Training: [8,    20] loss: 0.0690 loss smooth: 0.0133
# Metric: 0.0499
# Training: [8,    36] loss: 0.0696 loss smooth: 0.0157
# Metric: 0.0419
# Training: [8,    52] loss: 0.0687 loss smooth: 0.0129
# Metric: 0.0440
# Training: [8,    68] loss: 0.0789 loss smooth: 0.0134
# Metric: 0.0493
# Training: [8,    84] loss: 0.0584 loss smooth: 0.0120
# Metric: 0.0549
# Training: [8,   100] loss: 0.0631 loss smooth: 0.0145
# Metric: 0.0522
# Training: [8,   116] loss: 0.0586 loss smooth: 0.0119
# Metric: 0.0561
# Training: [8,   132] loss: 0.0829 loss smooth: 0.0135
# Metric: 0.0490
# Training: [8,   148] loss: 0.0648 loss smooth: 0.0128
# Metric: 0.0509
# Training: [8,   164] loss: 0.0595 loss smooth: 0.0121
# Metric: 0.0512
# Training: [8,   180] loss: 0.0579 loss smooth: 0.0141
# Metric: 0.0504
# Training: [8,   196] loss: 0.0550 loss smooth: 0.0123
# Metric: 0.0488
# Training: [8,   212] loss: 0.0745 loss smooth: 0.0105
# Metric: 0.0524
# Training: [8,   228] loss: 0.0761 loss smooth: 0.0127
# Metric: 0.0507
# Training: [8,   244] loss: 0.0556 loss smooth: 0.0127
# Metric: 0.0479
# Training: [8,   260] loss: 0.0695 loss smooth: 0.0129
# Metric: 0.0525
# Training: [8,   276] loss: 0.0766 loss smooth: 0.0153
# Metric: 0.0502
# Training: [8,   292] loss: 0.0679 loss smooth: 0.0121
# Metric: 0.0454
# Training: [8,   308] loss: 0.0668 loss smooth: 0.0122
# Metric: 0.0498
# Training: [8,   324] loss: 0.0697 loss smooth: 0.0144
# Metric: 0.0462
# Training: [8,   340] loss: 0.0583 loss smooth: 0.0129
# Metric: 0.0535
# Training: [8,   356] loss: 0.0614 loss smooth: 0.0106
# Metric: 0.0531
# Training: [8,   372] loss: 0.0552 loss smooth: 0.0137
# Metric: 0.0466
# Training: [8,   388] loss: 0.0836 loss smooth: 0.0121
# Metric: 0.0512
# Training: [8,   404] loss: 0.0676 loss smooth: 0.0129
# Metric: 0.0531
# Training: [8,   420] loss: 0.0780 loss smooth: 0.0121
# Metric: 0.0516
# Training: [8,   436] loss: 0.0770 loss smooth: 0.0153
# Metric: 0.0477
# Training: [8,   452] loss: 0.0778 loss smooth: 0.0124
# Metric: 0.0504
# Training: [8,   468] loss: 0.0676 loss smooth: 0.0127
# Metric: 0.0505
# Training: [8,   484] loss: 0.0649 loss smooth: 0.0130
# Metric: 0.0440
# Training: [8,   500] loss: 0.0835 loss smooth: 0.0147
# Metric: 0.0450
# Training: [8,   516] loss: 0.0749 loss smooth: 0.0128
# Metric: 0.0502
# Training: [8,   532] loss: 0.0797 loss smooth: 0.0152
# Metric: 0.0533
# Training: [8,   548] loss: 0.0789 loss smooth: 0.0128
# Metric: 0.0406
# Training: [8,   564] loss: 0.0672 loss smooth: 0.0118
# Metric: 0.0479
# Training: [8,   580] loss: 0.0693 loss smooth: 0.0123
# Metric: 0.0523
# Training: [8,   596] loss: 0.0735 loss smooth: 0.0135
# Metric: 0.0515
# Training: [8,   612] loss: 0.0767 loss smooth: 0.0123
# Metric: 0.0479
# Training: [8,   628] loss: 0.0667 loss smooth: 0.0125
# Metric: 0.0566
# Training: [8,   644] loss: 0.0777 loss smooth: 0.0132
# Metric: 0.0473
# Training: [8,   660] loss: 0.0635 loss smooth: 0.0122
# Metric: 0.0549
# Training: [8,   676] loss: 0.0727 loss smooth: 0.0140
# Metric: 0.0456
# Training: [8,   692] loss: 0.0786 loss smooth: 0.0104
# Metric: 0.0527
# Training: [8,   708] loss: 0.0683 loss smooth: 0.0115
# Metric: 0.0516
# Training: [8,   724] loss: 0.0782 loss smooth: 0.0123
# Metric: 0.0516
# Training: [8,   740] loss: 0.0575 loss smooth: 0.0128
# Metric: 0.0540
# Training: [8,   756] loss: 0.0745 loss smooth: 0.0128
# Metric: 0.0510
# Training: [8,   772] loss: 0.0635 loss smooth: 0.0130
# Metric: 0.0533
# Training: [8,   788] loss: 0.0806 loss smooth: 0.0139
# Metric: 0.0495
# Training: [8,   804] loss: 0.0623 loss smooth: 0.0127
# Metric: 0.0521
# Training: [8,   820] loss: 0.0669 loss smooth: 0.0134
# Metric: 0.0534
# Training: [8,   836] loss: 0.0684 loss smooth: 0.0129
# Metric: 0.0508
# Training: [8,   852] loss: 0.0774 loss smooth: 0.0161
# Metric: 0.0446
# Training: [8,   868] loss: 0.0696 loss smooth: 0.0118
# Metric: 0.0549
# Training: [8,   884] loss: 0.0797 loss smooth: 0.0135
# Metric: 0.0558
# Training: [8,   900] loss: 0.0711 loss smooth: 0.0113
# Metric: 0.0535
# Training: [8,   916] loss: 0.0730 loss smooth: 0.0124
# Metric: 0.0546
# Training: [8,   932] loss: 0.0572 loss smooth: 0.0127
# Metric: 0.0468
# Training: [8,   948] loss: 0.0679 loss smooth: 0.0157
# Metric: 0.0525
# Training: [8,   964] loss: 0.0626 loss smooth: 0.0119
# Metric: 0.0562
# Training: [8,   980] loss: 0.0639 loss smooth: 0.0130
# Metric: 0.0486
# Training: [8,   996] loss: 0.0822 loss smooth: 0.0123
# Metric: 0.0496
# Training: [8,  1012] loss: 0.0740 loss smooth: 0.0124
# Metric: 0.0460
# Training: [8,  1028] loss: 0.0641 loss smooth: 0.0163
# Metric: 0.0473
# Training: [8,  1044] loss: 0.0615 loss smooth: 0.0116
# Metric: 0.0500
# Training: [8,  1060] loss: 0.0711 loss smooth: 0.0139
# Metric: 0.0541
# Training: [8,  1076] loss: 0.0667 loss smooth: 0.0122
# Metric: 0.0573
# Training: [8,  1092] loss: 0.0622 loss smooth: 0.0131
# Metric: 0.0551
# Training: [8,  1108] loss: 0.0755 loss smooth: 0.0128
# Metric: 0.0502
# Training: [8,  1124] loss: 0.0580 loss smooth: 0.0140
# Metric: 0.0451
# Training: [8,  1140] loss: 0.0707 loss smooth: 0.0108
# Metric: 0.0565
# Training: [8,  1156] loss: 0.0670 loss smooth: 0.0124
# Metric: 0.0481
# Training: [8,  1172] loss: 0.0675 loss smooth: 0.0113
# Metric: 0.0509
# Training: [8,  1188] loss: 0.0685 loss smooth: 0.0140
# Metric: 0.0476
# Training: [8,  1204] loss: 0.0765 loss smooth: 0.0123
# Metric: 0.0510
# Training: [8,  1220] loss: 0.0741 loss smooth: 0.0155
# Metric: 0.0497
# Training: [8,   618] loss: 0.0767 loss smooth: 0.0123
# Metric: 0.0517
# Epoch: 8 Average Train loss: 0.0701
# Epoch: 8 Average Train metrics: 0.0501
# =======================================
# =======================================
# Epoch: 8 Average Test loss: 0.0489
# Best score: 0.0475
# Training: [9,     4] loss: 0.0804 loss smooth: 0.0112
# Metric: 0.0472
# Training: [9,    20] loss: 0.0748 loss smooth: 0.0148
# Metric: 0.0479
# Training: [9,    36] loss: 0.0722 loss smooth: 0.0146
# Metric: 0.0483
# Training: [9,    52] loss: 0.0587 loss smooth: 0.0126
# Metric: 0.0554
# Training: [9,    68] loss: 0.0691 loss smooth: 0.0129
# Metric: 0.0545
# Training: [9,    84] loss: 0.0812 loss smooth: 0.0130
# Metric: 0.0458
# Training: [9,   100] loss: 0.0627 loss smooth: 0.0133
# Metric: 0.0588
# Training: [9,   116] loss: 0.0579 loss smooth: 0.0114
# Metric: 0.0499
# Training: [9,   132] loss: 0.0652 loss smooth: 0.0130
# Metric: 0.0546
# Training: [9,   148] loss: 0.0779 loss smooth: 0.0116
# Metric: 0.0533
# Training: [9,   164] loss: 0.0687 loss smooth: 0.0114
# Metric: 0.0492
# Training: [9,   180] loss: 0.0882 loss smooth: 0.0139
# Metric: 0.0435
# Training: [9,   196] loss: 0.0738 loss smooth: 0.0118
# Metric: 0.0454
# Training: [9,   212] loss: 0.0700 loss smooth: 0.0130
# Metric: 0.0496
# Training: [9,   228] loss: 0.0702 loss smooth: 0.0131
# Metric: 0.0520
# Training: [9,   244] loss: 0.0757 loss smooth: 0.0146
# Metric: 0.0494
# Training: [9,   260] loss: 0.0748 loss smooth: 0.0123
# Metric: 0.0530
# Training: [9,   276] loss: 0.0775 loss smooth: 0.0145
# Metric: 0.0562
# Training: [9,   292] loss: 0.0708 loss smooth: 0.0144
# Metric: 0.0406
# Training: [9,   308] loss: 0.0693 loss smooth: 0.0152
# Metric: 0.0499
# Training: [9,   324] loss: 0.0872 loss smooth: 0.0139
# Metric: 0.0508
# Training: [9,   340] loss: 0.0765 loss smooth: 0.0114
# Metric: 0.0509
# Training: [9,   356] loss: 0.0753 loss smooth: 0.0152
# Metric: 0.0471
# Training: [9,   372] loss: 0.0771 loss smooth: 0.0148
# Metric: 0.0482
# Training: [9,   388] loss: 0.0811 loss smooth: 0.0131
# Metric: 0.0473
# Training: [9,   404] loss: 0.0819 loss smooth: 0.0135
# Metric: 0.0453
# Training: [9,   420] loss: 0.0715 loss smooth: 0.0128
# Metric: 0.0530
# Training: [9,   436] loss: 0.0641 loss smooth: 0.0162
# Metric: 0.0451
# Training: [9,   452] loss: 0.0855 loss smooth: 0.0158
# Metric: 0.0465
# Training: [9,   468] loss: 0.0653 loss smooth: 0.0121
# Metric: 0.0581
# Training: [9,   484] loss: 0.0582 loss smooth: 0.0135
# Metric: 0.0468
# Training: [9,   500] loss: 0.0692 loss smooth: 0.0113
# Metric: 0.0515
# Training: [9,   516] loss: 0.0795 loss smooth: 0.0144
# Metric: 0.0470
# ...
# Metric: 0.0539
# Training: [28,   292] loss: 0.0619 loss smooth: 0.0122
# Metric: 0.0598
# Training: [28,   308] loss: 0.0645 loss smooth: 0.0120
# Metric: 0.0565
# Training: [28,   324] loss: 0.0685 loss smooth: 0.0138
# Metric: 0.0567
# Training: [28,   340] loss: 0.0631 loss smooth: 0.0129
# Metric: 0.0538
# Training: [28,   356] loss: 0.0702 loss smooth: 0.0174
# Metric: 0.0453
# Training: [28,   372] loss: 0.0569 loss smooth: 0.0117
# Metric: 0.0589
# Training: [28,   388] loss: 0.0675 loss smooth: 0.0133
# Metric: 0.0538
# Training: [28,   404] loss: 0.0647 loss smooth: 0.0120
# Metric: 0.0564
# Training: [28,   420] loss: 0.0753 loss smooth: 0.0130
# Metric: 0.0555
# Training: [28,   436] loss: 0.0747 loss smooth: 0.0140
# Metric: 0.0569
# Training: [28,   452] loss: 0.0629 loss smooth: 0.0118
# Metric: 0.0573
# Training: [28,   468] loss: 0.0605 loss smooth: 0.0120
# Metric: 0.0499
# Training: [28,   484] loss: 0.0675 loss smooth: 0.0156
# Metric: 0.0515
# Training: [28,   500] loss: 0.0663 loss smooth: 0.0139
# Metric: 0.0446
# Training: [28,   516] loss: 0.0778 loss smooth: 0.0166
# Metric: 0.0509
# Training: [28,   532] loss: 0.0610 loss smooth: 0.0147
# Metric: 0.0519
# Training: [28,   548] loss: 0.0484 loss smooth: 0.0115
# Metric: 0.0598
# Training: [28,   564] loss: 0.0805 loss smooth: 0.0146
# Metric: 0.0537
# Training: [28,   580] loss: 0.0645 loss smooth: 0.0124
# Metric: 0.0573
# Training: [28,   596] loss: 0.0668 loss smooth: 0.0130
# Metric: 0.0536
# Training: [28,   612] loss: 0.0667 loss smooth: 0.0138
# Metric: 0.0495
# Training: [28,   628] loss: 0.0724 loss smooth: 0.0116
# Metric: 0.0547
# Training: [28,   644] loss: 0.0661 loss smooth: 0.0146
# Metric: 0.0538
# Training: [28,   660] loss: 0.0564 loss smooth: 0.0124
# Metric: 0.0546
# Training: [28,   676] loss: 0.0802 loss smooth: 0.0134
# Metric: 0.0502
# Training: [28,   692] loss: 0.0691 loss smooth: 0.0133
# Metric: 0.0557
# Training: [28,   708] loss: 0.0796 loss smooth: 0.0136
# Metric: 0.0459
# Training: [28,   724] loss: 0.0606 loss smooth: 0.0131
# Metric: 0.0527
# Training: [28,   740] loss: 0.0706 loss smooth: 0.0125
# Metric: 0.0569
# Training: [28,   756] loss: 0.0714 loss smooth: 0.0131
# Metric: 0.0476
# Training: [28,   772] loss: 0.0577 loss smooth: 0.0116
# Metric: 0.0542
# Training: [28,   788] loss: 0.0580 loss smooth: 0.0140
# Metric: 0.0509
# Training: [28,   804] loss: 0.0667 loss smooth: 0.0135
# Metric: 0.0562
# Training: [28,   820] loss: 0.0706 loss smooth: 0.0109
# Metric: 0.0460
# Training: [28,   836] loss: 0.0749 loss smooth: 0.0137
# Metric: 0.0467
# Training: [28,   852] loss: 0.0707 loss smooth: 0.0146
# Metric: 0.0535
# Training: [28,   868] loss: 0.0677 loss smooth: 0.0153
# Metric: 0.0442
# Training: [28,   884] loss: 0.0682 loss smooth: 0.0137
# Metric: 0.0573
# Training: [28,   900] loss: 0.0611 loss smooth: 0.0120
# Metric: 0.0555
# Training: [28,   916] loss: 0.0710 loss smooth: 0.0121
# Metric: 0.0633
# Training: [28,   932] loss: 0.0651 loss smooth: 0.0142
# Metric: 0.0536
# Training: [28,   948] loss: 0.0673 loss smooth: 0.0136
# Metric: 0.0560
# Training: [28,   964] loss: 0.0734 loss smooth: 0.0122
# Metric: 0.0515
# Training: [28,   980] loss: 0.0736 loss smooth: 0.0134
# Metric: 0.0489
# Training: [28,   996] loss: 0.0769 loss smooth: 0.0134
# Metric: 0.0537
# Training: [28,  1012] loss: 0.0657 loss smooth: 0.0129
# Metric: 0.0611
# Training: [28,  1028] loss: 0.0720 loss smooth: 0.0146
# Metric: 0.0499
# Training: [28,  1044] loss: 0.0673 loss smooth: 0.0127
# Metric: 0.0549
# Training: [28,  1060] loss: 0.0657 loss smooth: 0.0133
# Metric: 0.0510
# Training: [28,  1076] loss: 0.0812 loss smooth: 0.0138
# Metric: 0.0513
# Training: [28,  1092] loss: 0.0712 loss smooth: 0.0119
# Metric: 0.0604
# Training: [28,  1108] loss: 0.0599 loss smooth: 0.0135
# Metric: 0.0658
# Training: [28,  1124] loss: 0.0715 loss smooth: 0.0137
# Metric: 0.0588
# Training: [28,  1140] loss: 0.0663 loss smooth: 0.0106
# Metric: 0.0556
# Training: [28,  1156] loss: 0.0662 loss smooth: 0.0113
# Metric: 0.0529
# Training: [28,  1172] loss: 0.0700 loss smooth: 0.0140
# Metric: 0.0473
# Training: [28,  1188] loss: 0.0749 loss smooth: 0.0133
# Metric: 0.0574
# Training: [28,  1204] loss: 0.0585 loss smooth: 0.0123
# Metric: 0.0578
# Training: [28,  1220] loss: 0.0663 loss smooth: 0.0129
# Metric: 0.0556
# Training: [28,   618] loss: 0.0855 loss smooth: 0.0169
# Metric: 0.0453
# Epoch: 28 Average Train loss: 0.0679
# Epoch: 28 Average Train metrics: 0.0525
# =======================================
# =======================================
# Epoch: 28 Average Test loss: 0.0545
# Best score: 0.0468
# Training: [29,     4] loss: 0.0677 loss smooth: 0.0141
# Metric: 0.0536
# Training: [29,    20] loss: 0.0749 loss smooth: 0.0127
# Metric: 0.0536
# Training: [29,    36] loss: 0.0634 loss smooth: 0.0137
# Metric: 0.0559
# Training: [29,    52] loss: 0.0553 loss smooth: 0.0129
# Metric: 0.0557
# Training: [29,    68] loss: 0.0767 loss smooth: 0.0140
# Metric: 0.0472
# Training: [29,    84] loss: 0.0597 loss smooth: 0.0136
# Metric: 0.0508
# Training: [29,   100] loss: 0.0756 loss smooth: 0.0122
# Metric: 0.0577
# Training: [29,   116] loss: 0.0742 loss smooth: 0.0151
# Metric: 0.0466
# Training: [29,   132] loss: 0.0774 loss smooth: 0.0117
# Metric: 0.0590
# Training: [29,   148] loss: 0.0638 loss smooth: 0.0134
# Metric: 0.0523
# Training: [29,   164] loss: 0.0746 loss smooth: 0.0130
# Metric: 0.0577
# Training: [29,   180] loss: 0.0668 loss smooth: 0.0119
# Metric: 0.0436
# Training: [29,   196] loss: 0.0617 loss smooth: 0.0125
# Metric: 0.0507
# Training: [29,   212] loss: 0.0770 loss smooth: 0.0131
# Metric: 0.0516
# Training: [29,   228] loss: 0.0725 loss smooth: 0.0136
# Metric: 0.0549
# Training: [29,   244] loss: 0.0669 loss smooth: 0.0149
# Metric: 0.0527
# Training: [29,   260] loss: 0.0597 loss smooth: 0.0150
# Metric: 0.0478
# Training: [29,   276] loss: 0.0692 loss smooth: 0.0126
# Metric: 0.0506
# Training: [29,   292] loss: 0.0684 loss smooth: 0.0134
# Metric: 0.0468
# Training: [29,   308] loss: 0.0768 loss smooth: 0.0152
# Metric: 0.0489
# Training: [29,   324] loss: 0.0635 loss smooth: 0.0127
# Metric: 0.0561
# Training: [29,   340] loss: 0.0724 loss smooth: 0.0133
# Metric: 0.0512
# Training: [29,   356] loss: 0.0613 loss smooth: 0.0141
# Metric: 0.0507
# Training: [29,   372] loss: 0.0625 loss smooth: 0.0103
# Metric: 0.0574
# Training: [29,   388] loss: 0.0801 loss smooth: 0.0140
# Metric: 0.0497
# Training: [29,   404] loss: 0.0684 loss smooth: 0.0127
# Metric: 0.0568
# Training: [29,   420] loss: 0.0669 loss smooth: 0.0126
# Metric: 0.0503
# Training: [29,   436] loss: 0.0589 loss smooth: 0.0127
# Metric: 0.0522
# Training: [29,   452] loss: 0.0656 loss smooth: 0.0149
# Metric: 0.0560
# Training: [29,   468] loss: 0.0613 loss smooth: 0.0142
# Metric: 0.0560
# Training: [29,   484] loss: 0.0688 loss smooth: 0.0125
# Metric: 0.0526
# Training: [29,   500] loss: 0.0582 loss smooth: 0.0119
# Metric: 0.0529
# Training: [29,   516] loss: 0.0759 loss smooth: 0.0123
# Metric: 0.0391
# Training: [29,   532] loss: 0.0637 loss smooth: 0.0110
# Metric: 0.0515
# Training: [29,   548] loss: 0.0750 loss smooth: 0.0134
# Metric: 0.0566
# Training: [29,   564] loss: 0.0745 loss smooth: 0.0149
# Metric: 0.0549
# Training: [29,   580] loss: 0.0759 loss smooth: 0.0146
# Metric: 0.0613
# Training: [29,   596] loss: 0.0694 loss smooth: 0.0137
# Metric: 0.0550
# Training: [29,   612] loss: 0.0655 loss smooth: 0.0118
# Metric: 0.0502
# Training: [29,   628] loss: 0.0575 loss smooth: 0.0138
# Metric: 0.0483
# Training: [29,   644] loss: 0.0662 loss smooth: 0.0157
# Metric: 0.0502
# Training: [29,   660] loss: 0.0602 loss smooth: 0.0134
# Metric: 0.0571
# Training: [29,   676] loss: 0.0588 loss smooth: 0.0146
# Metric: 0.0543
# Training: [29,   692] loss: 0.0663 loss smooth: 0.0143
# Metric: 0.0567
# Training: [29,   708] loss: 0.0691 loss smooth: 0.0135
# Metric: 0.0454
# Training: [29,   724] loss: 0.0621 loss smooth: 0.0140
# Metric: 0.0533
# Training: [29,   740] loss: 0.0706 loss smooth: 0.0124
# Metric: 0.0534
# Training: [29,   756] loss: 0.0687 loss smooth: 0.0150
# Metric: 0.0481
# Training: [29,   772] loss: 0.0871 loss smooth: 0.0127
# Metric: 0.0470
# Training: [29,   788] loss: 0.0776 loss smooth: 0.0130
# Metric: 0.0534
# Training: [29,   804] loss: 0.0657 loss smooth: 0.0143
# Metric: 0.0589
# Training: [29,   820] loss: 0.0767 loss smooth: 0.0125
# Metric: 0.0496
# Training: [29,   836] loss: 0.0606 loss smooth: 0.0137
# Metric: 0.0572
# Training: [29,   852] loss: 0.0541 loss smooth: 0.0142
# Metric: 0.0593
# Training: [29,   868] loss: 0.0551 loss smooth: 0.0127
# Metric: 0.0540
# Training: [29,   884] loss: 0.0622 loss smooth: 0.0135
# Metric: 0.0520
# Training: [29,   900] loss: 0.0606 loss smooth: 0.0131
# Metric: 0.0488
# Training: [29,   916] loss: 0.0782 loss smooth: 0.0155
# Metric: 0.0483
# Training: [29,   932] loss: 0.0568 loss smooth: 0.0119
# Metric: 0.0533
# Training: [29,   948] loss: 0.0629 loss smooth: 0.0154
# Metric: 0.0509
# Training: [29,   964] loss: 0.0660 loss smooth: 0.0139
# Metric: 0.0520
# Training: [29,   980] loss: 0.0706 loss smooth: 0.0148
# Metric: 0.0582
# Training: [29,   996] loss: 0.0747 loss smooth: 0.0133
# Metric: 0.0473
# Training: [29,  1012] loss: 0.0638 loss smooth: 0.0140
# Metric: 0.0455
# Training: [29,  1028] loss: 0.0736 loss smooth: 0.0160
# Metric: 0.0483
# Training: [29,  1044] loss: 0.0786 loss smooth: 0.0146
# Metric: 0.0487
# Training: [29,  1060] loss: 0.0647 loss smooth: 0.0116
# Metric: 0.0560
# Training: [29,  1076] loss: 0.0731 loss smooth: 0.0129
# Metric: 0.0462
# Training: [29,  1092] loss: 0.0612 loss smooth: 0.0120
# Metric: 0.0575
# Training: [29,  1108] loss: 0.0753 loss smooth: 0.0148
# Metric: 0.0530
# Training: [29,  1124] loss: 0.0747 loss smooth: 0.0134
# Metric: 0.0499
# Training: [29,  1140] loss: 0.0658 loss smooth: 0.0138
# Metric: 0.0581
# Training: [29,  1156] loss: 0.0778 loss smooth: 0.0164
# Metric: 0.0508
# Training: [29,  1172] loss: 0.0719 loss smooth: 0.0155
# Metric: 0.0535
# Training: [29,  1188] loss: 0.0590 loss smooth: 0.0140
# Metric: 0.0535
# Training: [29,  1204] loss: 0.0699 loss smooth: 0.0143
# Metric: 0.0565
# Training: [29,  1220] loss: 0.0667 loss smooth: 0.0128
# Metric: 0.0525
# Training: [29,   618] loss: 0.0691 loss smooth: 0.0179
# Metric: 0.0529
# Epoch: 29 Average Train loss: 0.0677
# Epoch: 29 Average Train metrics: 0.0523
# =======================================
# =======================================
# Epoch: 29 Average Test loss: 0.0537
# Best score: 0.0468
# Training: [30,     4] loss: 0.0659 loss smooth: 0.0132
# Metric: 0.0506
# Training: [30,    20] loss: 0.0772 loss smooth: 0.0131
# Metric: 0.0482
# Training: [30,    36] loss: 0.0688 loss smooth: 0.0141
# Metric: 0.0556
# Training: [30,    52] loss: 0.0604 loss smooth: 0.0129
# Metric: 0.0609
# Training: [30,    68] loss: 0.0753 loss smooth: 0.0135
# Metric: 0.0475
# Training: [30,    84] loss: 0.0716 loss smooth: 0.0172
# Metric: 0.0515
# Training: [30,   100] loss: 0.0755 loss smooth: 0.0141
# Metric: 0.0453
# Training: [30,   116] loss: 0.0625 loss smooth: 0.0117
# Metric: 0.0577
# Training: [30,   132] loss: 0.0675 loss smooth: 0.0109
# Metric: 0.0514
# Training: [30,   148] loss: 0.0686 loss smooth: 0.0144
# Metric: 0.0556
# Training: [30,   164] loss: 0.0538 loss smooth: 0.0131
# Metric: 0.0554
# Training: [30,   180] loss: 0.0609 loss smooth: 0.0134
# Metric: 0.0557
# Training: [30,   196] loss: 0.0647 loss smooth: 0.0124
# Metric: 0.0534
# Training: [30,   212] loss: 0.0848 loss smooth: 0.0134
# Metric: 0.0444
# Training: [30,   228] loss: 0.0632 loss smooth: 0.0148
# Metric: 0.0465
# Training: [30,   244] loss: 0.0723 loss smooth: 0.0126
# Metric: 0.0519
# Training: [30,   260] loss: 0.0717 loss smooth: 0.0170
# Metric: 0.0526
# Training: [30,   276] loss: 0.0650 loss smooth: 0.0140
# Metric: 0.0533
# Training: [30,   292] loss: 0.0641 loss smooth: 0.0114
# Metric: 0.0525
# Training: [30,   308] loss: 0.0664 loss smooth: 0.0135
# Metric: 0.0567
# Training: [30,   324] loss: 0.0512 loss smooth: 0.0132
# Metric: 0.0619
# Training: [30,   340] loss: 0.0667 loss smooth: 0.0112
# Metric: 0.0532
# Training: [30,   356] loss: 0.0665 loss smooth: 0.0140
# Metric: 0.0503
# Training: [30,   372] loss: 0.0546 loss smooth: 0.0128
# Metric: 0.0513
# Training: [30,   388] loss: 0.0597 loss smooth: 0.0119
# Metric: 0.0585
# Training: [30,   404] loss: 0.0570 loss smooth: 0.0133
# Metric: 0.0542
# Training: [30,   420] loss: 0.0612 loss smooth: 0.0150
# Metric: 0.0469
# Training: [30,   436] loss: 0.0657 loss smooth: 0.0147
# Metric: 0.0521
# Training: [30,   452] loss: 0.0718 loss smooth: 0.0140
# Metric: 0.0633
# Training: [30,   468] loss: 0.0512 loss smooth: 0.0118
# Metric: 0.0621
# Training: [30,   484] loss: 0.0759 loss smooth: 0.0138
# Metric: 0.0529
# Training: [30,   500] loss: 0.0636 loss smooth: 0.0132
# Metric: 0.0519
# Training: [30,   516] loss: 0.0686 loss smooth: 0.0140
# Metric: 0.0614
# Training: [30,   532] loss: 0.0616 loss smooth: 0.0126
# Metric: 0.0590
# Training: [30,   548] loss: 0.0687 loss smooth: 0.0132
# Metric: 0.0520
# Training: [30,   564] loss: 0.0766 loss smooth: 0.0119
# Metric: 0.0550
# Training: [30,   580] loss: 0.0717 loss smooth: 0.0147
# Metric: 0.0449
# Training: [30,   596] loss: 0.0767 loss smooth: 0.0164
# Metric: 0.0516
# Training: [30,   612] loss: 0.0706 loss smooth: 0.0143
# Metric: 0.0460
# Training: [30,   628] loss: 0.0593 loss smooth: 0.0121
# Metric: 0.0622
# Training: [30,   644] loss: 0.0833 loss smooth: 0.0139
# Metric: 0.0471
# Training: [30,   660] loss: 0.0645 loss smooth: 0.0132
# Metric: 0.0504
# Training: [30,   676] loss: 0.0721 loss smooth: 0.0133
# Metric: 0.0494
# Training: [30,   692] loss: 0.0639 loss smooth: 0.0130
# Metric: 0.0581
# Training: [30,   708] loss: 0.0661 loss smooth: 0.0147
# Metric: 0.0560
# Training: [30,   724] loss: 0.0756 loss smooth: 0.0137
# Metric: 0.0475
# Training: [30,   740] loss: 0.0713 loss smooth: 0.0124
# Metric: 0.0531
# Training: [30,   756] loss: 0.0728 loss smooth: 0.0137
# Metric: 0.0539
# Training: [30,   772] loss: 0.0629 loss smooth: 0.0127
# Metric: 0.0471
# Training: [30,   788] loss: 0.0810 loss smooth: 0.0145
# Metric: 0.0474
# Training: [30,   804] loss: 0.0526 loss smooth: 0.0124
# Metric: 0.0560
# Training: [30,   820] loss: 0.0591 loss smooth: 0.0113
# Metric: 0.0555
# Training: [30,   836] loss: 0.0702 loss smooth: 0.0159
# Metric: 0.0506
# Training: [30,   852] loss: 0.0693 loss smooth: 0.0117
# Metric: 0.0552
# Training: [30,   868] loss: 0.0629 loss smooth: 0.0140
# Metric: 0.0548
# Training: [30,   884] loss: 0.0697 loss smooth: 0.0119
# Metric: 0.0491
# Training: [30,   900] loss: 0.0646 loss smooth: 0.0129
# Metric: 0.0477
# Training: [30,   916] loss: 0.0725 loss smooth: 0.0129
# Metric: 0.0525
# Training: [30,   932] loss: 0.0811 loss smooth: 0.0146
# Metric: 0.0477
# Training: [30,   948] loss: 0.0668 loss smooth: 0.0123
# Metric: 0.0531
# Training: [30,   964] loss: 0.0612 loss smooth: 0.0143
# Metric: 0.0502
# Training: [30,   980] loss: 0.0702 loss smooth: 0.0149
# Metric: 0.0509
# Training: [30,   996] loss: 0.0654 loss smooth: 0.0139
# Metric: 0.0544
# Training: [30,  1012] loss: 0.0730 loss smooth: 0.0124
# Metric: 0.0533
# Training: [30,  1028] loss: 0.0751 loss smooth: 0.0149
# Metric: 0.0508
# Training: [30,  1044] loss: 0.0620 loss smooth: 0.0122
# Metric: 0.0635
# Training: [30,  1060] loss: 0.0597 loss smooth: 0.0122
# Metric: 0.0517
# Training: [30,  1076] loss: 0.0675 loss smooth: 0.0137
# Metric: 0.0583
# Training: [30,  1092] loss: 0.0560 loss smooth: 0.0137
# Metric: 0.0489
# Training: [30,  1108] loss: 0.0712 loss smooth: 0.0125
# Metric: 0.0510
# Training: [30,  1124] loss: 0.0595 loss smooth: 0.0134
# Metric: 0.0553
# Training: [30,  1140] loss: 0.0770 loss smooth: 0.0140
# Metric: 0.0498
# Training: [30,  1156] loss: 0.0636 loss smooth: 0.0142
# Metric: 0.0485
# Training: [30,  1172] loss: 0.0610 loss smooth: 0.0118
# Metric: 0.0507
# Training: [30,  1188] loss: 0.0829 loss smooth: 0.0132
# Metric: 0.0488
# Training: [30,  1204] loss: 0.0657 loss smooth: 0.0142
# Metric: 0.0559
# Training: [30,  1220] loss: 0.0691 loss smooth: 0.0138
# Metric: 0.0508
# Training: [30,   618] loss: 0.0780 loss smooth: 0.0135
# Metric: 0.0486
# Epoch: 30 Average Train loss: 0.0677
# Epoch: 30 Average Train metrics: 0.0525
# =======================================
# =======================================
# Epoch: 30 Average Test loss: 0.0493
# Best score: 0.0468

# %% [markdown]
# # Test

# %%
from torch.utils.data import DataLoader
test_dl = DataLoader(test_dataset,batch_size=1,shuffle=False)

# %%
model_path = './sim_4obj_ele_data/checkpoints/sim_2023_11_14/9.pth'
model.load_state_dict(torch.load(model_path))

for i, data in enumerate(all_dl):
        
    ac, ele_gt, mask, ac_previous, ele_previous_gt, mask_previous, ac_next, ele_next_gt, mask_next, motion1, motion2, front = data
    ac, ele_gt, mask, ac_previous, ele_previous_gt, mask_previous, ac_next, ele_next_gt, mask_next, motion1, motion2 = ac.cuda(), ele_gt.cuda(), mask.cuda(), ac_previous.cuda(), ele_previous_gt.cuda(), mask_previous.cuda(), ac_next.cuda(), ele_next_gt.cuda(), mask_next.cuda(), motion1.cuda(), motion2.cuda()
    if i>8:
        break
#model_path = 'E:/real-data/checkpoint_ddv/2.pth'    
#model.load_state_dict(torch.load(model_path))       
#model.eval()
ac = ac*mask
ele = model(ac)

ele = ele*mask

warp_mask1,valid_mask1 = inverse_warp(mask_next,ele_gt,mask,motion2) #pose111
warp_mask2,valid_mask2 = inverse_warp(mask_previous,ele_gt,mask,motion1)
    
ele = ele#*warp_mask1*warp_mask2
ele_gt = ele_gt#*warp_mask1*warp_mask2


plt.figure(figsize=(12,12))
acc = ac.to('cpu').detach().numpy().copy()
acc = acc[0]
plt.imshow(acc.squeeze(),cmap=plt.cm.gray)
plt.clim(0,1)

plt.figure(figsize=(12,12))
tester = ele.to('cpu').detach().numpy().copy()
testers = tester[0]


plt.imshow(testers.squeeze(),cmap=plt.cm.jet)
plt.clim(0,1)

plt.figure(figsize=(12,12))
gt = ele_gt.to('cpu').detach().numpy().copy()
gt = gt[0]

plt.imshow(gt.squeeze(),cmap=plt.cm.jet)

print(np.mean(np.abs(gt-testers)))
# Out:
# 0.04450564

# %%
with torch.no_grad():
    model.eval()
    test_loss = 0
    counts=0
    for i,data in enumerate(train_dl):
        ac, ele_gt, mask, ac_previous, ele_previous_gt, mask_previous, ac_next, ele_next_gt, mask_next, motion1, motion2, front = data
        ac, ele_gt, mask, ac_previous, ele_previous_gt, mask_previous, ac_next, ele_next_gt, mask_next, motion1, motion2 = ac.cuda(), ele_gt.cuda(), mask.cuda(), ac_previous.cuda(), ele_previous_gt.cuda(), mask_previous.cuda(), ac_next.cuda(), ele_next_gt.cuda(), mask_next.cuda(), motion1.cuda(), motion2.cuda()
        ac = ac*mask
        ele = model(ac)
        ele = ele*mask
        diff_metric = ele-ele_gt*mask
            
        metric = diff_metric.abs().mean()
        test_loss = test_loss + metric.item()
        counts = counts+1
        #print(metric.item())
    print('Epoch: %d Average Test loss: %.4f' %(epoch + 1,test_loss/counts))
# Out:
# Epoch: 30 Average Test loss: 0.0478

# %%
for i, data in enumerate(all_dl):
        
    ac, ele_gt, mask, ac_previous, ele_previous_gt, mask_previous, ac_next, ele_next_gt, mask_next, motion1, motion2, front = data
    ac, ele_gt, mask, ac_previous, ele_previous_gt, mask_previous, ac_next, ele_next_gt, mask_next, motion1, motion2 = ac.cuda(), ele_gt.cuda(), mask.cuda(), ac_previous.cuda(), ele_previous_gt.cuda(), mask_previous.cuda(), ac_next.cuda(), ele_next_gt.cuda(), mask_next.cuda(), motion1.cuda(), motion2.cuda()
    #if i>88:
        #break
    model.eval()
    ac = ac*mask
    ele = model(ac)

    ele = ele*mask


    ele_gt = ele_gt*mask    


    plt.figure(figsize=(12,12))
    acc = ac.to('cpu').detach().numpy().copy()
    acc = acc[0]
    plt.imshow(acc.squeeze(),cmap=plt.cm.gray)
    plt.clim(0,1)

    plt.figure(figsize=(12,12))
    tester = ele.to('cpu').detach().numpy().copy()
    testers = tester[0]


    plt.imshow(testers.squeeze(),cmap=plt.cm.jet)
    plt.clim(0,1)

    plt.figure(figsize=(12,12))
    gt = ele_gt.to('cpu').detach().numpy().copy()
    gt = gt[0]
    plt.imshow(gt.squeeze(),cmap=plt.cm.jet)
    if i>5:
        break
#model_path = 'E:/real-data/checkpoint_ddv/2.pth'    
#model.load_state_dict(torch.load(model_path))
# Out:
# /tmp/ipykernel_127960/3954801758.py:31: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`). Consider using `matplotlib.pyplot.close()`.
#   plt.figure(figsize=(12,12))

# %% [markdown]
# # Visualize the results and save

# %%
import matplotlib.colors
def make_image(data, outputname,min_bar=0.0,max_bar=1.0, size=(1, 4), dpi=100):
    fig = plt.figure()
    fig.set_size_inches(size)
    ax = plt.Axes(fig, [0., 0., 1., 1.])
    ax.set_axis_off()
    fig.add_axes(ax)
    plt.set_cmap('jet')
    norm = matplotlib.colors.Normalize(vmin=min_bar,vmax=max_bar)
    ax.imshow(data, aspect='equal',norm=norm)
    #ax.set_clim(0,512)
    plt.savefig(outputname, dpi=dpi)
    plt.close(fig)
def make_image_gray(data, outputname, min_bar=0.0,max_bar=1.0, size=(1, 4), dpi=100):
    fig = plt.figure()
    fig.set_size_inches(size)
    ax = plt.Axes(fig, [0., 0., 1., 1.])
    ax.set_axis_off()
    fig.add_axes(ax)
    plt.set_cmap('gray')
    norm = matplotlib.colors.Normalize(vmin=min_bar,vmax=max_bar)
    ax.imshow(data, aspect='equal',norm=norm)
    plt.savefig(outputname, dpi=dpi)
    plt.close(fig)

# %%
import matplotlib.colors

# %%
model.eval()
#model_path = './Checkpoints/UNetCheckpoint_real/best.pth'
#model.load_state_dict(torch.load(model_path))
with torch.no_grad():
    for i,data in enumerate(train_dl): #train_dl
        ac, ele_gt, mask, ac_previous, ele_previous_gt, mask_previous, ac_next, ele_next_gt, mask_next, motion1, motion2, front = data
        ac, ele_gt, mask, ac_previous, ele_previous_gt, mask_previous, ac_next, ele_next_gt, mask_next, motion1, motion2 = ac.cuda(), ele_gt.cuda(), mask.cuda(), ac_previous.cuda(), ele_previous_gt.cuda(), mask_previous.cuda(), ac_next.cuda(), ele_next_gt.cuda(), mask_next.cuda(), motion1.cuda(), motion2.cuda()
        ac = ac*mask
        ele = model(ac)
        ele = ele*mask
        
        # Create directory if not exists
        output_directory = './sim_4obj_ele_data/output_sim/roll/'
        os.makedirs(output_directory, exist_ok=True)  # This ensures that the directory exists


        acc = ac.to('cpu').detach().numpy()
        min_bar = 0
        max_bar = 1
        path = './sim_4obj_ele_data/output_sim/roll/ac'+str(i)+'.png'
        make_image_gray(acc[0].squeeze(),path)
    
        eg = ele_gt.to('cpu').detach().numpy()
        min_bar = 0
        max_bar = 1
        path = './sim_4obj_ele_data/output_sim/roll/ele_gt'+str(i)+'.png'
        make_image(eg[0].squeeze(),path,0,1)
    
        el = ele.to('cpu').detach().numpy()
        min_bar = 0
        max_bar = 1
        path = './sim_4obj_ele_data/output_sim/roll/ele'+str(i)+'.png'
        make_image(el[0].squeeze(),path,0,1)
    
    
    
        if i>20:
            break

# %%
#model.eval()
#model_path = './Checkpoints/UNetCheckpoint_real/best.pth'
#model.load_state_dict(torch.load(model_path))
with torch.no_grad():
    for i,data in enumerate(test_dl): #test_dl
        ac, ele_gt, mask, ac_previous, ele_previous_gt, mask_previous, ac_next, ele_next_gt, mask_next, motion1, motion2, front = data
        ac, ele_gt, mask, ac_previous, ele_previous_gt, mask_previous, ac_next, ele_next_gt, mask_next, motion1, motion2 = ac.cuda(), ele_gt.cuda(), mask.cuda(), ac_previous.cuda(), ele_previous_gt.cuda(), mask_previous.cuda(), ac_next.cuda(), ele_next_gt.cuda(), mask_next.cuda(), motion1.cuda(), motion2.cuda()
        #ac = ac*mask
        #ele = model(ac)
        #ele = ele*mask

        # Create directory if it doesn't exist
        output_directory = './sim_4obj_ele_data/output_sim/raw/'
        os.makedirs(output_directory, exist_ok=True)  # This ensures that the directory exists

        acc = ac.to('cpu').detach().numpy()
        min_bar = 0
        max_bar = 1
        path = './sim_4obj_ele_data/output_sim/raw/ac'+str(i)+'.png'
        make_image_gray(acc[0].squeeze(),path)

# %% [markdown]
# # Elevation map to point cloud

# %%
def ele2pc_output(ele,mask): #depth: batch, channel, elevation, azimuth [b,c,e,a]  [1,1,32,128]
    scale=700/512
    angle=18
    
    ele = ele*mask
    ele = ele*angle-angle/2
        
    
    #print(ele.shape)
    aa = (ele<9)
    bb = (ele>-9)
    valid = (aa&bb)
  
    
    ele=ele/180.0*PI
    #global pixel_coords
    b,c,e,a = ele.size()
    valid = valid.reshape(b,-1)
    
    
    i_range = torch.arange(0, e).view(1, e, 1).expand(1,e,a).type_as(ele)*(scale*0.00299)+0.971+400*(0.00299)  # 48.55 optical camera aperture
    i_range = i_range
    j_range = torch.arange(0, a).view(1, 1, a).expand(1,e,a).type_as(ele)/128*(30.0)-(30.0/2)  #-32
    j_range = j_range/180.0*PI
    ones = torch.ones(1,e,a).type_as(ele)
    
    #print(i_range.shape)
    

    
    pixel_coords = torch.stack((j_range, i_range, ones), dim=1)
    
    
    current_pixel_coords = pixel_coords[:,:,:e,:a].expand(b,3,e,a)
    
    ones_exp = torch.ones(b,e,a).type_as(ele)

    ele_exp = torch.stack((ones_exp, ones_exp, ele.squeeze(1)), dim=1)
    
    current_pixel_coords= ele_exp*current_pixel_coords
    
    #print(current_pixel_coords.shape)
   
    #print(current_pixel_coords[:,2,:,:]/PI*180)
    
    x = current_pixel_coords[:,1,:,:]*torch.cos(current_pixel_coords[:,0,:,:])*torch.cos(current_pixel_coords[:,2,:,:])
    y = current_pixel_coords[:,1,:,:]*torch.sin(current_pixel_coords[:,0,:,:])*torch.cos(current_pixel_coords[:,2,:,:])
    z = current_pixel_coords[:,1,:,:]*torch.sin(current_pixel_coords[:,2,:,:])
    
    
    pc = torch.stack((x, y, z), dim=1)
    
    
    
    pc = pc.view(b,3,-1)
    #pc = pc.transpose(1,2)
    pc = pc*valid.unsqueeze(1).float()
    #valid =valid.unsqueeze(2)
    
    #print(pc.shape)
    
    return pc,valid

# %%
#model_path = './checkpoints/real_20230209/current_sc.pth'
#model.load_state_dict(torch.load(model_path))

for i, data in enumerate(train_dl):
        
        ac, ele_gt, mask, ac_previous, ele_previous_gt, mask_previous, ac_next, ele_next_gt, mask_next, motion1, motion2, front = data
        ac, ele_gt, mask, ac_previous, ele_previous_gt, mask_previous, ac_next, ele_next_gt, mask_next, motion1, motion2 = ac.cuda(), ele_gt.cuda(), mask.cuda(), ac_previous.cuda(), ele_previous_gt.cuda(), mask_previous.cuda(), ac_next.cuda(), ele_next_gt.cuda(), mask_next.cuda(), motion1.cuda(), motion2.cuda()
        #if i>5:
        break
#model_path = 'E:/real-data/checkpoint_ddv/2.pth'    
#model.load_state_dict(torch.load(model_path))       
model.eval()
ac = ac*mask
ele = model(ac)

acx=ac
print('motion2 shape: ', motion2.shape)
warp1,valid1 = inverse_warp(ac_next,ele,mask,motion2)

ele = ele*mask
pc,valid = ele2pc_output(ele,mask)



pc = pc[0]
print(pc.shape)
pc=pc.transpose(0,1)
pc =pc.to('cpu').detach().numpy().copy()
np.savetxt('./sim_4obj_ele_data/sampleR.txt',pc)

pc,valid = ele2pc_output(ele_gt,mask)

pc = pc[0]
print(pc.shape)
pc=pc.transpose(0,1)
pc =pc.to('cpu').detach().numpy().copy()
np.savetxt('./sim_4obj_ele_data/gtR.txt',pc)



#np.savetxt('gtA.txt',pc_gt)


warp1 = warp1*mask



plt.figure(figsize=(12,12))
tester = ele.to('cpu').detach().numpy().copy()
testers = tester[0]

plt.imshow(testers.squeeze())

plt.figure(figsize=(12,12))
wp = warp1.to('cpu').detach().numpy().copy()
wps = wp[0]

plt.imshow(wps.squeeze())

ac=ac*mask
plt.figure(figsize=(12,12))
acc = ac.to('cpu').detach().numpy().copy()
acs = acc[0]

plt.imshow(acs.squeeze())

#vis_pr=torch.max(pr,dim=1,keepdim=True)
    #max_pr = torch.max(pr,dim=1)
    #print(max_pr[1])
    #print(pr[:,max_pr[1],:,:])
    #print(vis_pr[0].shape)
# Out:
# motion2 shape:  torch.Size([4, 6])
# torch.Size([3, 65536])
# torch.Size([3, 65536])

# %%
model.eval()

for i,data in enumerate(all_dl): #test_dl
    ac, ele_gt, mask, ac_previous, ele_previous_gt, mask_previous, ac_next, ele_next_gt, mask_next, motion1, motion2, front = data
    ac, ele_gt, mask, ac_previous, ele_previous_gt, mask_previous, ac_next, ele_next_gt, mask_next, motion1, motion2 = ac.cuda(), ele_gt.cuda(), mask.cuda(), ac_previous.cuda(), ele_previous_gt.cuda(), mask_previous.cuda(), ac_next.cuda(), ele_next_gt.cuda(), mask_next.cuda(), motion1.cuda(), motion2.cuda()
    ac = ac*mask
    ele = model(ac)
    ele = ele*mask
    
    pc,valid = ele2pc_output(ele,mask)


    pc = pc[0]
    print(pc.shape)
    pc=pc.transpose(0,1)
    pc =pc.to('cpu').detach().numpy().copy()
    np.savetxt('./sim_4obj_ele_data/sampleR.txt',pc)
    
    pc,valid = ele2pc_output(ele_gt,mask)

    pc = pc[0]
    print(pc.shape)
    pc=pc.transpose(0,1)
    pc =pc.to('cpu').detach().numpy().copy()
    np.savetxt('./sim_4obj_ele_data/gtR.txt',pc)
    
    break
# Out:
# torch.Size([3, 65536])
# torch.Size([3, 65536])

# %%
model.eval()

for i, data in enumerate(all_dl):
    ac, ele_gt, mask, ac_previous, ele_previous_gt, mask_previous, ac_next, ele_next_gt, mask_next, motion1, motion2, front = data
    ac, ele_gt, mask, ac_previous, ele_previous_gt, mask_previous, ac_next, ele_next_gt, mask_next, motion1, motion2, front = ac.cuda(), ele_gt.cuda(), mask.cuda(), ac_previous.cuda(), ele_previous_gt.cuda(), mask_previous.cuda(), ac_next.cuda(), ele_next_gt.cuda(), mask_next.cuda(), motion1.cuda(), motion2.cuda(), front.cuda()
    ac = ac*mask
    ele = model(ac)
    ele = ele*mask
    ele_gt = ele_gt*mask
    
    ele = ele[0].squeeze().to('cpu').detach().numpy()

    pc1 = torch.zeros([512, 64, 128], dtype=torch.float32)
    sfront = torch.zeros([64, 128], dtype=torch.float32)
    
    ele = np.clip(ele,0,0.99)
    ele = ele*64
    ele = ele.astype(dtype = np.int64)
    
    mask = mask.squeeze()



    for m in range(512):
        for j in range(128):
             if mask[m, j].item() > 0:
                k = ele[m][j]
                #print(k)
                pc1[m][k][j] = 1
                sfront[k][j] = m
    
    pcr = torch.zeros([512, 64, 128], dtype=torch.float32)
    
    sfront = torch.tensor(sfront,dtype=torch.float32).unsqueeze(0).unsqueeze(0)
    
    #sfront = F.interpolate(sfront,(32,64), mode='bicubic')
    sfront = sfront.squeeze()
    #sfront[sfront<1]=511
    #sfront[sfront>512]=511
    
    for m in range(64):
        for j in range(128):
            if sfront[m][j]>5 and sfront[m][j]<512:
                k = int(sfront[m][j])
                #jd = int(j/2)
                pcr[k][m][j] = 1
    
    data = torch.nonzero(pcr).numpy().astype(dtype = np.int64)
    #path = '/data/share/wang/maskgt'+str(i)+'.txt'
    #np.savetxt(path,data)
    
    
    r1=0.971+0.00299*400+data[:,0]*(0.00299*(700/512))
    phi=np.deg2rad(-9+data[:,1]/64*18)
    theta=np.deg2rad(-15+data[:,2]/128*30)
    
    length = len(data[:,0])
    
    test_pc1 = np.zeros([length,3], dtype=np.float32)
    
    test_pc1[:,0]=r1*np.sin(theta)*np.cos(phi)
    test_pc1[:,1]=-r1*np.sin(phi)
    test_pc1[:,2]=-r1*np.cos(theta)*np.cos(phi)

    # Create directory if it doesn't exist
    output_directory = './sim_4obj_ele_data/result_sim/roll_blender/'
    os.makedirs(output_directory, exist_ok=True)  # This ensures that the directory exists
    
    
    path = './sim_4obj_ele_data/result_sim/roll_blender/test'+str(i)+'.txt'
    np.savetxt(path,test_pc1)

    # not complete gt point cloud
    ele_gt = ele_gt[0].squeeze().to('cpu').detach().numpy()

    pc2 = torch.zeros([512, 64, 128], dtype=torch.float32)
    sfront2 = torch.zeros([64, 128], dtype=torch.float32)
    
    ele_gt = np.clip(ele_gt,0,0.99)
    ele_gt = ele_gt*64
    ele_gt = ele_gt.astype(dtype = np.int64)
    
    mask = mask.squeeze()



    for m in range(512):
        for j in range(128):
             if mask[m, j].item() > 0:
                k2 = ele_gt[m][j]
                pc2[m][k2][j] = 1
                sfront2[k2][j] = m
    
    pcr2 = torch.zeros([512, 64, 128], dtype=torch.float32)
    
    sfront2 = torch.tensor(sfront2,dtype=torch.float32).unsqueeze(0).unsqueeze(0)
    
    sfront2 = sfront2.squeeze()
    
    for m in range(64):
        for j in range(128):
            if sfront2[m][j]>5 and sfront2[m][j]<512:
                k2 = int(sfront2[m][j])
                pcr2[k2][m][j] = 1
    
    data2 = torch.nonzero(pcr2).numpy().astype(dtype = np.int64)
    
    
    r12=0.971+0.00299*400+data2[:,0]*(0.00299*(700/512))
    phi2=np.deg2rad(-9+data2[:,1]/64*18)
    theta2=np.deg2rad(-15+data2[:,2]/128*30)
    
    length2 = len(data2[:,0])
    
    test_pc2 = np.zeros([length2,3], dtype=np.float32)
    
    test_pc2[:,0]=r12*np.sin(theta2)*np.cos(phi2)
    test_pc2[:,1]=-r12*np.sin(phi2)
    test_pc2[:,2]=-r12*np.cos(theta2)*np.cos(phi2)
    
    path = './sim_4obj_ele_data/result_sim/roll_blender/nComp'+str(i)+'.txt'
    np.savetxt(path,test_pc2)
    
    
    # gt point cloud
    y = front.to('cpu').detach().numpy().copy()
    
    gt= y[0]
    
    pc1 = torch.zeros([512, 64, 128], dtype=torch.float32)
    
    r1 = (gt-0.971-0.00299*400)/(0.00299*(700/512))
    r1 = r1.astype(dtype = np.int64)
    r1[r1<0]=0
    r1[r1>511]=0
    
    r1 = r1.astype(dtype = np.int64)
    #print(r)
    
    
    for m in range(64):
        for j in range(128):
            if r1[m][j]>0:
                k = r1[m][j]
                pc1[k][m][j] = 1
    data = torch.nonzero(pc1).numpy()
    #path = '/data/share/wang/maskgt'+str(i)+'.txt'
    #np.savetxt(path,data)
    
    
    r1=0.971+0.00299*400+data[:,0]*(0.00299*(700/512))
    
    phi=np.deg2rad(-9+data[:,1]/64*18)
    theta=np.deg2rad(-15+data[:,2]/128*30)
    
    length = len(data[:,0])
    
    euc_pc1 = np.zeros([length,3], dtype=np.float32)
    
    euc_pc1[:,0]=r1*np.sin(theta)*np.cos(phi)
    euc_pc1[:,1]=-r1*np.sin(phi)
    euc_pc1[:,2]=-r1*np.cos(theta)*np.cos(phi)
    
    path = './sim_4obj_ele_data/result_sim/roll_blender/gt'+str(i)+'.txt'
    np.savetxt(path,euc_pc1)
    
    
    
        #resize
    #break    
    #==================================================
# Out:
# /tmp/ipykernel_127960/3711955806.py:34: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   sfront = torch.tensor(sfront,dtype=torch.float32).unsqueeze(0).unsqueeze(0)
# /tmp/ipykernel_127960/3711955806.py:96: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   sfront2 = torch.tensor(sfront2,dtype=torch.float32).unsqueeze(0).unsqueeze(0)

# %% [markdown]
# # Quantitative evaluation

# %%
# !git clone https://github.com/ThibaultGROUEIX/ChamferDistancePytorch
# Out:
# fatal: destination path 'ChamferDistancePytorch' already exists and is not an empty directory.

# %%
import torch, time
import ChamferDistancePytorch.chamfer_python
import torch
import torch.nn as nn
import torch.nn.functional as F
import numpy as np
import ChamferDistancePytorch.fscore as fscore
import scipy.spatial.distance

# %%
list = []
for i in range(1):
    P = np.loadtxt("./sim_4obj_ele_data/result_sim/roll_blender/gt"+str(i)+".txt")
    Q = np.loadtxt("./sim_4obj_ele_data/result_sim/roll_blender/test"+str(i)+".txt")
    
    P = torch.tensor(P)
    Q = torch.tensor(Q)
    
    mydist1, mydist2, myidx1, myidx2 = ChamferDistancePytorch.chamfer_python.distChamfer(P.unsqueeze(0), Q.unsqueeze(0))
    
    dist = mydist1.mean()*500+mydist2.mean()*500
    list.append(dist)

# %%
print(np.mean(list))
# Out:
# 7.7315493

# %%
list = []
acc = []
com = []
list_fscore1 = []
list_fscore2 = []
hausdorff_list = []
for i in range(30):
    P = np.loadtxt("./sim_4obj_ele_data/result_sim/roll_blender/gt"+str(i)+".txt")
    Q = np.loadtxt("./sim_4obj_ele_data/result_sim/roll_blender/test"+str(i)+".txt")
    
    P = torch.tensor(P)
    Q = torch.tensor(Q)
    
    mydist1, mydist2, myidx1, myidx2 = ChamferDistancePytorch.chamfer_python.distChamfer(P.unsqueeze(0), Q.unsqueeze(0))
    com.append(mydist1.mean()*500)
    acc.append(mydist2.mean()*500)
    
    dist = mydist1.mean()*500+mydist2.mean()*500
    list.append(dist)
    
    f_score, precision, recall = fscore.fscore(mydist1, mydist2,0.001)
    list_fscore1.append(f_score)
    
    f_score, precision, recall = fscore.fscore(mydist1, mydist2,0.003)
    list_fscore2.append(f_score)

    dist = scipy.spatial.distance.directed_hausdorff(P, Q)[0]  # Only take the distance value, not the indices
    hausdorff_list.append(dist)

# %%
print(np.mean(list))
# Out:
# 7.273349

# %%
print(np.mean(hausdorff_list))
# Out:
# 0.37284782298744207

# %%
print(np.mean(list_fscore1))
# Out:
# 0.48814175

# %%
print(np.mean(list_fscore2))
# Out:
# 0.7098371

# %%
#1.2250342 2.7297041 1.7363062

# %%
print(np.mean(com))
# Out:
# 3.903158

# %%
print(np.mean(acc))
# Out:
# 3.3701918

# %%
import numpy as np
import pandas as pd
import torch
import scipy.spatial
import ChamferDistancePytorch
import ChamferDistancePytorch.fscore as fscore

def process_image(image_index):
    # Load your data
    P = np.loadtxt(f"./sim_4obj_ele_data/result_sim/roll_blender/gt{image_index}.txt")
    Q = np.loadtxt(f"./sim_4obj_ele_data/result_sim/roll_blender/test{image_index}.txt")
    
    P_tensor = torch.tensor(P)
    Q_tensor = torch.tensor(Q)
    
    mydist1, mydist2, _, _ = ChamferDistancePytorch.chamfer_python.distChamfer(P_tensor.unsqueeze(0), Q_tensor.unsqueeze(0))
    
    # Calculate metrics and convert tensor to float
    com = mydist1.mean().item() * 500
    acc = mydist2.mean().item() * 500
    dist = com + acc
    
    f_score1, _, _ = fscore.fscore(mydist1, mydist2, 0.001)
    f_score1 = f_score1.item()

    f_score2, _, _ = fscore.fscore(mydist1, mydist2, 0.003)
    f_score2 = f_score2.item()

    hausdorff_dist = scipy.spatial.distance.directed_hausdorff(P, Q)[0]

    # Return data as a dictionary with a unique image name
    return {
        'image_name': f'test_{image_index + 1}',  # Unique identifier for each image
        'index': image_index,
        'comb_dist': dist,
        'com': com,
        'acc': acc,
        'f_score_1': f_score1,
        'f_score_2': f_score2,
        'haus_dist': hausdorff_dist
    }

# Process images and create DataFrame
data = [process_image(i) for i in range(30)]
df = pd.DataFrame(data)

# Set the image name as the index of the DataFrame
df.set_index('image_name', inplace=True)

# Save to CSV
df.to_csv('image_metrics.csv')

# Display the DataFrame
print(df.head())  # Display first few rows for verification
# Out:
#             index  comb_dist       com       acc  f_score_1  f_score_2  \
# image_name
# test_1          0   7.731549  2.813288  4.918261   0.537994   0.715494
# test_2          1   6.732311  2.290987  4.441324   0.479225   0.749300
# test_3          2   6.763357  4.824428  1.938929   0.530161   0.686994
# test_4          3   7.986111  3.405236  4.580874   0.423924   0.736801
# test_5          4   5.444503  3.650401  1.794102   0.326847   0.535842
#
#             haus_dist
# image_name
# test_1       0.387308
# test_2       0.283534
# test_3       0.393148
# test_4       0.402854
# test_5       0.419178

# %%
import ChamferDistancePytorch.fscore as fscore
import matplotlib.pyplot as plt

f_score, precision, recall = fscore.fscore(mydist1, mydist2,0.002)
print(f_score)
# Out:
# tensor([0.6830])

# %%
# For acx
plt.figure(figsize=(12,12))
img = acx[0].to('cpu').detach().numpy().squeeze()  # Select the first image and squeeze
plt.imshow(img, cmap='gray')
plt.axis('off')

# For ac_next
plt.figure(figsize=(12,12))
img = ac_next[0].to('cpu').detach().numpy().squeeze()  # Select the first image and squeeze
plt.imshow(img, cmap='gray')
plt.axis('off')

# Reshape the image to 2D if necessary
if mask.ndim == 1:
    side_length = int(np.sqrt(mask.size(0)))
    mask = mask.reshape(side_length, side_length)

# Now you can safely squeeze since mask is at least 2D
img = mask[0].to('cpu').detach().numpy().squeeze()

# Visualize the image
plt.figure(figsize=(12,12))
plt.imshow(img, cmap='viridis')
plt.axis('off')

# For mask_next
plt.figure(figsize=(12,12))
print("Shape of img:", img.shape)

img = mask_next[0].to('cpu').detach().numpy().squeeze()  # Select the first image and squeeze
plt.imshow(img, cmap='viridis')
plt.axis('off')

# Compute pc and valid
print("Shape of ele before compute_3dpts_batch:", ele.shape)
print("Shape of mask before compute_3dpts_batch:", mask.shape)
ele_tensor = torch.tensor(ele).cuda()
pc, valid = compute_3dpts_batch(ele_tensor, mask)
print("Shape of pc:", pc.shape)
print("Shape of valid:", valid.shape)

'''
# Compute norm
print("Shape of ele before depth2normal_layer_batch:", ele.shape)
print("Shape of mask before depth2normal_layer_batch:", mask.shape)
norm = depth2normal_layer_batch(ele, mask)
print("Shape of norm:", norm.shape)

# For norm
plt.figure(figsize=(12,12))
img = norm[0].to('cpu').detach().numpy().squeeze()  # Select the first image and squeeze
plt.imshow(img, cmap='viridis')
plt.axis('off')
'''
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /home/philipp/MastersThesis/sim_4obj_elevation.ipynb Cell 68 line 2
#      <a href='vscode-notebook-cell:/home/philipp/MastersThesis/sim_4obj_elevation.ipynb#Y210sZmlsZQ%3D%3D?line=20'>21</a> # Visualize the image
#      <a href='vscode-notebook-cell:/home/philipp/MastersThesis/sim_4obj_elevation.ipynb#Y210sZmlsZQ%3D%3D?line=21'>22</a> plt.figure(figsize=(12,12))
# ---> <a href='vscode-notebook-cell:/home/philipp/MastersThesis/sim_4obj_elevation.ipynb#Y210sZmlsZQ%3D%3D?line=22'>23</a> plt.imshow(img, cmap='viridis')
#      <a href='vscode-notebook-cell:/home/philipp/MastersThesis/sim_4obj_elevation.ipynb#Y210sZmlsZQ%3D%3D?line=23'>24</a> plt.axis('off')
#      <a href='vscode-notebook-cell:/home/philipp/MastersThesis/sim_4obj_elevation.ipynb#Y210sZmlsZQ%3D%3D?line=25'>26</a> # For mask_next
#
# File ~/.local/lib/python3.10/site-packages/matplotlib/pyplot.py:3346, in imshow(X, cmap, norm, aspect, interpolation, alpha, vmin, vmax, origin, extent, interpolation_stage, filternorm, filterrad, resample, url, data, **kwargs)
#    3325 @_copy_docstring_and_deprecators(Axes.imshow)
#    3326 def imshow(
#    3327     X: ArrayLike | PIL.Image.Image,
#    (...)
#    3344     **kwargs,
#    3345 ) -> AxesImage:
# -> 3346     __ret = gca().imshow(
#    3347         X,
#    3348         cmap=cmap,
#    3349         norm=norm,
#    3350         aspect=aspect,
#    3351         interpolation=interpolation,
#    3352         alpha=alpha,
#    3353         vmin=vmin,
#    3354         vmax=vmax,
#    3355         origin=origin,
#    3356         extent=extent,
#    3357         interpolation_stage=interpolation_stage,
#    3358         filternorm=filternorm,
#    3359         filterrad=filterrad,
#    3360         resample=resample,
#    3361         url=url,
#    3362         **({"data": data} if data is not None else {}),
#    3363         **kwargs,
#    3364     )
#    3365     sci(__ret)
#    3366     return __ret
#
# File ~/.local/lib/python3.10/site-packages/matplotlib/__init__.py:1465, in _preprocess_data.<locals>.inner(ax, data, *args, **kwargs)
#    1462 @functools.wraps(func)
#    1463 def inner(ax, *args, data=None, **kwargs):
#    1464     if data is None:
# -> 1465         return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1467     bound = new_sig.bind(ax, *args, **kwargs)
#    1468     auto_label = (bound.arguments.get(label_namer)
#    1469                   or bound.kwargs.get(label_namer))
#
# File ~/.local/lib/python3.10/site-packages/matplotlib/axes/_axes.py:5751, in Axes.imshow(self, X, cmap, norm, aspect, interpolation, alpha, vmin, vmax, origin, extent, interpolation_stage, filternorm, filterrad, resample, url, **kwargs)
#    5748 if aspect is not None:
#    5749     self.set_aspect(aspect)
# -> 5751 im.set_data(X)
#    5752 im.set_alpha(alpha)
#    5753 if im.get_clip_path() is None:
#    5754     # image does not already have clipping set, clip to axes patch
#
# File ~/.local/lib/python3.10/site-packages/matplotlib/image.py:723, in _ImageBase.set_data(self, A)
#     721 if isinstance(A, PIL.Image.Image):
#     722     A = pil_to_array(A)  # Needed e.g. to apply png palette.
# --> 723 self._A = self._normalize_image_array(A)
#     724 self._imcache = None
#     725 self.stale = True
#
# File ~/.local/lib/python3.10/site-packages/matplotlib/image.py:693, in _ImageBase._normalize_image_array(A)
#     691     A = A.squeeze(-1)  # If just (M, N, 1), assume scalar and apply colormap.
#     692 if not (A.ndim == 2 or A.ndim == 3 and A.shape[-1] in [3, 4]):
# --> 693     raise TypeError(f"Invalid shape {A.shape} for image data")
#     694 if A.ndim == 3:
#     695     # If the input data has values outside the valid range (after
#     696     # normalisation), we issue a warning and then clip X to the bounds
#     697     # - otherwise casting wraps extreme values, hiding outliers and
#     698     # making reliable interpretation impossible.
#     699     high = 255 if np.issubdtype(A.dtype, np.integer) else 1
#
# TypeError: Invalid shape (128,) for image data

# %%
#print("Length of data:", len(data))

for i, data in enumerate(train_dl):
        
    ac, ele_gt, mask, ac_previous, ele_previous_gt, mask_previous, ac_next, ele_next_gt, mask_next, motion1, motion2, front = data
    ac, ele_gt, mask, ac_previous, ele_previous_gt, mask_previous, ac_next, ele_next_gt, mask_next, motion1, motion2 = ac.cuda(), ele_gt.cuda(), mask.cuda(), ac_previous.cuda(), ele_previous_gt.cuda(), mask_previous.cuda(), ac_next.cuda(), ele_next_gt.cuda(), mask_next.cuda(), motion1.cuda(), motion2.cuda()
        
    break
        
model.eval()

ele = model(ac)

warp1,valid1 = inverse_warp(ac_next,ele,mask,motion2)

ele = ele*mask
pc,valid = ele2pc_output(ele,mask)



pc = pc[0]
print(pc.shape)
pc=pc.transpose(0,1)
pc =pc.to('cpu').detach().numpy().copy()
np.savetxt('./sim_4obj_ele_data/sampleB.txt',pc)



#np.savetxt('gtA.txt',pc_gt)


warp1 = warp1*mask



plt.figure(figsize=(12,12))
tester = ele.to('cpu').detach().numpy().copy()
testers = tester[0]

plt.imshow(testers.squeeze())

plt.figure(figsize=(12,12))
wp = warp1.to('cpu').detach().numpy().copy()
wps = wp[0]

plt.imshow(wps.squeeze())

ac=ac*mask
plt.figure(figsize=(12,12))
acc = ac.to('cpu').detach().numpy().copy()
acs = acc[0]

plt.imshow(acs.squeeze())
# Out:
# torch.Size([3, 65536])

# %%
print(2.89/970)
# Out:
# 0.0029793814432989693

# %%
model = UNet()
model = model.cuda()

# %%
scale=624/256

model.eval()
model_path = '.sim_4obj_ele_data/checkpoints/sim_2023_11_14//19.pth'
model.load_state_dict(torch.load(model_path))

for i, data in enumerate(test_dl): #test_dl
    ac, ele_gt, mask, ac_previous, ele_previous_gt, mask_previous, ac_next, ele_next_gt, mask_next, motion1, motion2, *_ = data
    ac, ele_gt, mask, ac_previous, ele_previous_gt, mask_previous, ac_next, ele_next_gt, mask_next, motion1, motion2 = ac.cuda(), ele_gt.cuda(), mask.cuda(), ac_previous.cuda(), ele_previous_gt.cuda(), mask_previous.cuda(), ac_next.cuda(), ele_next_gt.cuda(), mask_next.cuda(), motion1.cuda(), motion2.cuda()
    output = model(ac)
    output = output*mask
    
    ele = output[0].squeeze().to('cpu').detach().numpy()

    pc1 = torch.zeros([256, 32, 128], dtype=torch.float32)
    sfront = torch.zeros([32, 128], dtype=torch.float32)
    
    #print(ele.min())
    #print(ele.max())
    ele = np.clip(ele,0,1)
    ele = ele*31
    ele = ele.astype(dtype = np.int64)
    
    
    
    for m in range(256):
        for j in range(128):
            if ele[m][j]>0:
                k = ele[m][j]
                #print(k)
                pc1[m][k][j] = 1
                sfront[k][j] = m
    
    
    #pc1 = F.interpolate(pc1.unsqueeze(0),(32,64), mode='bicubic')
    #pc1 = pc1.squeeze()
    #print(pc1.shape)
    
    pcr = torch.zeros([256, 32, 64], dtype=torch.float32)
    
    sfront = torch.tensor(sfront,dtype=torch.float32).unsqueeze(0).unsqueeze(0)
    
    #sfront = F.interpolate(sfront,(32,64), mode='bicubic')
    sfront = sfront.squeeze()
    #sfront[sfront<1]=511
    #sfront[sfront>512]=511
    
    for m in range(32):
        for j in range(128):
            if sfront[m][j]>5 and sfront[m][j]<256:
                k = int(sfront[m][j])
                jd = int(j/2)
                pcr[k][m][jd] = 1
    
    data = torch.nonzero(pcr).numpy().astype(dtype = np.int64)
    #path = '/data/share/wang/maskgt'+str(i)+'.txt'
    #np.savetxt(path,data)
    
    
    r1=0.971+400*(0.00299)+data[:,0]*(scale*0.00299)
    phi=np.deg2rad(-9+data[:,1]/32*18)
    theta=np.deg2rad(-15+data[:,2]/64*30)
    
    length = len(data[:,0])
    
    test_pc1 = np.zeros([length,3], dtype=np.float32)
    
    test_pc1[:,0]=r1*np.cos(theta)*np.cos(phi)
    test_pc1[:,1]=r1*np.sin(theta)*np.cos(phi)
    test_pc1[:,2]=r1*np.sin(phi)
    
    # Before saving the file, check if the directory exists and create it if necessary
    output_directory = './sim_4obj_ele_data/pc/unet_sim/'
    if not os.path.exists(output_directory):
        os.makedirs(output_directory)

    path = './sim_ele_data/pc/unet_sim/all_dl'+str(i)+'.txt'
    np.savetxt(path,test_pc1)
        #resize
    if i>5:
        break    
    #==================================================
    '''
    ele = ele_gt[0].squeeze().to('cpu').detach().numpy()

    pc1 = torch.zeros([512, 32, 128], dtype=torch.float32)
    sfront = torch.zeros([32, 128], dtype=torch.float32)
    
    #print(ele.min())
    #print(ele.max())
    ele = np.clip(ele,0,1)
    ele = ele*31
    ele = ele.astype(dtype = np.int64)
    
    
    
    for m in range(512):
        for j in range(128):
            if ele[m][j]>0:
                k = ele[m][j]
                #print(k)
                pc1[m][k][j] = 1
                sfront[k][j] = m
    
    
    #pc1 = F.interpolate(pc1.unsqueeze(0),(32,64), mode='bicubic')
    #pc1 = pc1.squeeze()
    #print(pc1.shape)
    
    pcr = torch.zeros([512, 32, 64], dtype=torch.float32)
    
    sfront = torch.tensor(sfront,dtype=torch.float32).unsqueeze(0).unsqueeze(0)
    
    #sfront = F.interpolate(sfront,(32,64), mode='bicubic')
    sfront = sfront.squeeze()
    #sfront[sfront<1]=511
    #sfront[sfront>512]=511
    
    for m in range(32):
        for j in range(128):
            if sfront[m][j]>5 and sfront[m][j]<512:
                k = int(sfront[m][j])
                jd = int(j/2)
                pcr[k][m][jd] = 1
    
    data = torch.nonzero(pcr).numpy().astype(dtype = np.int64)
    #path = '/data/share/wang/maskgt'+str(i)+'.txt'
    #np.savetxt(path,data)
    
    
    r1=2.2+data[:,0]*0.003
    phi=np.deg2rad(-7+data[:,1]/32*14)
    theta=np.deg2rad(-15+data[:,2]/64*30)
    
    length = len(data[:,0])
    
    test_pc1 = np.zeros([length,3], dtype=np.float32)
    
    test_pc1[:,0]=r1*np.cos(theta)*np.cos(phi)
    test_pc1[:,1]=r1*np.sin(theta)*np.cos(phi)
    test_pc1[:,2]=r1*np.sin(phi)
    
    path = './results/unet_arti/gt'+str(i)+'.txt'
    np.savetxt(path,test_pc1)
    '''
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /home/philipp/MastersThesis/sim_elevation.ipynb Cell 70 line 5
#       <a href='vscode-notebook-cell:/home/philipp/MastersThesis/sim_elevation.ipynb#Y126sZmlsZQ%3D%3D?line=2'>3</a> model.eval()
#       <a href='vscode-notebook-cell:/home/philipp/MastersThesis/sim_elevation.ipynb#Y126sZmlsZQ%3D%3D?line=3'>4</a> model_path = '.sim_ele_data/checkpoints/sim_2023_11_14//19.pth'
# ----> <a href='vscode-notebook-cell:/home/philipp/MastersThesis/sim_elevation.ipynb#Y126sZmlsZQ%3D%3D?line=4'>5</a> model.load_state_dict(torch.load(model_path))
#       <a href='vscode-notebook-cell:/home/philipp/MastersThesis/sim_elevation.ipynb#Y126sZmlsZQ%3D%3D?line=6'>7</a> for i, data in enumerate(test_dl): #test_dl
#       <a href='vscode-notebook-cell:/home/philipp/MastersThesis/sim_elevation.ipynb#Y126sZmlsZQ%3D%3D?line=7'>8</a>     ac, ele_gt, mask, ac_previous, ele_previous_gt, mask_previous, ac_next, ele_next_gt, mask_next, motion1, motion2, *_ = data
#
# File ~/.local/lib/python3.10/site-packages/torch/serialization.py:986, in load(f, map_location, pickle_module, weights_only, mmap, **pickle_load_args)
#     983 if 'encoding' not in pickle_load_args.keys():
#     984     pickle_load_args['encoding'] = 'utf-8'
# --> 986 with _open_file_like(f, 'rb') as opened_file:
#     987     if _is_zipfile(opened_file):
#     988         # The zipfile reader is going to advance the current file position.
#     989         # If we want to actually tail call to torch.jit.load, we need to
#     990         # reset back to the original position.
#     991         orig_position = opened_file.tell()
#
# File ~/.local/lib/python3.10/site-packages/torch/serialization.py:435, in _open_file_like(name_or_buffer, mode)
#     433 def _open_file_like(name_or_buffer, mode):
#     434     if _is_path(name_or_buffer):
# --> 435         return _open_file(name_or_buffer, mode)
#     436     else:
#     437         if 'w' in mode:
#
# File ~/.local/lib/python3.10/site-packages/torch/serialization.py:416, in _open_file.__init__(self, name, mode)
#     415 def __init__(self, name, mode):
# --> 416     super().__init__(open(name, mode))
#
# FileNotFoundError: [Errno 2] No such file or directory: '.sim_ele_data/checkpoints/sim_2023_11_14//19.pth'

# %%
import json
import pickle
from PIL import Image
import numpy as np

json_path = './transforms.json' 
with open(json_path) as f:
    di = json.load(f)

#train_dl = DataLoader(acoustic_dataset,batch_size=1,shuffle=False)

#model.eval()
#model_path = './Checkpoints/UNetCheckpoint_real/best.pth'
#model.load_state_dict(torch.load(model_path))
with torch.no_grad():
    for i,data in enumerate(test_dl):
        ac, ele_gt, mask, ac_previous, ele_previous_gt, mask_previous, ac_next, ele_next_gt, mask_next, motion1, motion2, front = data
        ac, ele_gt, mask, ac_previous, ele_previous_gt, mask_previous, ac_next, ele_next_gt, mask_next, motion1, motion2 = ac.cuda(), ele_gt.cuda(), mask.cuda(), ac_previous.cuda(), ele_previous_gt.cuda(), mask_previous.cuda(), ac_next.cuda(), ele_next_gt.cuda(), mask_next.cuda(), motion1.cuda(), motion2.cuda()
        ac = ac*mask
        #ele = model(ac)
        #ele = ele*mask

        np_image = ac.to('cpu').detach().numpy()
        #np_ele = ele.to('cpu').detach().numpy()
        np_ele_gt = ele_gt.to('cpu').detach().numpy()
        pose  = np.array(di['frames'][i]['transform_matrix'])

        data = {
            'ImagingSonar': np_image.squeeze(),
            'PoseSensor': pose,
            #'elemap': np_ele.squeeze(),
            'elemap_gt': np_ele_gt.squeeze()
        }

        save_path = '../neusis/data/nerf-ground-real-mask/Data/'+str(i)+'.pkl'
        with open(save_path, 'wb') as f:
            pickle.dump(data, f)

        #print(np_ele.max())

        #break
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /home/philipp/MastersThesis/sim_elevation.ipynb Cell 71 line 7
#       <a href='vscode-notebook-cell:/home/philipp/MastersThesis/sim_elevation.ipynb#Y130sZmlsZQ%3D%3D?line=3'>4</a> import numpy as np
#       <a href='vscode-notebook-cell:/home/philipp/MastersThesis/sim_elevation.ipynb#Y130sZmlsZQ%3D%3D?line=5'>6</a> json_path = './transforms.json'
# ----> <a href='vscode-notebook-cell:/home/philipp/MastersThesis/sim_elevation.ipynb#Y130sZmlsZQ%3D%3D?line=6'>7</a> with open(json_path) as f:
#       <a href='vscode-notebook-cell:/home/philipp/MastersThesis/sim_elevation.ipynb#Y130sZmlsZQ%3D%3D?line=7'>8</a>     di = json.load(f)
#      <a href='vscode-notebook-cell:/home/philipp/MastersThesis/sim_elevation.ipynb#Y130sZmlsZQ%3D%3D?line=9'>10</a> #train_dl = DataLoader(acoustic_dataset,batch_size=1,shuffle=False)
#      <a href='vscode-notebook-cell:/home/philipp/MastersThesis/sim_elevation.ipynb#Y130sZmlsZQ%3D%3D?line=10'>11</a>
#      <a href='vscode-notebook-cell:/home/philipp/MastersThesis/sim_elevation.ipynb#Y130sZmlsZQ%3D%3D?line=11'>12</a> #model.eval()
#      <a href='vscode-notebook-cell:/home/philipp/MastersThesis/sim_elevation.ipynb#Y130sZmlsZQ%3D%3D?line=12'>13</a> #model_path = './Checkpoints/UNetCheckpoint_real/best.pth'
#      <a href='vscode-notebook-cell:/home/philipp/MastersThesis/sim_elevation.ipynb#Y130sZmlsZQ%3D%3D?line=13'>14</a> #model.load_state_dict(torch.load(model_path))
#
# File ~/.local/lib/python3.10/site-packages/IPython/core/interactiveshell.py:286, in _modified_open(file, *args, **kwargs)
#     279 if file in {0, 1, 2}:
#     280     raise ValueError(
#     281         f"IPython won't let you open fd={file} by default "
#     282         "as it is likely to crash IPython. If you know what you are doing, "
#     283         "you can use builtins' open."
#     284     )
# --> 286 return io_open(file, *args, **kwargs)
#
# FileNotFoundError: [Errno 2] No such file or directory: './transforms.json'

# %%
minimum_depth = 0.971+0.00299*400
maximum_depth = 0.971+0.00299*1100

print(minimum_depth)
print(maximum_depth)
# Out:
# 2.167
# 4.26
